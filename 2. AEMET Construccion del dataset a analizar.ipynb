# %% [markdown]
# # 1. Se escribe el código necesario para descargar los datos de la AEMET disponibles en OpenData API de 6 en 6 meses sobre la estación meteorológica de Madrid - Retiro (id 3195).

# %% [markdown]
# ## 1.1 Primero se obtiene la fecha máxima de descarga, que se sabe que es de 4 días antes al día de hoy

# %%
import os
import requests
import json
from datetime import datetime, timedelta
import pandas as pd
import time
from urllib3.exceptions import ProtocolError
from requests.exceptions import ConnectionError
from http.client import RemoteDisconnected

# %%
with open('API_KEY_AEMET.txt') as f:
    API_KEY = f.readline().strip()

print(f"Mi API Key es: \n\n{API_KEY}")
# Out:
# Mi API Key es:
#
# eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJmZWxpeHRjbDk3QGdtYWlsLmNvbSIsImp0aSI6ImFmYTVjNjEwLTNmNmUtNDNhZS1iYTZiLWI0OTkyOTM2NTY2ZSIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNzQwOTM4NzY4LCJ1c2VySWQiOiJhZmE1YzYxMC0zZjZlLTQzYWUtYmE2Yi1iNDk5MjkzNjU2NmUiLCJyb2xlIjoiIn0.-D_-Zb0rh0kAgHJgGZOM_QCCKaNZhgDuP4wQPo2Bw7E

# %% [markdown]
# Se define la fecha actual en la variable 'ahora' y el día 1 del mes anterior para que haya suficientes días entre la fecha inicial y la fecha máxima del dato devuelto de la API

# %%
ahora = datetime.now()
if ahora.month == 1:
    dia_1_mes_anterior = datetime(ahora.year - 1, 12, 1)
else:
    dia_1_mes_anterior = datetime(ahora.year, ahora.month - 1, 1)

ahora = ahora.strftime("%Y-%m-%dT%H:%M:%SUTC")
dia_1_mes_anterior = dia_1_mes_anterior.strftime("%Y-%m-%dT%H:%M:%SUTC")

print(ahora)
print(dia_1_mes_anterior)
# Out:
# 2025-03-22T20:51:26UTC
# 2025-02-01T00:00:00UTC

# %% [markdown]
# Se descarga el json generado por las fechas definidas en el bloque anterior

# %%
fecha_ini = dia_1_mes_anterior
fecha_fin = ahora
estacion_id = "3195"  # Ejemplo de estación meteorológica de Madrid-Retiro

url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fecha_ini}/fechafin/{fecha_fin}/estacion/{estacion_id}?api_key={API_KEY}"

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=4, ensure_ascii=False))
    datos_url = data.get("datos")
    if datos_url:
        response_data = requests.get(datos_url)
        if response_data.status_code == 200:
            datos_historicos = response_data.json()
            print(json.dumps(datos_historicos, indent=4, ensure_ascii=False))
        else:
            print("Error al obtener los datos reales")
    else:
        print("No se encontró la URL de datos")
else:
    print("Error en la petición inicial, código de error:", response.status_code)
# Out:
# {
#     "descripcion": "exito",
#     "estado": 200,
#     "datos": "https://opendata.aemet.es/opendata/sh/61f7af51",
#     "metadatos": "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# [
#     {
#         "fecha": "2025-02-01",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,6",
#         "prec": "0,0",
#         "tmin": "1,5",
#         "horatmin": "06:30",
#         "tmax": "11,6",
#         "horatmax": "16:00",
#         "dir": "01",
#         "velmedia": "2,2",
#         "racha": "8,6",
#         "horaracha": "17:30",
#         "presMax": "948,1",
#         "horaPresMax": "00",
#         "presMin": "940,7",
#         "horaPresMin": "17",
#         "hrMedia": "63",
#         "hrMax": "89",
#         "horaHrMax": "06:10",
#         "hrMin": "46",
#         "horaHrMin": "17:30"
#     },
#     {
#         "fecha": "2025-02-02",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,2",
#         "prec": "0,0",
#         "tmin": "2,0",
#         "horatmin": "08:00",
#         "tmax": "10,5",
#         "horatmax": "13:30",
#         "dir": "04",
#         "velmedia": "0,8",
#         "racha": "9,4",
#         "horaracha": "23:59",
#         "presMax": "942,5",
#         "horaPresMax": "24",
#         "presMin": "939,4",
#         "horaPresMin": "15",
#         "hrMedia": "71",
#         "hrMax": "86",
#         "horaHrMax": "08:00",
#         "hrMin": "55",
#         "horaHrMin": "13:30"
#     },
#     {
#         "fecha": "2025-02-03",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,2",
#         "prec": "0,0",
#         "tmin": "3,2",
#         "horatmin": "07:50",
#         "tmax": "11,3",
#         "horatmax": "14:50",
#         "dir": "04",
#         "velmedia": "1,9",
#         "racha": "8,6",
#         "horaracha": "00:10",
#         "presMax": "946,8",
#         "horaPresMax": "24",
#         "presMin": "942,5",
#         "horaPresMin": "00",
#         "hrMedia": "62",
#         "hrMax": "84",
#         "horaHrMax": "07:30",
#         "hrMin": "40",
#         "horaHrMin": "15:50"
#     },
#     {
#         "fecha": "2025-02-04",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,6",
#         "prec": "0,0",
#         "tmin": "2,4",
#         "horatmin": "07:50",
#         "tmax": "12,7",
#         "horatmax": "13:50",
#         "dir": "05",
#         "velmedia": "1,4",
#         "racha": "5,8",
#         "horaracha": "00:30",
#         "presMax": "952,3",
#         "horaPresMax": "24",
#         "presMin": "946,7",
#         "horaPresMin": "Varias",
#         "hrMedia": "59",
#         "hrMax": "82",
#         "horaHrMax": "07:30",
#         "hrMin": "42",
#         "horaHrMin": "16:10"
#     },
#     {
#         "fecha": "2025-02-05",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,1",
#         "prec": "0,0",
#         "tmin": "2,2",
#         "horatmin": "07:50",
#         "tmax": "14,0",
#         "horatmax": "14:50",
#         "dir": "05",
#         "velmedia": "0,8",
#         "racha": "4,4",
#         "horaracha": "05:10",
#         "presMax": "954,8",
#         "horaPresMax": "10",
#         "presMin": "951,3",
#         "horaPresMin": "16",
#         "hrMedia": "56",
#         "hrMax": "85",
#         "horaHrMax": "07:30",
#         "hrMin": "30",
#         "horaHrMin": "14:20"
#     },
#     {
#         "fecha": "2025-02-06",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,2",
#         "prec": "0,0",
#         "tmin": "1,9",
#         "horatmin": "07:00",
#         "tmax": "12,5",
#         "horatmax": "16:40",
#         "dir": "04",
#         "velmedia": "1,4",
#         "racha": "4,4",
#         "horaracha": "00:30",
#         "presMax": "952,0",
#         "horaPresMax": "00",
#         "presMin": "944,8",
#         "horaPresMin": "24",
#         "hrMedia": "54",
#         "hrMax": "76",
#         "horaHrMax": "23:30",
#         "hrMin": "37",
#         "horaHrMin": "14:40"
#     },
#     {
#         "fecha": "2025-02-07",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,9",
#         "prec": "7,6",
#         "tmin": "1,2",
#         "horatmin": "06:50",
#         "tmax": "8,6",
#         "horatmax": "12:00",
#         "dir": "24",
#         "velmedia": "1,9",
#         "racha": "8,9",
#         "horaracha": "12:30",
#         "presMax": "944,8",
#         "horaPresMax": "00",
#         "presMin": "937,5",
#         "horaPresMin": "17",
#         "hrMedia": "88",
#         "hrMax": "99",
#         "horaHrMax": "Varias",
#         "hrMin": "67",
#         "horaHrMin": "12:00"
#     },
#     {
#         "fecha": "2025-02-08",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,2",
#         "prec": "0,0",
#         "tmin": "3,0",
#         "horatmin": "07:50",
#         "tmax": "11,4",
#         "horatmax": "16:40",
#         "dir": "99",
#         "velmedia": "1,7",
#         "racha": "5,8",
#         "horaracha": "Varias",
#         "presMax": "946,6",
#         "horaPresMax": "24",
#         "presMin": "938,3",
#         "horaPresMin": "00"
#     },
#     {
#         "fecha": "2025-02-09",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,2",
#         "prec": "0,0",
#         "tmin": "3,3",
#         "horatmin": "05:30",
#         "tmax": "13,2",
#         "horatmax": "16:00",
#         "dir": "99",
#         "velmedia": "0,8",
#         "racha": "3,3",
#         "horaracha": "Varias",
#         "presMax": "948,0",
#         "horaPresMax": "Varias",
#         "presMin": "944,6",
#         "horaPresMin": "24",
#         "hrMedia": "82"
#     },
#     {
#         "fecha": "2025-02-10",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,4",
#         "prec": "0,0",
#         "tmin": "7,4",
#         "horatmin": "05:00",
#         "tmax": "13,5",
#         "horatmax": "15:30",
#         "dir": "13",
#         "velmedia": "1,4",
#         "racha": "5,0",
#         "horaracha": "12:40",
#         "presMax": "944,6",
#         "horaPresMax": "00",
#         "presMin": "939,5",
#         "horaPresMin": "19",
#         "hrMedia": "78",
#         "hrMax": "95",
#         "horaHrMax": "05:00",
#         "hrMin": "64",
#         "horaHrMin": "13:40"
#     },
#     {
#         "fecha": "2025-02-11",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,4",
#         "prec": "16,3",
#         "tmin": "5,6",
#         "horatmin": "07:00",
#         "tmax": "13,3",
#         "horatmax": "16:10",
#         "dir": "25",
#         "velmedia": "1,4",
#         "racha": "7,2",
#         "horaracha": "19:50",
#         "presMax": "940,5",
#         "horaPresMax": "10",
#         "presMin": "935,8",
#         "horaPresMin": "24",
#         "hrMedia": "77",
#         "hrMax": "99",
#         "horaHrMax": "Varias",
#         "hrMin": "58",
#         "horaHrMin": "16:10"
#     },
#     {
#         "fecha": "2025-02-12",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,4",
#         "prec": "0,0",
#         "tmin": "7,3",
#         "horatmin": "08:00",
#         "tmax": "13,6",
#         "horatmax": "14:40",
#         "dir": "30",
#         "velmedia": "2,2",
#         "racha": "8,9",
#         "horaracha": "10:50",
#         "presMax": "942,1",
#         "horaPresMax": "23",
#         "presMin": "935,0",
#         "horaPresMin": "02",
#         "hrMedia": "67"
#     },
#     {
#         "fecha": "2025-02-13",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,2",
#         "prec": "0,0",
#         "tmin": "3,9",
#         "horatmin": "07:00",
#         "tmax": "14,4",
#         "horatmax": "15:30",
#         "dir": "24",
#         "velmedia": "1,4",
#         "racha": "5,0",
#         "horaracha": "14:20",
#         "presMax": "943,7",
#         "horaPresMax": "11",
#         "presMin": "941,4",
#         "horaPresMin": "15",
#         "hrMedia": "69",
#         "hrMax": "94",
#         "horaHrMax": "06:50",
#         "hrMin": "51",
#         "horaHrMin": "15:20"
#     },
#     {
#         "fecha": "2025-02-14",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,8",
#         "prec": "0,0",
#         "tmin": "5,8",
#         "horatmin": "06:00",
#         "tmax": "15,9",
#         "horatmax": "16:40",
#         "dir": "23",
#         "velmedia": "1,1",
#         "racha": "5,3",
#         "horaracha": "15:00",
#         "presMax": "942,5",
#         "horaPresMax": "00",
#         "presMin": "938,5",
#         "horaPresMin": "23",
#         "hrMedia": "71",
#         "hrMax": "93",
#         "horaHrMax": "05:50",
#         "hrMin": "46",
#         "horaHrMin": "16:10"
#     },
#     {
#         "fecha": "2025-02-15",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,8",
#         "prec": "0,0",
#         "tmin": "6,2",
#         "horatmin": "Varias",
#         "tmax": "15,5",
#         "horatmax": "16:00",
#         "dir": "04",
#         "velmedia": "1,1",
#         "racha": "6,1",
#         "horaracha": "23:50",
#         "presMax": "938,6",
#         "horaPresMax": "00",
#         "presMin": "934,3",
#         "horaPresMin": "Varias",
#         "hrMedia": "67",
#         "hrMax": "87",
#         "horaHrMax": "07:50",
#         "hrMin": "49",
#         "horaHrMin": "16:00"
#     },
#     {
#         "fecha": "2025-02-16",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "12,0",
#         "prec": "0,0",
#         "tmin": "6,2",
#         "horatmin": "06:00",
#         "tmax": "17,9",
#         "horatmax": "15:50",
#         "dir": "25",
#         "velmedia": "1,9",
#         "racha": "7,8",
#         "horaracha": "20:50",
#         "presMax": "938,4",
#         "horaPresMax": "22",
#         "presMin": "934,5",
#         "horaPresMin": "04",
#         "hrMedia": "56",
#         "hrMax": "84",
#         "horaHrMax": "Varias",
#         "hrMin": "32",
#         "horaHrMin": "15:00"
#     },
#     {
#         "fecha": "2025-02-17",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,3",
#         "prec": "0,0",
#         "tmin": "5,7",
#         "horatmin": "07:00",
#         "tmax": "14,9",
#         "horatmax": "15:20",
#         "dir": "99",
#         "velmedia": "1,1",
#         "racha": "4,2",
#         "horaracha": "Varias",
#         "presMax": "939,4",
#         "horaPresMax": "11",
#         "presMin": "936,4",
#         "horaPresMin": "Varias",
#         "hrMedia": "79",
#         "hrMax": "99",
#         "horaHrMax": "07:20",
#         "hrMin": "53",
#         "horaHrMin": "15:20"
#     },
#     {
#         "fecha": "2025-02-18",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "12,6",
#         "prec": "0,0",
#         "tmin": "8,3",
#         "horatmin": "06:00",
#         "tmax": "17,0",
#         "horatmax": "16:00",
#         "dir": "05",
#         "velmedia": "1,7",
#         "racha": "6,4",
#         "horaracha": "05:00",
#         "presMax": "937,1",
#         "horaPresMax": "24",
#         "presMin": "933,0",
#         "horaPresMin": "Varias",
#         "hrMedia": "67",
#         "hrMax": "82",
#         "horaHrMax": "06:10",
#         "hrMin": "46",
#         "horaHrMin": "16:50"
#     },
#     {
#         "fecha": "2025-02-19",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "12,4",
#         "prec": "0,0",
#         "tmin": "8,5",
#         "horatmin": "07:50",
#         "tmax": "16,2",
#         "horatmax": "16:40",
#         "dir": "23",
#         "velmedia": "1,7",
#         "racha": "5,6",
#         "horaracha": "16:10",
#         "presMax": "946,1",
#         "horaPresMax": "24",
#         "presMin": "937,1",
#         "horaPresMin": "00",
#         "hrMedia": "72",
#         "hrMax": "92",
#         "horaHrMax": "07:40",
#         "hrMin": "59",
#         "horaHrMin": "16:10"
#     },
#     {
#         "fecha": "2025-02-20",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "11,5",
#         "prec": "0,0",
#         "tmin": "6,1",
#         "horatmin": "06:10",
#         "tmax": "16,9",
#         "horatmax": "16:40",
#         "dir": "27",
#         "velmedia": "1,1",
#         "racha": "6,1",
#         "horaracha": "13:10",
#         "presMax": "949,1",
#         "horaPresMax": "11",
#         "presMin": "945,9",
#         "horaPresMin": "00",
#         "hrMedia": "78",
#         "hrMax": "99",
#         "horaHrMax": "Varias",
#         "hrMin": "57",
#         "horaHrMin": "Varias"
#     },
#     {
#         "fecha": "2025-02-21",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "12,2",
#         "prec": "0,5",
#         "tmin": "8,2",
#         "horatmin": "04:30",
#         "tmax": "16,3",
#         "horatmax": "16:30",
#         "dir": "18",
#         "velmedia": "1,9",
#         "racha": "10,0",
#         "horaracha": "21:50",
#         "presMax": "946,4",
#         "horaPresMax": "Varias",
#         "presMin": "938,7",
#         "horaPresMin": "18",
#         "hrMedia": "75",
#         "hrMax": "93",
#         "horaHrMax": "Varias",
#         "hrMin": "50",
#         "horaHrMin": "16:00"
#     },
#     {
#         "fecha": "2025-02-22",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,8",
#         "prec": "0,0",
#         "tmin": "6,9",
#         "horatmin": "07:20",
#         "tmax": "14,6",
#         "horatmax": "16:20",
#         "dir": "24",
#         "velmedia": "1,7",
#         "racha": "10,6",
#         "horaracha": "01:00",
#         "presMax": "947,5",
#         "horaPresMax": "24",
#         "presMin": "939,7",
#         "horaPresMin": "00",
#         "hrMedia": "64",
#         "hrMax": "97",
#         "horaHrMax": "06:50",
#         "hrMin": "36",
#         "horaHrMin": "16:00"
#     },
#     {
#         "fecha": "2025-02-23",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,0",
#         "prec": "0,0",
#         "tmin": "4,7",
#         "horatmin": "07:00",
#         "tmax": "15,4",
#         "horatmax": "15:50",
#         "dir": "23",
#         "velmedia": "1,1",
#         "racha": "4,7",
#         "horaracha": "13:10",
#         "presMax": "951,6",
#         "horaPresMax": "10",
#         "presMin": "947,4",
#         "horaPresMin": "00",
#         "hrMedia": "59",
#         "hrMax": "87",
#         "horaHrMax": "07:40",
#         "hrMin": "34",
#         "horaHrMin": "15:40"
#     },
#     {
#         "fecha": "2025-02-24",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,3",
#         "prec": "0,0",
#         "tmin": "5,4",
#         "horatmin": "07:40",
#         "tmax": "15,2",
#         "horatmax": "16:10",
#         "dir": "23",
#         "velmedia": "1,9",
#         "racha": "7,5",
#         "horaracha": "Varias",
#         "presMax": "951,6",
#         "horaPresMax": "10",
#         "presMin": "946,4",
#         "horaPresMin": "24",
#         "hrMedia": "65",
#         "hrMax": "88",
#         "horaHrMax": "06:00",
#         "hrMin": "49",
#         "horaHrMin": "17:30"
#     },
#     {
#         "fecha": "2025-02-25",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,5",
#         "prec": "0,0",
#         "tmin": "7,1",
#         "horatmin": "23:50",
#         "tmax": "13,9",
#         "horatmax": "16:30",
#         "dir": "29",
#         "velmedia": "3,1",
#         "racha": "10,0",
#         "horaracha": "12:50",
#         "presMax": "948,4",
#         "horaPresMax": "24",
#         "presMin": "944,3",
#         "horaPresMin": "Varias",
#         "hrMedia": "61",
#         "hrMax": "91",
#         "horaHrMax": "08:00",
#         "hrMin": "39",
#         "horaHrMin": "17:00"
#     },
#     {
#         "fecha": "2025-02-26",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,4",
#         "prec": "0,0",
#         "tmin": "3,7",
#         "horatmin": "07:30",
#         "tmax": "13,2",
#         "horatmax": "13:40",
#         "dir": "24",
#         "velmedia": "1,9",
#         "racha": "6,1",
#         "horaracha": "15:00",
#         "presMax": "949,4",
#         "horaPresMax": "10",
#         "presMin": "943,2",
#         "horaPresMin": "24",
#         "hrMedia": "54",
#         "hrMax": "82",
#         "horaHrMax": "06:20",
#         "hrMin": "36",
#         "horaHrMin": "14:00"
#     },
#     {
#         "fecha": "2025-02-27",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,4",
#         "prec": "1,9",
#         "tmin": "5,3",
#         "horatmin": "09:00",
#         "tmax": "13,5",
#         "horatmax": "16:30",
#         "dir": "08",
#         "velmedia": "1,7",
#         "racha": "4,7",
#         "horaracha": "06:20",
#         "presMax": "943,2",
#         "horaPresMax": "00",
#         "presMin": "938,6",
#         "horaPresMin": "Varias",
#         "hrMedia": "61",
#         "hrMax": "95",
#         "horaHrMax": "09:30",
#         "hrMin": "49",
#         "horaHrMin": "16:50"
#     },
#     {
#         "fecha": "2025-02-28",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "11,0",
#         "prec": "2,0",
#         "tmin": "6,1",
#         "horatmin": "06:00",
#         "tmax": "16,0",
#         "horatmax": "15:40",
#         "dir": "10",
#         "velmedia": "3,1",
#         "racha": "7,8",
#         "horaracha": "20:50",
#         "presMax": "939,6",
#         "horaPresMax": "00",
#         "presMin": "934,5",
#         "horaPresMin": "16",
#         "hrMedia": "58",
#         "hrMax": "80",
#         "horaHrMax": "05:00",
#         "hrMin": "42",
#         "horaHrMin": "16:30"
#     },
#     {
#         "fecha": "2025-03-01",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,4",
#         "prec": "12,0",
#         "tmin": "4,0",
#         "horatmin": "23:59",
#         "tmax": "10,8",
#         "horatmax": "00:10",
#         "dir": "99",
#         "velmedia": "3,3",
#         "racha": "9,2",
#         "horaracha": "Varias",
#         "presMax": "940,7",
#         "horaPresMax": "23",
#         "presMin": "936,0",
#         "horaPresMin": "04",
#         "hrMedia": "94",
#         "hrMax": "98",
#         "horaHrMax": "Varias",
#         "hrMin": "64",
#         "horaHrMin": "00:00"
#     },
#     {
#         "fecha": "2025-03-02",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "3,7",
#         "prec": "17,6",
#         "tmin": "2,5",
#         "horatmin": "08:00",
#         "tmax": "4,9",
#         "horatmax": "Varias",
#         "dir": "05",
#         "velmedia": "4,2",
#         "racha": "11,1",
#         "horaracha": "00:30",
#         "presMax": "941,5",
#         "horaPresMax": "09",
#         "presMin": "939,6",
#         "horaPresMin": "18",
#         "hrMedia": "96",
#         "hrMax": "99",
#         "horaHrMax": "Varias",
#         "hrMin": "89",
#         "horaHrMin": "03:20"
#     },
#     {
#         "fecha": "2025-03-03",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,6",
#         "prec": "14,3",
#         "tmin": "4,9",
#         "horatmin": "00:30",
#         "tmax": "10,4",
#         "horatmax": "13:50",
#         "dir": "05",
#         "velmedia": "3,3",
#         "racha": "7,8",
#         "horaracha": "07:50",
#         "presMax": "939,9",
#         "horaPresMax": "00",
#         "presMin": "936,3",
#         "horaPresMin": "17",
#         "hrMedia": "92",
#         "hrMax": "99",
#         "horaHrMax": "23:59",
#         "hrMin": "85",
#         "horaHrMin": "12:20"
#     },
#     {
#         "fecha": "2025-03-04",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,8",
#         "prec": "2,1",
#         "tmin": "7,5",
#         "horatmin": "06:30",
#         "tmax": "14,0",
#         "horatmax": "14:00",
#         "dir": "04",
#         "velmedia": "1,9",
#         "racha": "7,2",
#         "horaracha": "10:10",
#         "presMax": "939,6",
#         "horaPresMax": "22",
#         "presMin": "936,8",
#         "horaPresMin": "05",
#         "hrMedia": "84"
#     },
#     {
#         "fecha": "2025-03-05",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,8",
#         "prec": "4,4",
#         "tmin": "8,5",
#         "horatmin": "06:00",
#         "tmax": "13,0",
#         "horatmax": "13:50",
#         "dir": "06",
#         "velmedia": "2,8",
#         "racha": "8,1",
#         "horaracha": "08:20",
#         "presMax": "939,3",
#         "horaPresMax": "Varias",
#         "presMin": "936,7",
#         "horaPresMin": "Varias",
#         "hrMedia": "88",
#         "hrMax": "96",
#         "horaHrMax": "Varias",
#         "hrMin": "77",
#         "horaHrMin": "16:30"
#     },
#     {
#         "fecha": "2025-03-06",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,8",
#         "prec": "16,1",
#         "tmin": "8,5",
#         "horatmin": "04:00",
#         "tmax": "13,2",
#         "horatmax": "13:20",
#         "dir": "19",
#         "velmedia": "2,2",
#         "racha": "8,9",
#         "horaracha": "12:10",
#         "presMax": "937,2",
#         "horaPresMax": "23",
#         "presMin": "934,5",
#         "horaPresMin": "06"
#     },
#     {
#         "fecha": "2025-03-07",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,4",
#         "prec": "21,9",
#         "tmin": "8,7",
#         "horatmin": "03:30",
#         "tmax": "12,0",
#         "horatmax": "14:20",
#         "dir": "99",
#         "velmedia": "2,5",
#         "racha": "9,2",
#         "horaracha": "Varias",
#         "presMax": "936,7",
#         "horaPresMax": "00",
#         "presMin": "928,8",
#         "horaPresMin": "19"
#     },
#     {
#         "fecha": "2025-03-08",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,4",
#         "prec": "13,8",
#         "tmin": "5,7",
#         "horatmin": "23:59",
#         "tmax": "11,2",
#         "horatmax": "13:10",
#         "dir": "18",
#         "velmedia": "4,2",
#         "racha": "16,7",
#         "horaracha": "12:50",
#         "presMax": "929,3",
#         "horaPresMax": "00",
#         "presMin": "919,0",
#         "horaPresMin": "17",
#         "hrMedia": "92",
#         "hrMax": "99",
#         "horaHrMax": "01:00",
#         "hrMin": "88",
#         "horaHrMin": "14:00"
#     },
#     {
#         "fecha": "2025-03-09",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,2",
#         "prec": "3,6",
#         "tmin": "4,1",
#         "horatmin": "06:30",
#         "tmax": "10,3",
#         "horatmax": "14:00",
#         "dir": "25",
#         "velmedia": "2,2",
#         "racha": "11,1",
#         "horaracha": "11:20",
#         "presMax": "923,6",
#         "horaPresMax": "22",
#         "presMin": "921,1",
#         "horaPresMin": "16",
#         "hrMedia": "86",
#         "hrMax": "99",
#         "horaHrMax": "Varias",
#         "hrMin": "70",
#         "horaHrMin": "13:40"
#     },
#     {
#         "fecha": "2025-03-10",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,6",
#         "prec": "23,5",
#         "tmin": "5,8",
#         "horatmin": "Varias",
#         "tmax": "11,5",
#         "horatmax": "15:00"
#     },
#     {
#         "fecha": "2025-03-11",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,4",
#         "prec": "7,5",
#         "tmin": "6,2",
#         "horatmin": "23:59",
#         "tmax": "10,6",
#         "horatmax": "16:40",
#         "dir": "25",
#         "velmedia": "2,2",
#         "racha": "10,3",
#         "horaracha": "13:10",
#         "presMax": "925,8",
#         "horaPresMax": "24",
#         "presMin": "921,6",
#         "horaPresMin": "15"
#     },
#     {
#         "fecha": "2025-03-12",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,5",
#         "prec": "0,0",
#         "tmin": "4,2",
#         "horatmin": "07:00",
#         "tmax": "12,8",
#         "horatmax": "13:20",
#         "dir": "23",
#         "velmedia": "2,5",
#         "racha": "10,0",
#         "horaracha": "15:10",
#         "presMax": "928,1",
#         "horaPresMax": "09",
#         "presMin": "923,5",
#         "horaPresMin": "24"
#     },
#     {
#         "fecha": "2025-03-13",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,0",
#         "prec": "4,7",
#         "tmin": "4,3",
#         "horatmin": "23:50",
#         "tmax": "11,6",
#         "horatmax": "15:00",
#         "dir": "05",
#         "velmedia": "1,4",
#         "racha": "10,3",
#         "horaracha": "23:10",
#         "presMax": "923,5",
#         "horaPresMax": "00",
#         "presMin": "915,9",
#         "horaPresMin": "15",
#         "hrMedia": "89",
#         "hrMax": "98",
#         "horaHrMax": "18:40",
#         "hrMin": "63",
#         "horaHrMin": "14:30"
#     },
#     {
#         "fecha": "2025-03-14",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,2",
#         "prec": "0,0",
#         "tmin": "4,1",
#         "horatmin": "Varias",
#         "tmax": "10,4",
#         "horatmax": "14:00",
#         "dir": "05",
#         "velmedia": "3,6",
#         "racha": "12,2",
#         "horaracha": "09:10",
#         "presMax": "929,6",
#         "horaPresMax": "24",
#         "presMin": "919,3",
#         "horaPresMin": "04",
#         "hrMedia": "57",
#         "hrMax": "96",
#         "horaHrMax": "00:00",
#         "hrMin": "38",
#         "horaHrMin": "17:00"
#     },
#     {
#         "fecha": "2025-03-15",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,8",
#         "prec": "6,7",
#         "tmin": "1,1",
#         "horatmin": "06:00",
#         "tmax": "10,6",
#         "horatmax": "14:00",
#         "dir": "03",
#         "velmedia": "1,9",
#         "racha": "6,7",
#         "horaracha": "00:10",
#         "presMax": "936,1",
#         "horaPresMax": "Varias",
#         "presMin": "929,6",
#         "horaPresMin": "00",
#         "hrMedia": "60",
#         "hrMax": "88",
#         "horaHrMax": "05:20",
#         "hrMin": "40",
#         "horaHrMin": "13:50"
#     },
#     {
#         "fecha": "2025-03-16",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,8",
#         "prec": "0,4",
#         "tmin": "4,1",
#         "horatmin": "07:50",
#         "tmax": "11,6",
#         "horatmax": "15:30",
#         "dir": "27",
#         "velmedia": "2,2",
#         "racha": "7,2",
#         "horaracha": "09:50",
#         "presMax": "938,2",
#         "horaPresMax": "20",
#         "presMin": "934,3",
#         "horaPresMin": "Varias",
#         "hrMedia": "69",
#         "hrMax": "98",
#         "horaHrMax": "Varias",
#         "hrMin": "44",
#         "horaHrMin": "18:00"
#     },
#     {
#         "fecha": "2025-03-17",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,8",
#         "prec": "16,7",
#         "tmin": "4,2",
#         "horatmin": "09:00",
#         "tmax": "9,4",
#         "horatmax": "21:00",
#         "dir": "13",
#         "velmedia": "3,1",
#         "racha": "10,6",
#         "horaracha": "21:00",
#         "presMax": "937,8",
#         "horaPresMax": "00",
#         "presMin": "932,5",
#         "horaPresMin": "18",
#         "hrMedia": "87",
#         "hrMax": "99",
#         "horaHrMax": "23:59",
#         "hrMin": "58",
#         "horaHrMin": "00:00"
#     },
#     {
#         "fecha": "2025-03-18",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,8",
#         "prec": "20,9",
#         "tmin": "6,2",
#         "horatmin": "Varias",
#         "tmax": "11,4",
#         "horatmax": "16:00",
#         "dir": "12",
#         "velmedia": "2,8",
#         "racha": "10,8",
#         "horaracha": "10:00",
#         "presMax": "938,3",
#         "horaPresMax": "24",
#         "presMin": "931,8",
#         "horaPresMin": "Varias"
#     },
#     {
#         "fecha": "2025-03-19",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "12,4",
#         "prec": "0,0",
#         "tmin": "8,1",
#         "horatmin": "07:00",
#         "tmax": "16,6",
#         "horatmax": "16:00",
#         "dir": "12",
#         "velmedia": "3,3",
#         "racha": "13,1",
#         "horaracha": "21:10",
#         "presMax": "940,1",
#         "horaPresMax": "10",
#         "presMin": "935,9",
#         "horaPresMin": "18",
#         "hrMedia": "74",
#         "hrMax": "99",
#         "horaHrMax": "00:00",
#         "hrMin": "51",
#         "horaHrMin": "15:00"
#     }
# ]

# %% [markdown]
# Se obtiene la fecha maxima descargada. A día 22/03/2025 es el 18/03/2025

# %%
fechas = [fecha['fecha'] for fecha in datos_historicos]
fecha_max_descargada = max(fechas)
print(fecha_max_descargada)
# Out:
# 2025-03-19

# %% [markdown]
# Se imprime la diferencia en días entre hoy y la fecha máxima descargada

# %%
# Convert fecha_max_descargada to datetime
fecha_max = datetime.strptime(fecha_max_descargada, '%Y-%m-%d')

# Convert ahora to datetime
ahora_dt = datetime.strptime(ahora, '%Y-%m-%dT%H:%M:%SUTC')

# Calculate difference in days
diferencia_dias = (ahora_dt - fecha_max).days

print(f"Diferencia en días: {diferencia_dias}")
# Out:
# Diferencia en días: 3

# %% [markdown]
# ## 1.2 Se descargan todos los datos de 6 en 6 meses, ya que esta API no permite un rango de fechas superior a 6 meses.

# %% [markdown]
# Se definen las fechas a descargar con la siguiente función

# %%
# Se formatea la fecha para que coincida con el formato de la API
fecha_max_descargada = fecha_max.strftime("%Y-%m-%dT%H:%M:%SUTC")

# Se convierte la fecha a datetime para poder restarle los dias que se quiera
fecha_max_dt = datetime.strptime(fecha_max_descargada, "%Y-%m-%dT%H:%M:%SUTC")

# %% [markdown]
# Se define la siguiente funcion que devuelve los intervalos de fechas a ejecutar en la API

# %%
def listar_fechas_descargas(fecha_max: datetime, dias: int, n_veces: int) -> {list, list}:
    """
    Función que devuelve 1 diccionario que contiene 2 listas de fechas empezando por 
    una fecha dada y retrocediendo un número de días dado n_veces.

    La primera lista almacena la fecha inicial de descarga y la segunda lista
    almacena la fecha final de descarga.

    Las fechas devueltas están en el formato correcto para la API de AEMET.
    """
    fechas_iniciales = []
    for i in range(n_veces):

        if i == 0 :
            fecha_inicial = fecha_max - timedelta(days=dias*(i+1))
        else:
            fecha_inicial = fecha_max - timedelta(days=dias*(i+1)+i) 
            # Se resta 1 días más para que la fecha inicial no coincida con la fecha final del siguiente periodo.

        fecha_inicial = fecha_inicial.strftime("%Y-%m-%dT%H:%M:%SUTC")
        fechas_iniciales.append(fecha_inicial)

    fechas_finales = []
    for i in range(n_veces):

        if i == 0:
            fecha_final = fecha_max - timedelta(days=dias*(i)) # En la primera iteración no resta nada porque interesa almacenar la fecha máxima.
        else:
            fecha_final = fecha_max - timedelta(days=dias*(i)+i)
            # Se resta i días más para que la fecha final no coincida con la fecha inicial del periodo anterior.

        fecha_final = fecha_final.strftime("%Y-%m-%dT%H:%M:%SUTC")
        fechas_finales.append(fecha_final)

    return {"fechas_iniciales" : fechas_iniciales, "fechas_finales" : fechas_finales}

# %% [markdown]
# Interesa que los intervalos sean de 6 en 6 meses, o lo que es lo mismo, de 180 en 180 días

# %%
diccionario_fechas = listar_fechas_descargas(fecha_max_dt, 180, 3)
diccionario_fechas
# Out:
# {'fechas_iniciales': ['2024-09-20T00:00:00UTC',
#   '2024-03-23T00:00:00UTC',
#   '2023-09-24T00:00:00UTC'],
#  'fechas_finales': ['2025-03-19T00:00:00UTC',
#   '2024-09-19T00:00:00UTC',
#   '2024-03-22T00:00:00UTC']}

# %% [markdown]
# Se comprueba en la siguiente tabla que efectivamente hay 180 días de diferencia entre las fechas iniciales y fechas finales por intervalo

# %%
df_lista_fechas = pd.DataFrame(diccionario_fechas)
df_lista_fechas["fechas_iniciales"] = pd.to_datetime(df_lista_fechas["fechas_iniciales"])
df_lista_fechas["fechas_finales"] = pd.to_datetime(df_lista_fechas["fechas_finales"])
df_lista_fechas["Diferencia en días"] = (df_lista_fechas["fechas_finales"] - df_lista_fechas["fechas_iniciales"]).dt.days
df_lista_fechas
# Out:
#            fechas_iniciales            fechas_finales  Diferencia en días
# 0 2024-09-20 00:00:00+00:00 2025-03-19 00:00:00+00:00                 180
# 1 2024-03-23 00:00:00+00:00 2024-09-19 00:00:00+00:00                 180
# 2 2023-09-24 00:00:00+00:00 2024-03-22 00:00:00+00:00                 180

# %% [markdown]
# Se descargan los datos recursivamente

# %% [markdown]
# 1. Controles de tiempo de descarga de datos

# %%
espera_error_429 = 20
espera_error_except = 30

# %% [markdown]
# 2. Bloque de código para descargar los datos

# %%
n_veces_inicial = 0
lista_datos_historicos = []
max_intentos = 0
max_intentors_error = 0

start_time = time.time()

while True :

    try :
        n_veces_inicial += 1
        fechas_descargas = listar_fechas_descargas(fecha_max_dt, 180, n_veces_inicial)

        fecha_ini = fechas_descargas["fechas_iniciales"][-1]
        fecha_fin = fechas_descargas["fechas_finales"][-1]

        estacion_id = "3195"  # Ejemplo de estación meteorológica de Madrid-Retiro

        url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fecha_ini}/fechafin/{fecha_fin}/estacion/{estacion_id}?api_key={API_KEY}"

        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            datos_url = data.get("datos")
            if datos_url:
                response_data = requests.get(datos_url)
                if response_data.status_code == 200:
                    datos_historicos = response_data.json()
                    lista_datos_historicos.append(datos_historicos)
                    print(f"Se ha descargado los datos de {fecha_ini} a {fecha_fin}")
                else:
                    print("Error al obtener los datos reales", response_data.status_code)
            else:
                print("No se encontró la URL de datos")
                n_veces_inicial -= 1
                max_intentos += 1
        else:
            print("Error en la petición inicial, código de error:", response.status_code)

        if (response.status_code == 200) and datos_url :
            max_intentos = 0
            max_intentors_error = 0
            
        elif response.status_code == 429 :
            time.sleep(espera_error_429)
            n_veces_inicial -= 1
            max_intentos += 1

        elif max_intentos == 3:
            print("Número máximo de intentos alcanzado")
            break
                
        elif response.status_code != 200 :
            break
    
    except (ConnectionError, ProtocolError, RemoteDisconnected) as e:
        print(f"Error de conexión: {e}")
        time.sleep(espera_error_except)
        n_veces_inicial -= 1
        max_intentors_error += 1
        if max_intentors_error == 3:
            print("Número máximo de intentos alcanzado")
            break
        continue

end_time = time.time()
# Out:
# Se ha descargado los datos de 2024-09-20T00:00:00UTC a 2025-03-19T00:00:00UTC
# Se ha descargado los datos de 2024-03-23T00:00:00UTC a 2024-09-19T00:00:00UTC
# Se ha descargado los datos de 2023-09-24T00:00:00UTC a 2024-03-22T00:00:00UTC
# Se ha descargado los datos de 2023-03-27T00:00:00UTC a 2023-09-23T00:00:00UTC
# Se ha descargado los datos de 2022-09-27T00:00:00UTC a 2023-03-26T00:00:00UTC
# Se ha descargado los datos de 2022-03-30T00:00:00UTC a 2022-09-26T00:00:00UTC
# Se ha descargado los datos de 2021-09-30T00:00:00UTC a 2022-03-29T00:00:00UTC
# Se ha descargado los datos de 2021-04-02T00:00:00UTC a 2021-09-29T00:00:00UTC
# Se ha descargado los datos de 2020-10-03T00:00:00UTC a 2021-04-01T00:00:00UTC
# Se ha descargado los datos de 2020-04-05T00:00:00UTC a 2020-10-02T00:00:00UTC
# Se ha descargado los datos de 2019-10-07T00:00:00UTC a 2020-04-04T00:00:00UTC
# Se ha descargado los datos de 2019-04-09T00:00:00UTC a 2019-10-06T00:00:00UTC
# Se ha descargado los datos de 2018-10-10T00:00:00UTC a 2019-04-08T00:00:00UTC
# Se ha descargado los datos de 2018-04-12T00:00:00UTC a 2018-10-09T00:00:00UTC
# Se ha descargado los datos de 2017-10-13T00:00:00UTC a 2018-04-11T00:00:00UTC
# Se ha descargado los datos de 2017-04-15T00:00:00UTC a 2017-10-12T00:00:00UTC
# Se ha descargado los datos de 2016-10-16T00:00:00UTC a 2017-04-14T00:00:00UTC
# Se ha descargado los datos de 2016-04-18T00:00:00UTC a 2016-10-15T00:00:00UTC
# Se ha descargado los datos de 2015-10-20T00:00:00UTC a 2016-04-17T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 2015-04-22T00:00:00UTC a 2015-10-19T00:00:00UTC
# Se ha descargado los datos de 2014-10-23T00:00:00UTC a 2015-04-21T00:00:00UTC
# Se ha descargado los datos de 2014-04-25T00:00:00UTC a 2014-10-22T00:00:00UTC
# Se ha descargado los datos de 2013-10-26T00:00:00UTC a 2014-04-24T00:00:00UTC
# Se ha descargado los datos de 2013-04-28T00:00:00UTC a 2013-10-25T00:00:00UTC
# Se ha descargado los datos de 2012-10-29T00:00:00UTC a 2013-04-27T00:00:00UTC
# Se ha descargado los datos de 2012-05-01T00:00:00UTC a 2012-10-28T00:00:00UTC
# Se ha descargado los datos de 2011-11-02T00:00:00UTC a 2012-04-30T00:00:00UTC
# Se ha descargado los datos de 2011-05-05T00:00:00UTC a 2011-11-01T00:00:00UTC
# Se ha descargado los datos de 2010-11-05T00:00:00UTC a 2011-05-04T00:00:00UTC
# Se ha descargado los datos de 2010-05-08T00:00:00UTC a 2010-11-04T00:00:00UTC
# Se ha descargado los datos de 2009-11-08T00:00:00UTC a 2010-05-07T00:00:00UTC
# Se ha descargado los datos de 2009-05-11T00:00:00UTC a 2009-11-07T00:00:00UTC
# Se ha descargado los datos de 2008-11-11T00:00:00UTC a 2009-05-10T00:00:00UTC
# Se ha descargado los datos de 2008-05-14T00:00:00UTC a 2008-11-10T00:00:00UTC
# Se ha descargado los datos de 2007-11-15T00:00:00UTC a 2008-05-13T00:00:00UTC
# Se ha descargado los datos de 2007-05-18T00:00:00UTC a 2007-11-14T00:00:00UTC
# Se ha descargado los datos de 2006-11-18T00:00:00UTC a 2007-05-17T00:00:00UTC
# Se ha descargado los datos de 2006-05-21T00:00:00UTC a 2006-11-17T00:00:00UTC
# Se ha descargado los datos de 2005-11-21T00:00:00UTC a 2006-05-20T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 2005-05-24T00:00:00UTC a 2005-11-20T00:00:00UTC
# Se ha descargado los datos de 2004-11-24T00:00:00UTC a 2005-05-23T00:00:00UTC
# Se ha descargado los datos de 2004-05-27T00:00:00UTC a 2004-11-23T00:00:00UTC
# Se ha descargado los datos de 2003-11-28T00:00:00UTC a 2004-05-26T00:00:00UTC
# Se ha descargado los datos de 2003-05-31T00:00:00UTC a 2003-11-27T00:00:00UTC
# Se ha descargado los datos de 2002-12-01T00:00:00UTC a 2003-05-30T00:00:00UTC
# Se ha descargado los datos de 2002-06-03T00:00:00UTC a 2002-11-30T00:00:00UTC
# Se ha descargado los datos de 2001-12-04T00:00:00UTC a 2002-06-02T00:00:00UTC
# Se ha descargado los datos de 2001-06-06T00:00:00UTC a 2001-12-03T00:00:00UTC
# Se ha descargado los datos de 2000-12-07T00:00:00UTC a 2001-06-05T00:00:00UTC
# Se ha descargado los datos de 2000-06-09T00:00:00UTC a 2000-12-06T00:00:00UTC
# Se ha descargado los datos de 1999-12-11T00:00:00UTC a 2000-06-08T00:00:00UTC
# Se ha descargado los datos de 1999-06-13T00:00:00UTC a 1999-12-10T00:00:00UTC
# Se ha descargado los datos de 1998-12-14T00:00:00UTC a 1999-06-12T00:00:00UTC
# Se ha descargado los datos de 1998-06-16T00:00:00UTC a 1998-12-13T00:00:00UTC
# Se ha descargado los datos de 1997-12-17T00:00:00UTC a 1998-06-15T00:00:00UTC
# Se ha descargado los datos de 1997-06-19T00:00:00UTC a 1997-12-16T00:00:00UTC
# Se ha descargado los datos de 1996-12-20T00:00:00UTC a 1997-06-18T00:00:00UTC
# Se ha descargado los datos de 1996-06-22T00:00:00UTC a 1996-12-19T00:00:00UTC
# Se ha descargado los datos de 1995-12-24T00:00:00UTC a 1996-06-21T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 1995-06-26T00:00:00UTC a 1995-12-23T00:00:00UTC
# Se ha descargado los datos de 1994-12-27T00:00:00UTC a 1995-06-25T00:00:00UTC
# Se ha descargado los datos de 1994-06-29T00:00:00UTC a 1994-12-26T00:00:00UTC
# Se ha descargado los datos de 1993-12-30T00:00:00UTC a 1994-06-28T00:00:00UTC
# Se ha descargado los datos de 1993-07-02T00:00:00UTC a 1993-12-29T00:00:00UTC
# Se ha descargado los datos de 1993-01-02T00:00:00UTC a 1993-07-01T00:00:00UTC
# Se ha descargado los datos de 1992-07-05T00:00:00UTC a 1993-01-01T00:00:00UTC
# Se ha descargado los datos de 1992-01-06T00:00:00UTC a 1992-07-04T00:00:00UTC
# Se ha descargado los datos de 1991-07-09T00:00:00UTC a 1992-01-05T00:00:00UTC
# Se ha descargado los datos de 1991-01-09T00:00:00UTC a 1991-07-08T00:00:00UTC
# Se ha descargado los datos de 1990-07-12T00:00:00UTC a 1991-01-08T00:00:00UTC
# Se ha descargado los datos de 1990-01-12T00:00:00UTC a 1990-07-11T00:00:00UTC
# Se ha descargado los datos de 1989-07-15T00:00:00UTC a 1990-01-11T00:00:00UTC
# Se ha descargado los datos de 1989-01-15T00:00:00UTC a 1989-07-14T00:00:00UTC
# Se ha descargado los datos de 1988-07-18T00:00:00UTC a 1989-01-14T00:00:00UTC
# Se ha descargado los datos de 1988-01-19T00:00:00UTC a 1988-07-17T00:00:00UTC
# Se ha descargado los datos de 1987-07-22T00:00:00UTC a 1988-01-18T00:00:00UTC
# Se ha descargado los datos de 1987-01-22T00:00:00UTC a 1987-07-21T00:00:00UTC
# Se ha descargado los datos de 1986-07-25T00:00:00UTC a 1987-01-21T00:00:00UTC
# Se ha descargado los datos de 1986-01-25T00:00:00UTC a 1986-07-24T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error de conexión: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Se ha descargado los datos de 1985-07-28T00:00:00UTC a 1986-01-24T00:00:00UTC
# Se ha descargado los datos de 1985-01-28T00:00:00UTC a 1985-07-27T00:00:00UTC
# Se ha descargado los datos de 1984-07-31T00:00:00UTC a 1985-01-27T00:00:00UTC
# Se ha descargado los datos de 1984-02-01T00:00:00UTC a 1984-07-30T00:00:00UTC
# Se ha descargado los datos de 1983-08-04T00:00:00UTC a 1984-01-31T00:00:00UTC
# Se ha descargado los datos de 1983-02-04T00:00:00UTC a 1983-08-03T00:00:00UTC
# Se ha descargado los datos de 1982-08-07T00:00:00UTC a 1983-02-03T00:00:00UTC
# Se ha descargado los datos de 1982-02-07T00:00:00UTC a 1982-08-06T00:00:00UTC
# Se ha descargado los datos de 1981-08-10T00:00:00UTC a 1982-02-06T00:00:00UTC
# Se ha descargado los datos de 1981-02-10T00:00:00UTC a 1981-08-09T00:00:00UTC
# Se ha descargado los datos de 1980-08-13T00:00:00UTC a 1981-02-09T00:00:00UTC
# Se ha descargado los datos de 1980-02-14T00:00:00UTC a 1980-08-12T00:00:00UTC
# Se ha descargado los datos de 1979-08-17T00:00:00UTC a 1980-02-13T00:00:00UTC
# Se ha descargado los datos de 1979-02-17T00:00:00UTC a 1979-08-16T00:00:00UTC
# Se ha descargado los datos de 1978-08-20T00:00:00UTC a 1979-02-16T00:00:00UTC
# Se ha descargado los datos de 1978-02-20T00:00:00UTC a 1978-08-19T00:00:00UTC
# Se ha descargado los datos de 1977-08-23T00:00:00UTC a 1978-02-19T00:00:00UTC
# Se ha descargado los datos de 1977-02-23T00:00:00UTC a 1977-08-22T00:00:00UTC
# Se ha descargado los datos de 1976-08-26T00:00:00UTC a 1977-02-22T00:00:00UTC
# Se ha descargado los datos de 1976-02-27T00:00:00UTC a 1976-08-25T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 1975-08-30T00:00:00UTC a 1976-02-26T00:00:00UTC
# Se ha descargado los datos de 1975-03-02T00:00:00UTC a 1975-08-29T00:00:00UTC
# Se ha descargado los datos de 1974-09-02T00:00:00UTC a 1975-03-01T00:00:00UTC
# Se ha descargado los datos de 1974-03-05T00:00:00UTC a 1974-09-01T00:00:00UTC
# Se ha descargado los datos de 1973-09-05T00:00:00UTC a 1974-03-04T00:00:00UTC
# Se ha descargado los datos de 1973-03-08T00:00:00UTC a 1973-09-04T00:00:00UTC
# Se ha descargado los datos de 1972-09-08T00:00:00UTC a 1973-03-07T00:00:00UTC
# Se ha descargado los datos de 1972-03-11T00:00:00UTC a 1972-09-07T00:00:00UTC
# Se ha descargado los datos de 1971-09-12T00:00:00UTC a 1972-03-10T00:00:00UTC
# Se ha descargado los datos de 1971-03-15T00:00:00UTC a 1971-09-11T00:00:00UTC
# Se ha descargado los datos de 1970-09-15T00:00:00UTC a 1971-03-14T00:00:00UTC
# Se ha descargado los datos de 1970-03-18T00:00:00UTC a 1970-09-14T00:00:00UTC
# Se ha descargado los datos de 1969-09-18T00:00:00UTC a 1970-03-17T00:00:00UTC
# Se ha descargado los datos de 1969-03-21T00:00:00UTC a 1969-09-17T00:00:00UTC
# Se ha descargado los datos de 1968-09-21T00:00:00UTC a 1969-03-20T00:00:00UTC
# Se ha descargado los datos de 1968-03-24T00:00:00UTC a 1968-09-20T00:00:00UTC
# Se ha descargado los datos de 1967-09-25T00:00:00UTC a 1968-03-23T00:00:00UTC
# Se ha descargado los datos de 1967-03-28T00:00:00UTC a 1967-09-24T00:00:00UTC
# Se ha descargado los datos de 1966-09-28T00:00:00UTC a 1967-03-27T00:00:00UTC
# Se ha descargado los datos de 1966-03-31T00:00:00UTC a 1966-09-27T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 1965-10-01T00:00:00UTC a 1966-03-30T00:00:00UTC
# Se ha descargado los datos de 1965-04-03T00:00:00UTC a 1965-09-30T00:00:00UTC
# Se ha descargado los datos de 1964-10-04T00:00:00UTC a 1965-04-02T00:00:00UTC
# Se ha descargado los datos de 1964-04-06T00:00:00UTC a 1964-10-03T00:00:00UTC
# Se ha descargado los datos de 1963-10-08T00:00:00UTC a 1964-04-05T00:00:00UTC
# Se ha descargado los datos de 1963-04-10T00:00:00UTC a 1963-10-07T00:00:00UTC
# Se ha descargado los datos de 1962-10-11T00:00:00UTC a 1963-04-09T00:00:00UTC
# Se ha descargado los datos de 1962-04-13T00:00:00UTC a 1962-10-10T00:00:00UTC
# Se ha descargado los datos de 1961-10-14T00:00:00UTC a 1962-04-12T00:00:00UTC
# Se ha descargado los datos de 1961-04-16T00:00:00UTC a 1961-10-13T00:00:00UTC
# Se ha descargado los datos de 1960-10-17T00:00:00UTC a 1961-04-15T00:00:00UTC
# Se ha descargado los datos de 1960-04-19T00:00:00UTC a 1960-10-16T00:00:00UTC
# Se ha descargado los datos de 1959-10-21T00:00:00UTC a 1960-04-18T00:00:00UTC
# Se ha descargado los datos de 1959-04-23T00:00:00UTC a 1959-10-20T00:00:00UTC
# Se ha descargado los datos de 1958-10-24T00:00:00UTC a 1959-04-22T00:00:00UTC
# Se ha descargado los datos de 1958-04-26T00:00:00UTC a 1958-10-23T00:00:00UTC
# Se ha descargado los datos de 1957-10-27T00:00:00UTC a 1958-04-25T00:00:00UTC
# Se ha descargado los datos de 1957-04-29T00:00:00UTC a 1957-10-26T00:00:00UTC
# Se ha descargado los datos de 1956-10-30T00:00:00UTC a 1957-04-28T00:00:00UTC
# Se ha descargado los datos de 1956-05-02T00:00:00UTC a 1956-10-29T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 1955-11-03T00:00:00UTC a 1956-05-01T00:00:00UTC
# Se ha descargado los datos de 1955-05-06T00:00:00UTC a 1955-11-02T00:00:00UTC
# Se ha descargado los datos de 1954-11-06T00:00:00UTC a 1955-05-05T00:00:00UTC
# Se ha descargado los datos de 1954-05-09T00:00:00UTC a 1954-11-05T00:00:00UTC
# Se ha descargado los datos de 1953-11-09T00:00:00UTC a 1954-05-08T00:00:00UTC
# Se ha descargado los datos de 1953-05-12T00:00:00UTC a 1953-11-08T00:00:00UTC
# Se ha descargado los datos de 1952-11-12T00:00:00UTC a 1953-05-11T00:00:00UTC
# Se ha descargado los datos de 1952-05-15T00:00:00UTC a 1952-11-11T00:00:00UTC
# Se ha descargado los datos de 1951-11-16T00:00:00UTC a 1952-05-14T00:00:00UTC
# Se ha descargado los datos de 1951-05-19T00:00:00UTC a 1951-11-15T00:00:00UTC
# Se ha descargado los datos de 1950-11-19T00:00:00UTC a 1951-05-18T00:00:00UTC
# Se ha descargado los datos de 1950-05-22T00:00:00UTC a 1950-11-18T00:00:00UTC
# Se ha descargado los datos de 1949-11-22T00:00:00UTC a 1950-05-21T00:00:00UTC
# Se ha descargado los datos de 1949-05-25T00:00:00UTC a 1949-11-21T00:00:00UTC
# Se ha descargado los datos de 1948-11-25T00:00:00UTC a 1949-05-24T00:00:00UTC
# Se ha descargado los datos de 1948-05-28T00:00:00UTC a 1948-11-24T00:00:00UTC
# Se ha descargado los datos de 1947-11-29T00:00:00UTC a 1948-05-27T00:00:00UTC
# Se ha descargado los datos de 1947-06-01T00:00:00UTC a 1947-11-28T00:00:00UTC
# Se ha descargado los datos de 1946-12-02T00:00:00UTC a 1947-05-31T00:00:00UTC
# Se ha descargado los datos de 1946-06-04T00:00:00UTC a 1946-12-01T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 1945-12-05T00:00:00UTC a 1946-06-03T00:00:00UTC
# Se ha descargado los datos de 1945-06-07T00:00:00UTC a 1945-12-04T00:00:00UTC
# Se ha descargado los datos de 1944-12-08T00:00:00UTC a 1945-06-06T00:00:00UTC
# Se ha descargado los datos de 1944-06-10T00:00:00UTC a 1944-12-07T00:00:00UTC
# Se ha descargado los datos de 1943-12-12T00:00:00UTC a 1944-06-09T00:00:00UTC
# Se ha descargado los datos de 1943-06-14T00:00:00UTC a 1943-12-11T00:00:00UTC
# Se ha descargado los datos de 1942-12-15T00:00:00UTC a 1943-06-13T00:00:00UTC
# Se ha descargado los datos de 1942-06-17T00:00:00UTC a 1942-12-14T00:00:00UTC
# Se ha descargado los datos de 1941-12-18T00:00:00UTC a 1942-06-16T00:00:00UTC
# Se ha descargado los datos de 1941-06-20T00:00:00UTC a 1941-12-17T00:00:00UTC
# Se ha descargado los datos de 1940-12-21T00:00:00UTC a 1941-06-19T00:00:00UTC
# Se ha descargado los datos de 1940-06-23T00:00:00UTC a 1940-12-20T00:00:00UTC
# Se ha descargado los datos de 1939-12-25T00:00:00UTC a 1940-06-22T00:00:00UTC
# Se ha descargado los datos de 1939-06-27T00:00:00UTC a 1939-12-24T00:00:00UTC
# Se ha descargado los datos de 1938-12-28T00:00:00UTC a 1939-06-26T00:00:00UTC
# Se ha descargado los datos de 1938-06-30T00:00:00UTC a 1938-12-27T00:00:00UTC
# Se ha descargado los datos de 1937-12-31T00:00:00UTC a 1938-06-29T00:00:00UTC
# Se ha descargado los datos de 1937-07-03T00:00:00UTC a 1937-12-30T00:00:00UTC
# Se ha descargado los datos de 1937-01-03T00:00:00UTC a 1937-07-02T00:00:00UTC
# Se ha descargado los datos de 1936-07-06T00:00:00UTC a 1937-01-02T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 1936-01-07T00:00:00UTC a 1936-07-05T00:00:00UTC
# Se ha descargado los datos de 1935-07-10T00:00:00UTC a 1936-01-06T00:00:00UTC
# Se ha descargado los datos de 1935-01-10T00:00:00UTC a 1935-07-09T00:00:00UTC
# Se ha descargado los datos de 1934-07-13T00:00:00UTC a 1935-01-09T00:00:00UTC
# Se ha descargado los datos de 1934-01-13T00:00:00UTC a 1934-07-12T00:00:00UTC
# Se ha descargado los datos de 1933-07-16T00:00:00UTC a 1934-01-12T00:00:00UTC
# Se ha descargado los datos de 1933-01-16T00:00:00UTC a 1933-07-15T00:00:00UTC
# Se ha descargado los datos de 1932-07-19T00:00:00UTC a 1933-01-15T00:00:00UTC
# Se ha descargado los datos de 1932-01-20T00:00:00UTC a 1932-07-18T00:00:00UTC
# Se ha descargado los datos de 1931-07-23T00:00:00UTC a 1932-01-19T00:00:00UTC
# Se ha descargado los datos de 1931-01-23T00:00:00UTC a 1931-07-22T00:00:00UTC
# Se ha descargado los datos de 1930-07-26T00:00:00UTC a 1931-01-22T00:00:00UTC
# Se ha descargado los datos de 1930-01-26T00:00:00UTC a 1930-07-25T00:00:00UTC
# Se ha descargado los datos de 1929-07-29T00:00:00UTC a 1930-01-25T00:00:00UTC
# Se ha descargado los datos de 1929-01-29T00:00:00UTC a 1929-07-28T00:00:00UTC
# Se ha descargado los datos de 1928-08-01T00:00:00UTC a 1929-01-28T00:00:00UTC
# Se ha descargado los datos de 1928-02-02T00:00:00UTC a 1928-07-31T00:00:00UTC
# Se ha descargado los datos de 1927-08-05T00:00:00UTC a 1928-02-01T00:00:00UTC
# Se ha descargado los datos de 1927-02-05T00:00:00UTC a 1927-08-04T00:00:00UTC
# Se ha descargado los datos de 1926-08-08T00:00:00UTC a 1927-02-04T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 1926-02-08T00:00:00UTC a 1926-08-07T00:00:00UTC
# Se ha descargado los datos de 1925-08-11T00:00:00UTC a 1926-02-07T00:00:00UTC
# Se ha descargado los datos de 1925-02-11T00:00:00UTC a 1925-08-10T00:00:00UTC
# Se ha descargado los datos de 1924-08-14T00:00:00UTC a 1925-02-10T00:00:00UTC
# Se ha descargado los datos de 1924-02-15T00:00:00UTC a 1924-08-13T00:00:00UTC
# Se ha descargado los datos de 1923-08-18T00:00:00UTC a 1924-02-14T00:00:00UTC
# Se ha descargado los datos de 1923-02-18T00:00:00UTC a 1923-08-17T00:00:00UTC
# Se ha descargado los datos de 1922-08-21T00:00:00UTC a 1923-02-17T00:00:00UTC
# Se ha descargado los datos de 1922-02-21T00:00:00UTC a 1922-08-20T00:00:00UTC
# Se ha descargado los datos de 1921-08-24T00:00:00UTC a 1922-02-20T00:00:00UTC
# Se ha descargado los datos de 1921-02-24T00:00:00UTC a 1921-08-23T00:00:00UTC
# Se ha descargado los datos de 1920-08-27T00:00:00UTC a 1921-02-23T00:00:00UTC
# Se ha descargado los datos de 1920-02-28T00:00:00UTC a 1920-08-26T00:00:00UTC
# Se ha descargado los datos de 1919-08-31T00:00:00UTC a 1920-02-27T00:00:00UTC
# No se encontró la URL de datos
# No se encontró la URL de datos
# No se encontró la URL de datos
# Número máximo de intentos alcanzado

# %%
execution_time = end_time - start_time
hours = int(execution_time // 3600)
minutes = int((execution_time % 3600) // 60)
seconds = execution_time % 60
print(f"Tiempo de ejecución: {hours}h {minutes}m {seconds:.0f}s")
# Out:
# Tiempo de ejecución: 0h 9m 55s

# %% [markdown]
# 3. Se guardan los datos descargados en un fichero .json

# %%
folder_name = "dataset_historico_id_3195"
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

file_path = os.path.join(folder_name, f"datos_historicos_{fecha_max_descargada[0:10]}_{fecha_ini[0:10]}.json")
with open(file_path, "w") as f:
    for datos_historicos in lista_datos_historicos :
        json.dump(datos_historicos, f, indent=4, ensure_ascii=False)

# %% [markdown]
# 4. Se guarda el tiempo de ejecución de la descarga en un fichero .txt en modo "append"

# %%
file_path_time = os.path.join(folder_name, f"tiempo_ejecucion.txt")
with open(file_path_time, "a", encoding="utf-8") as f:
    f.write(f"Tiempo de ejecución: {hours}h {minutes}m {seconds:.0f}s a fecha de {ahora}\n")

# %% [markdown]
# ## 1.3 Se concluye que la fecha más antigua de los datos descargados es el 01/01/1920

# %%
fecha_ini = "1919-08-31T20:00:00UTC"
fecha_fin = "1920-01-01T20:00:00UTC"
estacion_id = "3195"  # Ejemplo de estación meteorológica de Madrid-Retiro

url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fecha_ini}/fechafin/{fecha_fin}/estacion/{estacion_id}?api_key={API_KEY}"

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=4, ensure_ascii=False))
    datos_url = data.get("datos")
    if datos_url:
        response_data = requests.get(datos_url)
        if response_data.status_code == 200:
            datos_historicos = response_data.json()
            print(json.dumps(datos_historicos, indent=4, ensure_ascii=False))
        else:
            print("Error al obtener los datos reales")
    else:
        print("No se encontró la URL de datos")
else:
    print("Error en la petición inicial, código de error:", response.status_code)
# Out:
# {
#     "descripcion": "exito",
#     "estado": 200,
#     "datos": "https://opendata.aemet.es/opendata/sh/8cd35436",
#     "metadatos": "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# [
#     {
#         "fecha": "1920-01-01",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,4",
#         "prec": "0,0",
#         "tmin": "8,8",
#         "horatmin": "23:59",
#         "tmax": "11,9",
#         "horatmax": "10:30",
#         "sol": "3,5",
#         "presMax": "934,6",
#         "horaPresMax": "00",
#         "presMin": "925,3",
#         "horaPresMin": "15",
#         "hrMedia": "72"
#     }
# ]

# %%
fecha_min_descargada = min([fecha['fecha'] for fecha in datos_historicos])
print(f"La fecha más antigua que da la API es {fecha_min_descargada}")
# Out:
# La fecha más antigua que da la API es 1920-01-01

# %% [markdown]
# # ¿2. Se escribe el código necesario para descargar los datos de la AEMET disponibles en OpenData API de 15 en 15 días sobre todas las estacion meteorológicas?
#
# # ¿2. Unir dataset actual a los EFMA y SINOBAS?
