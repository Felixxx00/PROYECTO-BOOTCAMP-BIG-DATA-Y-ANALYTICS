# %% [markdown]
# # 1. Se escribe el código necesario para descargar los datos de la AEMET disponibles en OpenData API de 6 en 6 meses sobre la estación meteorológica de Madrid - Retiro (id 3195).

# %% [markdown]
# ## 1.1 Primero se obtiene la fecha máxima de descarga, que se sabe que es de 4 días antes al día de hoy

# %%
import os
import requests
import json
from datetime import datetime, timedelta
import pandas as pd
import time
from urllib3.exceptions import ProtocolError
from requests.exceptions import ConnectionError
from http.client import RemoteDisconnected

# %%
with open('API_KEY_AEMET.txt') as f:
    API_KEY = f.readline().strip()

print(f"Mi API Key es: \n\n{API_KEY}")
# Out:
# Mi API Key es:
#
# eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJmZWxpeHRjbDk3QGdtYWlsLmNvbSIsImp0aSI6ImFmYTVjNjEwLTNmNmUtNDNhZS1iYTZiLWI0OTkyOTM2NTY2ZSIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNzQwOTM4NzY4LCJ1c2VySWQiOiJhZmE1YzYxMC0zZjZlLTQzYWUtYmE2Yi1iNDk5MjkzNjU2NmUiLCJyb2xlIjoiIn0.-D_-Zb0rh0kAgHJgGZOM_QCCKaNZhgDuP4wQPo2Bw7E

# %% [markdown]
# Se define la fecha actual en la variable 'ahora' y el día 1 del mes anterior para que haya suficientes días entre la fecha inicial y la fecha máxima del dato devuelto de la API

# %%
ahora = datetime.now()
if ahora.month == 1:
    dia_1_mes_anterior = datetime(ahora.year - 1, 12, 1)
else:
    dia_1_mes_anterior = datetime(ahora.year, ahora.month - 1, 1)

ahora = ahora.strftime("%Y-%m-%dT%H:%M:%SUTC")
dia_1_mes_anterior = dia_1_mes_anterior.strftime("%Y-%m-%dT%H:%M:%SUTC")

print(ahora)
print(dia_1_mes_anterior)
# Out:
# 2025-05-10T14:54:23UTC
# 2025-04-01T00:00:00UTC

# %% [markdown]
# Se descarga el json generado por las fechas definidas en el bloque anterior

# %%
fecha_ini = dia_1_mes_anterior
fecha_fin = ahora
estacion_id = "3195"  # Ejemplo de estación meteorológica de Madrid-Retiro

url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fecha_ini}/fechafin/{fecha_fin}/estacion/{estacion_id}?api_key={API_KEY}"

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=4, ensure_ascii=False))
    datos_url = data.get("datos")
    if datos_url:
        response_data = requests.get(datos_url)
        if response_data.status_code == 200:
            datos_historicos = response_data.json()
            print(json.dumps(datos_historicos, indent=4, ensure_ascii=False))
        else:
            print("Error al obtener los datos reales")
    else:
        print("No se encontró la URL de datos")
else:
    print("Error en la petición inicial, código de error:", response.status_code)
# Out:
# {
#     "descripcion": "exito",
#     "estado": 200,
#     "datos": "https://opendata.aemet.es/opendata/sh/fbcb52de",
#     "metadatos": "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# [
#     {
#         "fecha": "2025-04-01",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "16,9",
#         "prec": "0,0",
#         "tmin": "10,1",
#         "horatmin": "05:20",
#         "tmax": "23,7",
#         "horatmax": "14:00",
#         "dir": "11",
#         "velmedia": "1,9",
#         "racha": "7,2",
#         "horaracha": "15:00",
#         "presMax": "935,4",
#         "horaPresMax": "00",
#         "presMin": "927,2",
#         "horaPresMin": "24",
#         "hrMedia": "42",
#         "hrMax": "71",
#         "horaHrMax": "23:59",
#         "hrMin": "26",
#         "horaHrMin": "14:00"
#     },
#     {
#         "fecha": "2025-04-02",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "14,6",
#         "prec": "21,9",
#         "tmin": "10,3",
#         "horatmin": "06:00",
#         "tmax": "18,8",
#         "horatmax": "15:10",
#         "dir": "14",
#         "velmedia": "2,2",
#         "racha": "8,3",
#         "horaracha": "23:50",
#         "presMax": "931,4",
#         "horaPresMax": "24",
#         "presMin": "925,5",
#         "horaPresMin": "06",
#         "hrMedia": "67",
#         "hrMax": "95",
#         "horaHrMax": "23:50",
#         "hrMin": "48",
#         "horaHrMin": "17:00"
#     },
#     {
#         "fecha": "2025-04-03",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,5",
#         "prec": "20,2",
#         "tmin": "8,3",
#         "horatmin": "07:00",
#         "tmax": "10,7",
#         "horatmax": "00:10",
#         "dir": "15",
#         "velmedia": "2,2",
#         "racha": "7,8",
#         "horaracha": "00:20",
#         "presMax": "935,2",
#         "horaPresMax": "11",
#         "presMin": "930,9",
#         "horaPresMin": "03",
#         "hrMedia": "98"
#     },
#     {
#         "fecha": "2025-04-04",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "12,3",
#         "prec": "12,7",
#         "tmin": "8,4",
#         "horatmin": "23:59",
#         "tmax": "16,2",
#         "horatmax": "11:30",
#         "dir": "99",
#         "velmedia": "2,8",
#         "racha": "12,2",
#         "horaracha": "Varias",
#         "presMax": "934,2",
#         "horaPresMax": "24",
#         "presMin": "930,6",
#         "horaPresMin": "17",
#         "hrMedia": "87",
#         "hrMax": "99",
#         "horaHrMax": "Varias",
#         "hrMin": "58",
#         "horaHrMin": "11:20"
#     },
#     {
#         "fecha": "2025-04-05",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "12,4",
#         "prec": "0,0",
#         "tmin": "8,2",
#         "horatmin": "06:00",
#         "tmax": "16,5",
#         "horatmax": "14:40",
#         "dir": "09",
#         "velmedia": "1,9",
#         "racha": "6,7",
#         "horaracha": "04:20",
#         "presMax": "937,5",
#         "horaPresMax": "10",
#         "presMin": "934,0",
#         "horaPresMin": "00",
#         "hrMedia": "76",
#         "hrMax": "99",
#         "horaHrMax": "00:00",
#         "hrMin": "54",
#         "horaHrMin": "14:20"
#     },
#     {
#         "fecha": "2025-04-06",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "14,0",
#         "prec": "0,0",
#         "tmin": "8,8",
#         "horatmin": "06:00",
#         "tmax": "19,3",
#         "horatmax": "13:30",
#         "dir": "07",
#         "velmedia": "1,7",
#         "racha": "5,3",
#         "horaracha": "16:10",
#         "presMax": "938,3",
#         "horaPresMax": "Varias",
#         "presMin": "936,0",
#         "horaPresMin": "Varias",
#         "hrMedia": "65",
#         "hrMax": "98",
#         "horaHrMax": "05:40",
#         "hrMin": "44",
#         "horaHrMin": "Varias"
#     },
#     {
#         "fecha": "2025-04-07",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "15,8",
#         "prec": "0,0",
#         "tmin": "8,8",
#         "horatmin": "Varias",
#         "tmax": "22,8",
#         "horatmax": "14:20",
#         "dir": "27",
#         "velmedia": "1,1",
#         "racha": "5,3",
#         "horaracha": "14:00",
#         "presMax": "941,9",
#         "horaPresMax": "24",
#         "presMin": "938,2",
#         "horaPresMin": "01",
#         "hrMedia": "56",
#         "hrMax": "94",
#         "horaHrMax": "03:30",
#         "hrMin": "30",
#         "horaHrMin": "14:50"
#     },
#     {
#         "fecha": "2025-04-08",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "18,0",
#         "prec": "0,0",
#         "tmin": "11,0",
#         "horatmin": "05:00",
#         "tmax": "24,9",
#         "horatmax": "14:20",
#         "dir": "12",
#         "velmedia": "1,4",
#         "racha": "6,7",
#         "horaracha": "12:30",
#         "presMax": "943,7",
#         "horaPresMax": "10",
#         "presMin": "940,2",
#         "horaPresMin": "18",
#         "hrMedia": "45",
#         "hrMax": "80",
#         "horaHrMax": "04:10",
#         "hrMin": "28",
#         "horaHrMin": "Varias"
#     },
#     {
#         "fecha": "2025-04-09",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "18,6",
#         "prec": "0,0",
#         "tmin": "12,6",
#         "horatmin": "06:50",
#         "tmax": "24,6",
#         "horatmax": "15:10",
#         "dir": "10",
#         "velmedia": "2,2",
#         "racha": "6,7",
#         "horaracha": "04:00",
#         "presMax": "941,6",
#         "horaPresMax": "01",
#         "presMin": "936,9",
#         "horaPresMin": "18",
#         "hrMedia": "40",
#         "hrMax": "61",
#         "horaHrMax": "04:00",
#         "hrMin": "25",
#         "horaHrMin": "Varias"
#     },
#     {
#         "fecha": "2025-04-10",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "18,2",
#         "prec": "0,0",
#         "tmin": "13,0",
#         "horatmin": "05:20",
#         "tmax": "23,5",
#         "horatmax": "13:40",
#         "dir": "32",
#         "velmedia": "3,6",
#         "racha": "10,6",
#         "horaracha": "17:00",
#         "presMax": "941,0",
#         "horaPresMax": "24",
#         "presMin": "937,2",
#         "horaPresMin": "16",
#         "hrMedia": "49",
#         "hrMax": "68",
#         "horaHrMax": "05:10",
#         "hrMin": "34",
#         "horaHrMin": "11:40"
#     },
#     {
#         "fecha": "2025-04-11",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "13,2",
#         "prec": "11,3",
#         "tmin": "10,7",
#         "horatmin": "11:10",
#         "tmax": "15,7",
#         "horatmax": "15:30",
#         "dir": "05",
#         "velmedia": "2,5",
#         "racha": "8,1",
#         "horaracha": "15:30",
#         "presMax": "940,7",
#         "horaPresMax": "00",
#         "presMin": "933,6",
#         "horaPresMin": "17",
#         "hrMedia": "75",
#         "hrMax": "96",
#         "horaHrMax": "23:59",
#         "hrMin": "62",
#         "horaHrMin": "02:40"
#     },
#     {
#         "fecha": "2025-04-12",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "13,8",
#         "prec": "4,5",
#         "tmin": "10,8",
#         "horatmin": "04:30",
#         "tmax": "16,7",
#         "horatmax": "12:20",
#         "dir": "04",
#         "velmedia": "1,7",
#         "racha": "6,4",
#         "horaracha": "17:00",
#         "presMax": "935,0",
#         "horaPresMax": "00",
#         "presMin": "931,5",
#         "horaPresMin": "16",
#         "hrMedia": "85",
#         "hrMax": "98",
#         "horaHrMax": "02:00",
#         "hrMin": "75",
#         "horaHrMin": "12:00"
#     },
#     {
#         "fecha": "2025-04-13",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "14,8",
#         "prec": "3,6",
#         "tmin": "11,7",
#         "horatmin": "05:50",
#         "tmax": "17,9",
#         "horatmax": "12:30",
#         "dir": "03",
#         "velmedia": "1,1",
#         "racha": "5,3",
#         "horaracha": "11:10",
#         "presMax": "933,6",
#         "horaPresMax": "Varias",
#         "presMin": "931,1",
#         "horaPresMin": "Varias",
#         "hrMedia": "85",
#         "hrMax": "99",
#         "horaHrMax": "Varias",
#         "hrMin": "67",
#         "horaHrMin": "13:10"
#     },
#     {
#         "fecha": "2025-04-14",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "13,3",
#         "prec": "4,9",
#         "tmin": "9,7",
#         "horatmin": "21:10",
#         "tmax": "16,9",
#         "horatmax": "14:00",
#         "dir": "04",
#         "velmedia": "3,6",
#         "racha": "11,7",
#         "horaracha": "13:00",
#         "presMax": "931,8",
#         "horaPresMax": "00",
#         "presMin": "926,8",
#         "horaPresMin": "24",
#         "hrMedia": "67"
#     },
#     {
#         "fecha": "2025-04-15",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,8",
#         "prec": "0,0",
#         "tmin": "6,2",
#         "horatmin": "Varias",
#         "tmax": "11,5",
#         "horatmax": "11:40",
#         "dir": "21",
#         "velmedia": "1,7",
#         "racha": "11,4",
#         "horaracha": "19:10",
#         "presMax": "932,6",
#         "horaPresMax": "24",
#         "presMin": "926,2",
#         "horaPresMin": "03",
#         "hrMedia": "71",
#         "hrMax": "98",
#         "horaHrMax": "04:00",
#         "hrMin": "51",
#         "horaHrMin": "18:10"
#     },
#     {
#         "fecha": "2025-04-16",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,0",
#         "prec": "2,8",
#         "tmin": "5,2",
#         "horatmin": "04:00",
#         "tmax": "12,9",
#         "horatmax": "13:00",
#         "dir": "12",
#         "velmedia": "3,1",
#         "racha": "10,3",
#         "horaracha": "13:50",
#         "presMax": "937,2",
#         "horaPresMax": "23",
#         "presMin": "932,4",
#         "horaPresMin": "00",
#         "hrMedia": "67",
#         "hrMax": "99",
#         "horaHrMax": "Varias",
#         "hrMin": "45",
#         "horaHrMin": "10:50"
#     },
#     {
#         "fecha": "2025-04-17",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "12,8",
#         "prec": "0,0",
#         "tmin": "6,2",
#         "horatmin": "Varias",
#         "tmax": "19,3",
#         "horatmax": "15:30",
#         "dir": "14",
#         "velmedia": "3,1",
#         "racha": "9,7",
#         "horaracha": "07:50",
#         "presMax": "939,2",
#         "horaPresMax": "23",
#         "presMin": "936,7",
#         "horaPresMin": "02",
#         "hrMedia": "53",
#         "hrMax": "99",
#         "horaHrMax": "00:00",
#         "hrMin": "34",
#         "horaHrMin": "12:40"
#     },
#     {
#         "fecha": "2025-04-18",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "14,2",
#         "prec": "12,7",
#         "tmin": "9,4",
#         "horatmin": "05:40",
#         "tmax": "18,9",
#         "horatmax": "14:00",
#         "dir": "12",
#         "velmedia": "2,8",
#         "racha": "15,8",
#         "horaracha": "17:30",
#         "presMax": "939,0",
#         "horaPresMax": "00",
#         "presMin": "929,7",
#         "horaPresMin": "24",
#         "hrMedia": "84",
#         "hrMax": "98",
#         "horaHrMax": "19:40",
#         "hrMin": "54",
#         "horaHrMin": "14:00"
#     },
#     {
#         "fecha": "2025-04-19",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,5",
#         "prec": "4,8",
#         "tmin": "5,8",
#         "horatmin": "06:00",
#         "tmax": "13,2",
#         "horatmax": "14:00",
#         "dir": "06",
#         "velmedia": "3,9",
#         "racha": "13,3",
#         "horaracha": "16:00",
#         "presMax": "930,4",
#         "horaPresMax": "Varias",
#         "presMin": "927,0",
#         "horaPresMin": "04",
#         "hrMedia": "70",
#         "hrMax": "98",
#         "horaHrMax": "05:00",
#         "hrMin": "47",
#         "horaHrMin": "11:20"
#     },
#     {
#         "fecha": "2025-04-20",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "11,2",
#         "prec": "0,0",
#         "tmin": "6,2",
#         "horatmin": "Varias",
#         "tmax": "16,2",
#         "horatmax": "14:20",
#         "dir": "05",
#         "velmedia": "2,2",
#         "racha": "10,0",
#         "horaracha": "00:10",
#         "presMax": "937,1",
#         "horaPresMax": "24",
#         "presMin": "929,2",
#         "horaPresMin": "04",
#         "hrMedia": "63",
#         "hrMax": "96",
#         "horaHrMax": "Varias",
#         "hrMin": "39",
#         "horaHrMin": "14:30"
#     },
#     {
#         "fecha": "2025-04-21",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "13,2",
#         "prec": "0,9",
#         "tmin": "7,5",
#         "horatmin": "05:50",
#         "tmax": "19,0",
#         "horatmax": "14:40",
#         "dir": "14",
#         "velmedia": "1,9",
#         "racha": "7,5",
#         "horaracha": "00:10",
#         "presMax": "939,8",
#         "horaPresMax": "22",
#         "presMin": "937,0",
#         "horaPresMin": "00",
#         "hrMedia": "60",
#         "hrMax": "94",
#         "horaHrMax": "23:50",
#         "hrMin": "41",
#         "horaHrMin": "12:10"
#     },
#     {
#         "fecha": "2025-04-22",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "14,8",
#         "prec": "0,0",
#         "tmin": "10,6",
#         "horatmin": "05:00",
#         "tmax": "18,9",
#         "horatmax": "16:20",
#         "dir": "16",
#         "velmedia": "1,7",
#         "racha": "8,1",
#         "horaracha": "19:40",
#         "presMax": "944,5",
#         "horaPresMax": "24",
#         "presMin": "938,7",
#         "horaPresMin": "04",
#         "hrMedia": "63",
#         "hrMax": "98",
#         "horaHrMax": "04:50",
#         "hrMin": "41",
#         "horaHrMin": "14:20"
#     },
#     {
#         "fecha": "2025-04-23",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "15,5",
#         "prec": "0,0",
#         "tmin": "8,6",
#         "horatmin": "06:00",
#         "tmax": "22,4",
#         "horatmax": "16:40",
#         "dir": "26",
#         "velmedia": "1,1",
#         "racha": "5,6",
#         "horaracha": "14:10",
#         "presMax": "945,7",
#         "horaPresMax": "09",
#         "presMin": "942,0",
#         "horaPresMin": "17",
#         "hrMedia": "52",
#         "hrMax": "84",
#         "horaHrMax": "Varias",
#         "hrMin": "34",
#         "horaHrMin": "14:40"
#     },
#     {
#         "fecha": "2025-04-24",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "19,2",
#         "prec": "0,0",
#         "tmin": "12,1",
#         "horatmin": "04:00",
#         "tmax": "26,2",
#         "horatmax": "13:40",
#         "dir": "29",
#         "velmedia": "1,7",
#         "racha": "5,8",
#         "horaracha": "04:50",
#         "presMax": "943,5",
#         "horaPresMax": "00",
#         "presMin": "938,3",
#         "horaPresMin": "18",
#         "hrMedia": "45",
#         "hrMax": "84",
#         "horaHrMax": "03:50",
#         "hrMin": "25",
#         "horaHrMin": "14:50"
#     },
#     {
#         "fecha": "2025-04-25",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "20,0",
#         "prec": "0,0",
#         "tmin": "13,2",
#         "horatmin": "05:30",
#         "tmax": "26,8",
#         "horatmax": "14:00",
#         "dir": "09",
#         "velmedia": "3,1",
#         "racha": "11,9",
#         "horaracha": "23:10",
#         "presMax": "938,9",
#         "horaPresMax": "00",
#         "presMin": "935,0",
#         "horaPresMin": "16",
#         "hrMedia": "49",
#         "hrMax": "78",
#         "horaHrMax": "03:10",
#         "hrMin": "27",
#         "horaHrMin": "14:40"
#     },
#     {
#         "fecha": "2025-04-26",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "16,7",
#         "prec": "0,0",
#         "tmin": "11,8",
#         "horatmin": "05:20",
#         "tmax": "21,6",
#         "horatmax": "13:40",
#         "dir": "04",
#         "velmedia": "1,4",
#         "racha": "7,8",
#         "horaracha": "21:50",
#         "presMax": "943,9",
#         "horaPresMax": "23",
#         "presMin": "937,2",
#         "horaPresMin": "02",
#         "hrMedia": "48",
#         "hrMax": "78",
#         "horaHrMax": "05:00",
#         "hrMin": "31",
#         "horaHrMin": "18:00"
#     },
#     {
#         "fecha": "2025-04-27",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "15,2",
#         "prec": "0,0",
#         "tmin": "9,0",
#         "horatmin": "05:40",
#         "tmax": "21,4",
#         "horatmax": "14:40",
#         "dir": "06",
#         "velmedia": "1,9",
#         "racha": "7,5",
#         "horaracha": "11:50",
#         "presMax": "944,6",
#         "horaPresMax": "09",
#         "presMin": "941,8",
#         "horaPresMin": "18",
#         "hrMedia": "47",
#         "hrMax": "71",
#         "horaHrMax": "Varias",
#         "hrMin": "34",
#         "horaHrMin": "14:50"
#     },
#     {
#         "fecha": "2025-04-28",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "17,1",
#         "prec": "0,0",
#         "tmin": "10,7",
#         "horatmin": "06:00",
#         "tmax": "23,5",
#         "horatmax": "14:00",
#         "dir": "26",
#         "velmedia": "2,8",
#         "racha": "11,7",
#         "horaracha": "23:00",
#         "presMax": "943,4",
#         "horaPresMax": "00",
#         "presMin": "938,9",
#         "horaPresMin": "18",
#         "hrMedia": "45",
#         "hrMax": "73",
#         "horaHrMax": "05:40",
#         "hrMin": "28",
#         "horaHrMin": "14:20"
#     },
#     {
#         "fecha": "2025-04-29",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "17,0",
#         "prec": "0,0",
#         "tmin": "11,8",
#         "horatmin": "06:00",
#         "tmax": "22,3",
#         "horatmax": "15:20",
#         "dir": "35",
#         "velmedia": "3,3",
#         "racha": "11,1",
#         "horaracha": "14:10",
#         "presMax": "940,9",
#         "horaPresMax": "00",
#         "presMin": "936,0",
#         "horaPresMin": "16",
#         "hrMedia": "52",
#         "hrMax": "69",
#         "horaHrMax": "06:40",
#         "hrMin": "38",
#         "horaHrMin": "14:10"
#     },
#     {
#         "fecha": "2025-04-30",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "16,0",
#         "prec": "5,3",
#         "tmin": "11,4",
#         "horatmin": "05:50",
#         "tmax": "20,5",
#         "horatmax": "16:10",
#         "dir": "30",
#         "velmedia": "3,3",
#         "racha": "12,8",
#         "horaracha": "20:30",
#         "presMax": "939,0",
#         "horaPresMax": "08",
#         "presMin": "933,6",
#         "horaPresMin": "17",
#         "hrMedia": "60",
#         "hrMax": "99",
#         "horaHrMax": "23:20",
#         "hrMin": "49",
#         "horaHrMin": "16:00"
#     },
#     {
#         "fecha": "2025-05-01",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "16,7",
#         "prec": "22,7",
#         "tmin": "11,7",
#         "horatmin": "00:50",
#         "tmax": "21,7",
#         "horatmax": "16:50",
#         "dir": "05",
#         "velmedia": "1,4",
#         "racha": "6,4",
#         "horaracha": "23:59",
#         "presMax": "938,8",
#         "horaPresMax": "01",
#         "presMin": "934,2",
#         "horaPresMin": "19",
#         "hrMedia": "71"
#     },
#     {
#         "fecha": "2025-05-02",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "15,0",
#         "prec": "13,6",
#         "tmin": "10,5",
#         "horatmin": "07:10",
#         "tmax": "19,5",
#         "horatmax": "14:20",
#         "dir": "09",
#         "velmedia": "2,8",
#         "racha": "11,9",
#         "horaracha": "06:20",
#         "presMax": "937,5",
#         "horaPresMax": "09",
#         "presMin": "932,7",
#         "horaPresMin": "05",
#         "hrMedia": "80"
#     },
#     {
#         "fecha": "2025-05-03",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "15,8",
#         "prec": "0,9",
#         "tmin": "11,2",
#         "horatmin": "03:20",
#         "tmax": "20,4",
#         "horatmax": "14:40",
#         "dir": "04",
#         "velmedia": "1,7",
#         "racha": "12,2",
#         "horaracha": "19:40",
#         "presMax": "938,2",
#         "horaPresMax": "Varias",
#         "presMin": "935,4",
#         "horaPresMin": "17",
#         "hrMedia": "65",
#         "hrMax": "97",
#         "horaHrMax": "03:30",
#         "hrMin": "41",
#         "horaHrMin": "16:10"
#     },
#     {
#         "fecha": "2025-05-04",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "14,0",
#         "prec": "2,8",
#         "tmin": "11,5",
#         "horatmin": "08:30",
#         "tmax": "16,6",
#         "horatmax": "12:30",
#         "dir": "07",
#         "velmedia": "2,8",
#         "racha": "10,8",
#         "horaracha": "15:40",
#         "presMax": "936,7",
#         "horaPresMax": "00",
#         "presMin": "933,3",
#         "horaPresMin": "18",
#         "hrMedia": "82",
#         "hrMax": "98",
#         "horaHrMax": "08:20",
#         "hrMin": "59",
#         "horaHrMin": "15:40"
#     },
#     {
#         "fecha": "2025-05-05",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "13,8",
#         "prec": "19,4",
#         "tmin": "10,3",
#         "horatmin": "03:50",
#         "tmax": "17,2",
#         "horatmax": "10:10",
#         "dir": "22",
#         "velmedia": "1,4",
#         "racha": "7,8",
#         "horaracha": "22:00",
#         "presMax": "936,1",
#         "horaPresMax": "24",
#         "presMin": "932,5",
#         "horaPresMin": "15",
#         "hrMedia": "89",
#         "hrMax": "99",
#         "horaHrMax": "04:40",
#         "hrMin": "65",
#         "horaHrMin": "10:10"
#     },
#     {
#         "fecha": "2025-05-06",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "12,8",
#         "prec": "0,0",
#         "tmin": "8,3",
#         "horatmin": "05:40",
#         "tmax": "17,3",
#         "horatmax": "15:20",
#         "dir": "33",
#         "velmedia": "1,9",
#         "racha": "8,9",
#         "horaracha": "23:00",
#         "presMax": "937,2",
#         "horaPresMax": "09",
#         "presMin": "934,7",
#         "horaPresMin": "16",
#         "hrMedia": "52",
#         "hrMax": "80",
#         "horaHrMax": "00:00",
#         "hrMin": "38",
#         "horaHrMin": "16:30"
#     }
# ]

# %% [markdown]
# Se obtiene la fecha maxima descargada. A día 22/03/2025 es el 18/03/2025

# %%
fechas = [fecha['fecha'] for fecha in datos_historicos]
fecha_max_descargada = max(fechas)
print(fecha_max_descargada)
# Out:
# 2025-05-06

# %% [markdown]
# Se imprime la diferencia en días entre hoy y la fecha máxima descargada

# %%
# Convert fecha_max_descargada to datetime
fecha_max = datetime.strptime(fecha_max_descargada, '%Y-%m-%d')

# Convert ahora to datetime
ahora_dt = datetime.strptime(ahora, '%Y-%m-%dT%H:%M:%SUTC')

# Calculate difference in days
diferencia_dias = (ahora_dt - fecha_max).days

print(f"Diferencia en días: {diferencia_dias}")
# Out:
# Diferencia en días: 4

# %% [markdown]
# ## 1.2 Se descargan todos los datos de 6 en 6 meses, ya que esta API no permite un rango de fechas superior a 6 meses.

# %% [markdown]
# Se definen las fechas a descargar con la siguiente función

# %%
# Se formatea la fecha para que coincida con el formato de la API
fecha_max_descargada = fecha_max.strftime("%Y-%m-%dT%H:%M:%SUTC")

# Se convierte la fecha a datetime para poder restarle los dias que se quiera
fecha_max_dt = datetime.strptime(fecha_max_descargada, "%Y-%m-%dT%H:%M:%SUTC")

# %% [markdown]
# Se define la siguiente funcion que devuelve los intervalos de fechas a ejecutar en la API

# %%
def listar_fechas_descargas(fecha_max: datetime, dias: int, n_veces: int) -> {list, list}:
    """
    Función que devuelve 1 diccionario que contiene 2 listas de fechas empezando por 
    una fecha dada y retrocediendo un número de días dado n_veces.

    La primera lista almacena la fecha inicial de descarga y la segunda lista
    almacena la fecha final de descarga.

    Las fechas devueltas están en el formato correcto para la API de AEMET.
    """
    fechas_iniciales = []
    for i in range(n_veces):

        if i == 0 :
            fecha_inicial = fecha_max - timedelta(days=dias*(i+1))
        else:
            fecha_inicial = fecha_max - timedelta(days=dias*(i+1)+i) 
            # Se resta 1 días más para que la fecha inicial no coincida con la fecha final del siguiente periodo.

        fecha_inicial = fecha_inicial.strftime("%Y-%m-%dT%H:%M:%SUTC")
        fechas_iniciales.append(fecha_inicial)

    fechas_finales = []
    for i in range(n_veces):

        if i == 0:
            fecha_final = fecha_max - timedelta(days=dias*(i)) # En la primera iteración no resta nada porque interesa almacenar la fecha máxima.
        else:
            fecha_final = fecha_max - timedelta(days=dias*(i)+i)
            # Se resta i días más para que la fecha final no coincida con la fecha inicial del periodo anterior.

        fecha_final = fecha_final.strftime("%Y-%m-%dT%H:%M:%SUTC")
        fechas_finales.append(fecha_final)

    return {"fechas_iniciales" : fechas_iniciales, "fechas_finales" : fechas_finales}

# %% [markdown]
# Interesa que los intervalos sean de 6 en 6 meses, o lo que es lo mismo, de 180 en 180 días

# %%
diccionario_fechas = listar_fechas_descargas(fecha_max_dt, 180, 3)
diccionario_fechas
# Out:
# {'fechas_iniciales': ['2024-11-07T00:00:00UTC',
#   '2024-05-10T00:00:00UTC',
#   '2023-11-11T00:00:00UTC'],
#  'fechas_finales': ['2025-05-06T00:00:00UTC',
#   '2024-11-06T00:00:00UTC',
#   '2024-05-09T00:00:00UTC']}

# %% [markdown]
# Se comprueba en la siguiente tabla que efectivamente hay 180 días de diferencia entre las fechas iniciales y fechas finales por intervalo

# %%
df_lista_fechas = pd.DataFrame(diccionario_fechas)
df_lista_fechas["fechas_iniciales"] = pd.to_datetime(df_lista_fechas["fechas_iniciales"])
df_lista_fechas["fechas_finales"] = pd.to_datetime(df_lista_fechas["fechas_finales"])
df_lista_fechas["Diferencia en días"] = (df_lista_fechas["fechas_finales"] - df_lista_fechas["fechas_iniciales"]).dt.days
df_lista_fechas
# Out:
#            fechas_iniciales            fechas_finales  Diferencia en días
# 0 2024-11-07 00:00:00+00:00 2025-05-06 00:00:00+00:00                 180
# 1 2024-05-10 00:00:00+00:00 2024-11-06 00:00:00+00:00                 180
# 2 2023-11-11 00:00:00+00:00 2024-05-09 00:00:00+00:00                 180

# %% [markdown]
# Se descargan los datos recursivamente

# %% [markdown]
# 1. Controles de tiempo de descarga de datos

# %%
espera_error_429 = 20
espera_error_except = 30

# %% [markdown]
# 2. Bloque de código para descargar los datos

# %%
n_veces_inicial = 0
lista_datos_historicos = []
max_intentos = 0
max_intentors_error = 0

start_time = time.time()

while True :

    try :
        n_veces_inicial += 1
        fechas_descargas = listar_fechas_descargas(fecha_max_dt, 180, n_veces_inicial)

        # La variable n_veces_inicial se usa para obtener la última fecha de descarga recursivamente.

        fecha_ini = fechas_descargas["fechas_iniciales"][-1]
        fecha_fin = fechas_descargas["fechas_finales"][-1]

        estacion_id = "3195"  # Ejemplo de estación meteorológica de Madrid-Retiro

        url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fecha_ini}/fechafin/{fecha_fin}/estacion/{estacion_id}?api_key={API_KEY}"

        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            datos_url = data.get("datos")
            if datos_url:
                response_data = requests.get(datos_url)
                if response_data.status_code == 200:
                    datos_historicos = response_data.json()
                    lista_datos_historicos.append(datos_historicos)
                    print(f"Se ha descargado los datos de {fecha_ini} a {fecha_fin}")
                else:
                    print("Error al obtener los datos reales", response_data.status_code)
                    n_veces_inicial -= 1 # Se resta 1 para volver a la fecha anterior del ciclo.
            else:
                print("No se encontró la URL de datos")
                n_veces_inicial -= 1 # Se resta 1 para volver a la fecha anterior del ciclo.
                max_intentos += 1
        else:
            print("Error en la petición inicial, código de error:", response.status_code)

        if (response.status_code == 200) and datos_url :
            max_intentos = 0
            max_intentors_error = 0
            
        elif response.status_code == 429 :
            time.sleep(espera_error_429)
            n_veces_inicial -= 1 # Se resta 1 para volver a la fecha anterior del ciclo.
            max_intentos += 1

        elif max_intentos == 3:
            print("Número máximo de intentos alcanzado")
            break
                
        elif response.status_code != 200 :
            break
    
    except (ConnectionError, ProtocolError, RemoteDisconnected) as e:
        print(f"Error de conexión: {e}")
        time.sleep(espera_error_except)
        n_veces_inicial -= 1 # Se resta 1 para volver a la fecha anterior del ciclo.
        max_intentors_error += 1
        if max_intentors_error == 3:
            print("Número máximo de intentos alcanzado")
            break
        continue

end_time = time.time()
# Out:
# Se ha descargado los datos de 1925-03-31T00:00:00UTC a 1925-09-27T00:00:00UTC
# Se ha descargado los datos de 1924-10-01T00:00:00UTC a 1925-03-30T00:00:00UTC
# Se ha descargado los datos de 1924-04-03T00:00:00UTC a 1924-09-30T00:00:00UTC
# Se ha descargado los datos de 1923-10-05T00:00:00UTC a 1924-04-02T00:00:00UTC
# Se ha descargado los datos de 1923-04-07T00:00:00UTC a 1923-10-04T00:00:00UTC
# Se ha descargado los datos de 1922-10-08T00:00:00UTC a 1923-04-06T00:00:00UTC
# Se ha descargado los datos de 1922-04-10T00:00:00UTC a 1922-10-07T00:00:00UTC
# Se ha descargado los datos de 1921-10-11T00:00:00UTC a 1922-04-09T00:00:00UTC
# Se ha descargado los datos de 1921-04-13T00:00:00UTC a 1921-10-10T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Error de conexión: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Se ha descargado los datos de 1920-10-14T00:00:00UTC a 1921-04-12T00:00:00UTC
# Se ha descargado los datos de 1920-04-16T00:00:00UTC a 1920-10-13T00:00:00UTC
# Se ha descargado los datos de 1919-10-18T00:00:00UTC a 1920-04-15T00:00:00UTC
# No se encontró la URL de datos
# No se encontró la URL de datos
# No se encontró la URL de datos
# Número máximo de intentos alcanzado

# %%
execution_time = end_time - start_time
hours = int(execution_time // 3600)
minutes = int((execution_time % 3600) // 60)
seconds = execution_time % 60
print(f"Tiempo de ejecución: {hours}h {minutes}m {seconds:.0f}s")
# Out:
# Tiempo de ejecución: 0h 11m 9s

# %% [markdown]
# 3. Se guardan los datos descargados en un fichero .json

# %%
folder_name = "dataset_historico_id_3195"
os.makedirs(folder_name, exist_ok=True)

file_path = os.path.join(folder_name, f"datos_historicos_{fecha_max_descargada[:10]}.jsonl")

with open(file_path, "w", encoding="utf-8") as f:
    for sublista in lista_datos_historicos:  # Iterar sobre cada sublista
        for item in sublista:  # Iterar sobre cada diccionario en la sublista
            f.write(json.dumps(item, ensure_ascii=False) + "\n")  # 1 línea por JSON

# %% [markdown]
# 4. Se guarda el tiempo de ejecución de la descarga en un fichero .txt en modo "append"

# %%
file_path_time = os.path.join(folder_name, f"tiempo_ejecucion.txt")
with open(file_path_time, "a", encoding="utf-8") as f:
    f.write(f"Tiempo de ejecución: {hours}h {minutes}m {seconds:.0f}s a fecha de {ahora}\n")

# %% [markdown]
# # 2. Se investiga la fecha más antigua descargada

# %%
fecha_ini = "1919-09-15T00:00:00UTC"
fecha_fin = "1920-03-13T00:00:00UTC"
estacion_id = "3195"  # Ejemplo de estación meteorológica de Madrid-Retiro

url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fecha_ini}/fechafin/{fecha_fin}/estacion/{estacion_id}?api_key={API_KEY}"

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=4, ensure_ascii=False))
    datos_url = data.get("datos")
    if datos_url:
        response_data = requests.get(datos_url)
        if response_data.status_code == 200:
            datos_historicos = response_data.json()
            print(json.dumps(datos_historicos, indent=4, ensure_ascii=False))
        else:
            print("Error al obtener los datos reales")
    else:
        print("No se encontró la URL de datos")
else:
    print("Error en la petición inicial, código de error:", response.status_code)
# Out:
# {
#     "descripcion": "exito",
#     "estado": 200,
#     "datos": "https://opendata.aemet.es/opendata/sh/48ac66f1",
#     "metadatos": "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# [
#     {
#         "fecha": "1920-01-01",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,4",
#         "prec": "0,0",
#         "tmin": "8,8",
#         "horatmin": "23:59",
#         "tmax": "11,9",
#         "horatmax": "10:30",
#         "sol": "3,5",
#         "presMax": "934,6",
#         "horaPresMax": "00",
#         "presMin": "925,3",
#         "horaPresMin": "15",
#         "hrMedia": "72"
#     },
#     {
#         "fecha": "1920-01-02",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,8",
#         "prec": "0,0",
#         "tmin": "2,6",
#         "horatmin": "06:30",
#         "tmax": "11,0",
#         "horatmax": "12:30",
#         "sol": "7,4",
#         "presMax": "940,3",
#         "horaPresMax": "11",
#         "presMin": "931,9",
#         "horaPresMin": "00",
#         "hrMedia": "63"
#     },
#     {
#         "fecha": "1920-01-03",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,5",
#         "prec": "1,4",
#         "tmin": "2,4",
#         "horatmin": "23:30",
#         "tmax": "8,6",
#         "horatmax": "09:30",
#         "sol": "3,3",
#         "presMax": "937,3",
#         "horaPresMax": "00",
#         "presMin": "923,7",
#         "horaPresMin": "24",
#         "hrMedia": "77"
#     },
#     {
#         "fecha": "1920-01-04",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,6",
#         "prec": "0,0",
#         "tmin": "2,5",
#         "horatmin": "22:00",
#         "tmax": "6,8",
#         "horatmax": "13:30",
#         "sol": "3,3",
#         "presMax": "929,0",
#         "horaPresMax": "24",
#         "presMin": "922,7",
#         "horaPresMin": "04",
#         "hrMedia": "72"
#     },
#     {
#         "fecha": "1920-01-05",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,1",
#         "prec": "0,0",
#         "tmin": "1,6",
#         "horatmin": "08:00",
#         "tmax": "6,6",
#         "horatmax": "00:00",
#         "sol": "5,3",
#         "presMax": "933,8",
#         "horaPresMax": "23",
#         "presMin": "928,7",
#         "horaPresMin": "00",
#         "hrMedia": "69"
#     },
#     {
#         "fecha": "1920-01-06",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "2,2",
#         "prec": "0,0",
#         "tmin": "-1,5",
#         "horatmin": "06:30",
#         "tmax": "5,8",
#         "horatmax": "16:00",
#         "sol": "7,2",
#         "presMax": "935,0",
#         "horaPresMax": "23",
#         "presMin": "929,8",
#         "horaPresMin": "14",
#         "hrMedia": "78"
#     },
#     {
#         "fecha": "1920-01-07",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "3,8",
#         "prec": "0,0",
#         "tmin": "0,8",
#         "horatmin": "08:00",
#         "tmax": "6,9",
#         "horatmax": "15:00",
#         "sol": "0,7",
#         "presMax": "943,3",
#         "horaPresMax": "24",
#         "presMin": "934,9",
#         "horaPresMin": "01",
#         "hrMedia": "72"
#     },
#     {
#         "fecha": "1920-01-08",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "2,3",
#         "prec": "0,0",
#         "tmin": "-1,6",
#         "horatmin": "08:00",
#         "tmax": "6,2",
#         "horatmax": "16:00",
#         "sol": "1,2",
#         "presMax": "948,6",
#         "horaPresMax": "23",
#         "presMin": "943,3",
#         "horaPresMin": "00",
#         "hrMedia": "81"
#     },
#     {
#         "fecha": "1920-01-09",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,5",
#         "prec": "0,0",
#         "tmin": "-1,2",
#         "horatmin": "04:15",
#         "tmax": "12,2",
#         "horatmax": "14:00",
#         "sol": "7,7",
#         "presMax": "950,3",
#         "horaPresMax": "24",
#         "presMin": "947,7",
#         "horaPresMin": "01",
#         "hrMedia": "77"
#     },
#     {
#         "fecha": "1920-01-10",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,3",
#         "prec": "0,0",
#         "tmin": "0,9",
#         "horatmin": "06:30",
#         "tmax": "9,7",
#         "horatmax": "00:00",
#         "sol": "0,0",
#         "presMax": "951,0",
#         "horaPresMax": "11",
#         "presMin": "948,2",
#         "horaPresMin": "01",
#         "hrMedia": "100"
#     },
#     {
#         "fecha": "1920-01-11",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,9",
#         "prec": "0,0",
#         "tmin": "4,2",
#         "horatmin": "07:00",
#         "tmax": "9,6",
#         "horatmax": "13:30",
#         "sol": "1,3",
#         "presMax": "953,8",
#         "horaPresMax": "24",
#         "presMin": "950,6",
#         "horaPresMin": "03"
#     },
#     {
#         "fecha": "1920-01-12",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,0",
#         "prec": "0,2",
#         "tmin": "3,6",
#         "horatmin": "08:00",
#         "tmax": "6,5",
#         "horatmax": "15:00",
#         "sol": "0,0",
#         "presMax": "957,2",
#         "horaPresMax": "21",
#         "presMin": "953,8",
#         "horaPresMin": "00",
#         "hrMedia": "99"
#     },
#     {
#         "fecha": "1920-01-13",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,5",
#         "prec": "0,0",
#         "tmin": "2,8",
#         "horatmin": "Varias",
#         "tmax": "10,2",
#         "horatmax": "14:00",
#         "sol": "5,0",
#         "presMax": "955,9",
#         "horaPresMax": "00",
#         "presMin": "951,9",
#         "horaPresMin": "16",
#         "hrMedia": "94"
#     },
#     {
#         "fecha": "1920-01-14",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,3",
#         "prec": "0,0",
#         "tmin": "0,1",
#         "horatmin": "08:00",
#         "tmax": "12,5",
#         "horatmax": "15:10",
#         "sol": "7,3",
#         "presMax": "953,3",
#         "horaPresMax": "10",
#         "presMin": "951,7",
#         "horaPresMin": "16",
#         "hrMedia": "86"
#     },
#     {
#         "fecha": "1920-01-15",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,2",
#         "prec": "0,0",
#         "tmin": "1,4",
#         "horatmin": "06:00",
#         "tmax": "12,9",
#         "horatmax": "15:00",
#         "sol": "8,4",
#         "presMax": "956,1",
#         "horaPresMax": "24",
#         "presMin": "952,9",
#         "horaPresMin": "01",
#         "hrMedia": "86"
#     },
#     {
#         "fecha": "1920-01-16",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,4",
#         "prec": "0,0",
#         "tmin": "3,4",
#         "horatmin": "08:00",
#         "tmax": "13,4",
#         "horatmax": "15:55",
#         "sol": "8,5",
#         "presMax": "959,7",
#         "horaPresMax": "24",
#         "presMin": "955,9",
#         "horaPresMin": "00",
#         "hrMedia": "81"
#     },
#     {
#         "fecha": "1920-01-17",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,6",
#         "prec": "0,0",
#         "tmin": "3,0",
#         "horatmin": "05:30",
#         "tmax": "14,3",
#         "horatmax": "15:00",
#         "sol": "8,4",
#         "presMax": "959,7",
#         "horaPresMax": "00",
#         "presMin": "955,9",
#         "horaPresMin": "24",
#         "hrMedia": "72"
#     },
#     {
#         "fecha": "1920-01-18",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,0",
#         "prec": "0,0",
#         "tmin": "0,3",
#         "horatmin": "07:45",
#         "tmax": "11,8",
#         "horatmax": "15:00",
#         "sol": "8,3",
#         "presMax": "955,9",
#         "horaPresMax": "00",
#         "presMin": "948,1",
#         "horaPresMin": "24",
#         "hrMedia": "80"
#     },
#     {
#         "fecha": "1920-01-19",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,7",
#         "prec": "0,0",
#         "tmin": "-0,1",
#         "horatmin": "07:00",
#         "tmax": "9,5",
#         "horatmax": "16:00",
#         "sol": "8,4",
#         "presMax": "951,9",
#         "horaPresMax": "24",
#         "presMin": "947,1",
#         "horaPresMin": "05"
#     },
#     {
#         "fecha": "1920-01-20",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,6",
#         "prec": "0,0",
#         "tmin": "-0,7",
#         "horatmin": "06:50",
#         "tmax": "9,8",
#         "horatmax": "16:00",
#         "sol": "8,3",
#         "presMax": "955,1",
#         "horaPresMax": "10",
#         "presMin": "952,1",
#         "horaPresMin": "00",
#         "hrMedia": "65"
#     },
#     {
#         "fecha": "1920-01-21",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,0",
#         "prec": "0,0",
#         "tmin": "1,7",
#         "horatmin": "08:00",
#         "tmax": "12,4",
#         "horatmax": "17:00",
#         "sol": "7,8",
#         "presMax": "953,5",
#         "horaPresMax": "00",
#         "presMin": "949,5",
#         "horaPresMin": "17",
#         "hrMedia": "76"
#     },
#     {
#         "fecha": "1920-01-22",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,9",
#         "prec": "0,0",
#         "tmin": "3,2",
#         "horatmin": "08:15",
#         "tmax": "14,6",
#         "horatmax": "16:30",
#         "sol": "8,4",
#         "presMax": "950,6",
#         "horaPresMax": "00",
#         "presMin": "947,4",
#         "horaPresMin": "24",
#         "hrMedia": "70"
#     },
#     {
#         "fecha": "1920-01-23",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,2",
#         "prec": "0,0",
#         "tmin": "2,1",
#         "horatmin": "08:00",
#         "tmax": "12,4",
#         "horatmax": "15:00",
#         "sol": "7,6",
#         "presMax": "947,9",
#         "horaPresMax": "11",
#         "presMin": "945,3",
#         "horaPresMin": "24",
#         "hrMedia": "62"
#     },
#     {
#         "fecha": "1920-01-24",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,6",
#         "prec": "0,0",
#         "tmin": "3,5",
#         "horatmin": "08:00",
#         "tmax": "11,6",
#         "horatmax": "15:00",
#         "sol": "4,4",
#         "presMax": "946,5",
#         "horaPresMax": "11",
#         "presMin": "944,2",
#         "horaPresMin": "15",
#         "hrMedia": "77"
#     },
#     {
#         "fecha": "1920-01-25",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,0",
#         "prec": "0,0",
#         "tmin": "3,7",
#         "horatmin": "06:30",
#         "tmax": "12,4",
#         "horatmax": "16:00",
#         "sol": "7,4",
#         "presMax": "946,6",
#         "horaPresMax": "11",
#         "presMin": "942,9",
#         "horaPresMin": "16",
#         "hrMedia": "75"
#     },
#     {
#         "fecha": "1920-01-26",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,8",
#         "prec": "0,8",
#         "tmin": "4,4",
#         "horatmin": "07:30",
#         "tmax": "9,3",
#         "horatmax": "14:45",
#         "sol": "0,0",
#         "presMax": "945,8",
#         "horaPresMax": "24",
#         "presMin": "944,5",
#         "horaPresMin": "00",
#         "hrMedia": "92"
#     },
#     {
#         "fecha": "1920-01-27",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,9",
#         "prec": "0,0",
#         "tmin": "6,0",
#         "horatmin": "Varias",
#         "tmax": "11,8",
#         "horatmax": "15:50",
#         "sol": "1,8",
#         "presMax": "946,6",
#         "horaPresMax": "11",
#         "presMin": "944,3",
#         "horaPresMin": "24",
#         "hrMedia": "95"
#     },
#     {
#         "fecha": "1920-01-28",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,8",
#         "prec": "0,4",
#         "tmin": "4,4",
#         "horatmin": "06:50",
#         "tmax": "11,2",
#         "horatmax": "15:30",
#         "sol": "1,0",
#         "presMax": "944,6",
#         "horaPresMax": "00",
#         "presMin": "940,1",
#         "horaPresMin": "14",
#         "hrMedia": "86"
#     },
#     {
#         "fecha": "1920-01-29",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,6",
#         "prec": "0,0",
#         "tmin": "3,5",
#         "horatmin": "23:59",
#         "tmax": "9,7",
#         "horatmax": "15:30",
#         "sol": "5,7",
#         "presMax": "952,5",
#         "horaPresMax": "24",
#         "presMin": "942,6",
#         "horaPresMin": "00",
#         "hrMedia": "69"
#     },
#     {
#         "fecha": "1920-01-30",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "3,6",
#         "prec": "0,0",
#         "tmin": "0,4",
#         "horatmin": "03:55",
#         "tmax": "6,8",
#         "horatmax": "17:00",
#         "sol": "0,0",
#         "presMax": "956,3",
#         "horaPresMax": "24",
#         "presMin": "952,2",
#         "horaPresMin": "02",
#         "hrMedia": "91"
#     },
#     {
#         "fecha": "1920-01-31",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,6",
#         "prec": "0,0",
#         "tmin": "0,5",
#         "horatmin": "05:00",
#         "tmax": "10,8",
#         "horatmax": "16:00",
#         "sol": "8,7",
#         "presMax": "957,0",
#         "horaPresMax": "24",
#         "presMin": "955,1",
#         "horaPresMin": "17",
#         "hrMedia": "86"
#     },
#     {
#         "fecha": "1920-02-01",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,6",
#         "prec": "0,0",
#         "tmin": "2,5",
#         "horatmin": "07:15",
#         "tmax": "14,8",
#         "horatmax": "15:30",
#         "sol": "9,0",
#         "presMax": "959,3",
#         "horaPresMax": "11",
#         "presMin": "956,9",
#         "horaPresMin": "00",
#         "hrMedia": "73"
#     },
#     {
#         "fecha": "1920-02-02",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,6",
#         "prec": "0,0",
#         "tmin": "4,6",
#         "horatmin": "08:00",
#         "tmax": "14,7",
#         "horatmax": "15:00",
#         "sol": "9,0",
#         "presMax": "960,6",
#         "horaPresMax": "10",
#         "presMin": "958,2",
#         "horaPresMin": "16",
#         "hrMedia": "76"
#     },
#     {
#         "fecha": "1920-02-03",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,4",
#         "prec": "0,0",
#         "tmin": "1,2",
#         "horatmin": "06:30",
#         "tmax": "13,7",
#         "horatmax": "16:00",
#         "sol": "9,1",
#         "presMax": "958,6",
#         "horaPresMax": "00",
#         "presMin": "954,2",
#         "horaPresMin": "24",
#         "hrMedia": "81"
#     },
#     {
#         "fecha": "1920-02-04",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,0",
#         "prec": "0,0",
#         "tmin": "1,0",
#         "horatmin": "07:15",
#         "tmax": "13,1",
#         "horatmax": "15:30",
#         "sol": "9,1",
#         "presMax": "954,6",
#         "horaPresMax": "24",
#         "presMin": "952,1",
#         "horaPresMin": "06",
#         "hrMedia": "59"
#     },
#     {
#         "fecha": "1920-02-05",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,1",
#         "prec": "0,0",
#         "tmin": "-0,6",
#         "horatmin": "07:30",
#         "tmax": "10,8",
#         "horatmax": "16:00",
#         "sol": "9,3",
#         "presMax": "954,6",
#         "horaPresMax": "00",
#         "presMin": "949,5",
#         "horaPresMin": "17",
#         "hrMedia": "74"
#     },
#     {
#         "fecha": "1920-02-06",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,9",
#         "prec": "0,0",
#         "tmin": "0,2",
#         "horatmin": "07:45",
#         "tmax": "9,6",
#         "horatmax": "16:00",
#         "sol": "9,2",
#         "presMax": "951,1",
#         "horaPresMax": "12",
#         "presMin": "948,6",
#         "horaPresMin": "16",
#         "hrMedia": "69"
#     },
#     {
#         "fecha": "1920-02-07",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,5",
#         "prec": "0,0",
#         "tmin": "-0,3",
#         "horatmin": "07:45",
#         "tmax": "9,3",
#         "horatmax": "15:00",
#         "sol": "8,1",
#         "presMax": "953,9",
#         "horaPresMax": "24",
#         "presMin": "949,7",
#         "horaPresMin": "15",
#         "hrMedia": "79"
#     },
#     {
#         "fecha": "1920-02-08",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "3,8",
#         "prec": "0,0",
#         "tmin": "-0,7",
#         "horatmin": "07:30",
#         "tmax": "8,2",
#         "horatmax": "15:30",
#         "sol": "9,3",
#         "presMax": "957,7",
#         "horaPresMax": "24",
#         "presMin": "953,9",
#         "horaPresMin": "00",
#         "hrMedia": "77"
#     },
#     {
#         "fecha": "1920-02-09",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,0",
#         "prec": "0,0",
#         "tmin": "-1,6",
#         "horatmin": "06:45",
#         "tmax": "9,7",
#         "horatmax": "15:00",
#         "sol": "9,3",
#         "presMax": "959,0",
#         "horaPresMax": "11",
#         "presMin": "956,1",
#         "horaPresMin": "18",
#         "hrMedia": "59"
#     },
#     {
#         "fecha": "1920-02-10",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,9",
#         "prec": "0,0",
#         "tmin": "-1,4",
#         "horatmin": "07:15",
#         "tmax": "11,2",
#         "horatmax": "16:00",
#         "sol": "9,5",
#         "presMax": "957,9",
#         "horaPresMax": "11",
#         "presMin": "954,3",
#         "horaPresMin": "18",
#         "hrMedia": "38"
#     },
#     {
#         "fecha": "1920-02-11",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,4",
#         "prec": "0,0",
#         "tmin": "-2,9",
#         "horatmin": "07:15",
#         "tmax": "11,6",
#         "horatmax": "16:00",
#         "sol": "9,6",
#         "presMax": "955,9",
#         "horaPresMax": "00",
#         "presMin": "951,8",
#         "horaPresMin": "17",
#         "hrMedia": "56"
#     },
#     {
#         "fecha": "1920-02-12",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,4",
#         "prec": "0,0",
#         "tmin": "-1,3",
#         "horatmin": "07:15",
#         "tmax": "14,2",
#         "horatmax": "15:00",
#         "sol": "9,6",
#         "presMax": "953,3",
#         "horaPresMax": "11",
#         "presMin": "947,8",
#         "horaPresMin": "24",
#         "hrMedia": "58"
#     },
#     {
#         "fecha": "1920-02-13",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,4",
#         "prec": "0,0",
#         "tmin": "2,1",
#         "horatmin": "07:15",
#         "tmax": "12,8",
#         "horatmax": "14:30",
#         "sol": "0,0",
#         "presMax": "947,8",
#         "horaPresMax": "00",
#         "presMin": "943,5",
#         "horaPresMin": "24",
#         "hrMedia": "69"
#     },
#     {
#         "fecha": "1920-02-14",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,2",
#         "prec": "0,0",
#         "tmin": "4,6",
#         "horatmin": "06:15",
#         "tmax": "13,8",
#         "horatmax": "14:00",
#         "sol": "7,5",
#         "presMax": "943,9",
#         "horaPresMax": "14",
#         "presMin": "939,5",
#         "horaPresMin": "17",
#         "hrMedia": "68"
#     },
#     {
#         "fecha": "1920-02-15",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,2",
#         "prec": "Ip",
#         "tmin": "4,6",
#         "horatmin": "07:15",
#         "tmax": "9,8",
#         "horatmax": "16:00",
#         "sol": "1,6",
#         "presMax": "940,7",
#         "horaPresMax": "00",
#         "presMin": "939,7",
#         "horaPresMin": "16",
#         "hrMedia": "80"
#     },
#     {
#         "fecha": "1920-02-16",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,8",
#         "prec": "1,5",
#         "tmin": "5,9",
#         "horatmin": "06:55",
#         "tmax": "11,8",
#         "horatmax": "15:00",
#         "sol": "0,0",
#         "presMax": "940,2",
#         "horaPresMax": "00",
#         "presMin": "934,3",
#         "horaPresMin": "24",
#         "hrMedia": "79"
#     },
#     {
#         "fecha": "1920-02-17",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,0",
#         "prec": "2,5",
#         "tmin": "6,4",
#         "horatmin": "06:00",
#         "tmax": "11,5",
#         "horatmax": "16:00",
#         "sol": "1,3",
#         "presMax": "935,3",
#         "horaPresMax": "00",
#         "presMin": "927,9",
#         "horaPresMin": "18",
#         "hrMedia": "74"
#     },
#     {
#         "fecha": "1920-02-18",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "11,4",
#         "prec": "24,5",
#         "tmin": "8,7",
#         "horatmin": "18:45",
#         "tmax": "14,0",
#         "horatmax": "12:00",
#         "sol": "0,5",
#         "presMax": "931,7",
#         "horaPresMax": "22",
#         "presMin": "927,3",
#         "horaPresMin": "15",
#         "hrMedia": "79"
#     },
#     {
#         "fecha": "1920-02-19",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,2",
#         "prec": "26,2",
#         "tmin": "7,2",
#         "horatmin": "23:00",
#         "tmax": "11,1",
#         "horatmax": "12:00",
#         "sol": "0,0",
#         "presMax": "931,1",
#         "horaPresMax": "00",
#         "presMin": "924,3",
#         "horaPresMin": "14"
#     },
#     {
#         "fecha": "1920-02-20",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,0",
#         "prec": "14,4",
#         "tmin": "4,8",
#         "horatmin": "06:45",
#         "tmax": "7,3",
#         "horatmax": "17:00",
#         "sol": "0,0",
#         "presMax": "928,7",
#         "horaPresMax": "24",
#         "presMin": "923,9",
#         "horaPresMin": "06",
#         "hrMedia": "100"
#     },
#     {
#         "fecha": "1920-02-21",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,2",
#         "prec": "0,1",
#         "tmin": "4,7",
#         "horatmin": "06:00",
#         "tmax": "11,7",
#         "horatmax": "14:30",
#         "sol": "1,9",
#         "presMax": "940,2",
#         "horaPresMax": "24",
#         "presMin": "928,7",
#         "horaPresMin": "00",
#         "hrMedia": "89"
#     },
#     {
#         "fecha": "1920-02-22",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,8",
#         "prec": "0,0",
#         "tmin": "5,4",
#         "horatmin": "07:00",
#         "tmax": "12,3",
#         "horatmax": "16:00",
#         "sol": "8,4",
#         "presMax": "943,8",
#         "horaPresMax": "24",
#         "presMin": "940,2",
#         "horaPresMin": "00",
#         "hrMedia": "77"
#     },
#     {
#         "fecha": "1920-02-23",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,2",
#         "prec": "0,0",
#         "tmin": "4,6",
#         "horatmin": "06:00",
#         "tmax": "11,7",
#         "horatmax": "16:00",
#         "sol": "2,0",
#         "presMax": "945,7",
#         "horaPresMax": "10",
#         "presMin": "942,7",
#         "horaPresMin": "18",
#         "hrMedia": "79"
#     },
#     {
#         "fecha": "1920-02-24",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,6",
#         "prec": "7,7",
#         "tmin": "5,6",
#         "horatmin": "02:30",
#         "tmax": "9,5",
#         "horatmax": "14:00",
#         "sol": "0,0",
#         "presMax": "943,5",
#         "horaPresMax": "00",
#         "presMin": "941,0",
#         "horaPresMin": "17",
#         "hrMedia": "81"
#     },
#     {
#         "fecha": "1920-02-25",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,4",
#         "prec": "1,9",
#         "tmin": "7,0",
#         "horatmin": "07:00",
#         "tmax": "9,7",
#         "horatmax": "16:00",
#         "sol": "0,0",
#         "presMax": "942,2",
#         "horaPresMax": "24",
#         "presMin": "941,3",
#         "horaPresMin": "16",
#         "hrMedia": "98"
#     },
#     {
#         "fecha": "1920-02-26",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,2",
#         "prec": "6,0",
#         "tmin": "7,9",
#         "horatmin": "07:15",
#         "tmax": "12,5",
#         "horatmax": "15:00",
#         "sol": "0,0",
#         "presMax": "944,3",
#         "horaPresMax": "24",
#         "presMin": "941,9",
#         "horaPresMin": "15",
#         "hrMedia": "91"
#     },
#     {
#         "fecha": "1920-02-27",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "11,3",
#         "prec": "1,8",
#         "tmin": "8,4",
#         "horatmin": "07:15",
#         "tmax": "14,2",
#         "horatmax": "15:00",
#         "sol": "1,3",
#         "presMax": "945,8",
#         "horaPresMax": "20",
#         "presMin": "942,7",
#         "horaPresMin": "15",
#         "hrMedia": "88"
#     },
#     {
#         "fecha": "1920-02-28",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "11,8",
#         "prec": "2,8",
#         "tmin": "9,7",
#         "horatmin": "03:00",
#         "tmax": "13,8",
#         "horatmax": "12:00",
#         "sol": "1,0",
#         "presMax": "945,8",
#         "horaPresMax": "10",
#         "presMin": "942,6",
#         "horaPresMin": "16",
#         "hrMedia": "80"
#     },
#     {
#         "fecha": "1920-02-29",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "12,3",
#         "prec": "0,0",
#         "tmin": "8,8",
#         "horatmin": "23:59",
#         "tmax": "15,8",
#         "horatmax": "15:00",
#         "sol": "6,3",
#         "presMax": "946,6",
#         "horaPresMax": "24",
#         "presMin": "943,7",
#         "horaPresMin": "16",
#         "hrMedia": "80"
#     },
#     {
#         "fecha": "1920-03-01",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,4",
#         "prec": "0,5",
#         "tmin": "4,2",
#         "horatmin": "06:00",
#         "tmax": "10,6",
#         "horatmax": "13:00",
#         "sol": "1,3",
#         "presMax": "947,3",
#         "horaPresMax": "10",
#         "presMin": "944,5",
#         "horaPresMin": "16"
#     },
#     {
#         "fecha": "1920-03-02",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,1",
#         "prec": "3,9",
#         "tmin": "7,8",
#         "horatmin": "05:00",
#         "tmax": "12,4",
#         "horatmax": "12:55",
#         "sol": "0,0",
#         "presMax": "947,9",
#         "horaPresMax": "00",
#         "presMin": "944,4",
#         "horaPresMin": "Varias",
#         "hrMedia": "88"
#     },
#     {
#         "fecha": "1920-03-03",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,6",
#         "prec": "3,1",
#         "tmin": "6,2",
#         "horatmin": "08:40",
#         "tmax": "14,9",
#         "horatmax": "15:00",
#         "sol": "5,4",
#         "presMax": "951,9",
#         "horaPresMax": "09",
#         "presMin": "947,4",
#         "horaPresMin": "00",
#         "hrMedia": "72"
#     },
#     {
#         "fecha": "1920-03-04",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "11,8",
#         "prec": "0,0",
#         "tmin": "6,4",
#         "horatmin": "06:30",
#         "tmax": "17,2",
#         "horatmax": "16:00",
#         "sol": "9,2",
#         "presMax": "951,7",
#         "horaPresMax": "10",
#         "presMin": "945,7",
#         "horaPresMin": "19",
#         "hrMedia": "67"
#     },
#     {
#         "fecha": "1920-03-05",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "11,3",
#         "prec": "0,0",
#         "tmin": "6,5",
#         "horatmin": "06:40",
#         "tmax": "16,1",
#         "horatmax": "12:00",
#         "sol": "4,7",
#         "presMax": "946,9",
#         "horaPresMax": "00",
#         "presMin": "943,3",
#         "horaPresMin": "24",
#         "hrMedia": "81"
#     },
#     {
#         "fecha": "1920-03-06",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "13,6",
#         "prec": "0,0",
#         "tmin": "9,8",
#         "horatmin": "23:59",
#         "tmax": "17,4",
#         "horatmax": "13:00",
#         "sol": "1,5",
#         "presMax": "943,3",
#         "horaPresMax": "00",
#         "presMin": "931,1",
#         "horaPresMin": "24"
#     },
#     {
#         "fecha": "1920-03-07",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,6",
#         "prec": "8,2",
#         "tmin": "3,8",
#         "horatmin": "23:59",
#         "tmax": "7,5",
#         "horatmax": "13:00",
#         "sol": "2,5",
#         "presMax": "934,3",
#         "horaPresMax": "19",
#         "presMin": "929,7",
#         "horaPresMin": "05"
#     },
#     {
#         "fecha": "1920-03-08",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "3,1",
#         "prec": "0,6",
#         "tmin": "-0,5",
#         "horatmin": "04:00",
#         "tmax": "6,7",
#         "horatmax": "14:00",
#         "sol": "4,9",
#         "presMax": "945,9",
#         "horaPresMax": "24",
#         "presMin": "933,7",
#         "horaPresMin": "00",
#         "hrMedia": "69"
#     },
#     {
#         "fecha": "1920-03-09",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "1,8",
#         "prec": "Ip",
#         "tmin": "-0,7",
#         "horatmin": "06:00",
#         "tmax": "4,4",
#         "horatmax": "12:00",
#         "sol": "8,2",
#         "presMax": "951,7",
#         "horaPresMax": "23",
#         "presMin": "945,7",
#         "horaPresMin": "03",
#         "hrMedia": "46"
#     },
#     {
#         "fecha": "1920-03-10",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "3,5",
#         "prec": "0,0",
#         "tmin": "-0,6",
#         "horatmin": "03:00",
#         "tmax": "7,6",
#         "horatmax": "16:00",
#         "sol": "6,7",
#         "presMax": "951,5",
#         "horaPresMax": "00",
#         "presMin": "949,1",
#         "horaPresMin": "14",
#         "hrMedia": "55"
#     },
#     {
#         "fecha": "1920-03-11",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,4",
#         "prec": "0,0",
#         "tmin": "-1,8",
#         "horatmin": "05:00",
#         "tmax": "12,7",
#         "horatmax": "16:30",
#         "sol": "10,0",
#         "presMax": "951,2",
#         "horaPresMax": "09",
#         "presMin": "948,6",
#         "horaPresMin": "16",
#         "hrMedia": "57"
#     },
#     {
#         "fecha": "1920-03-12",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,5",
#         "prec": "0,0",
#         "tmin": "5,9",
#         "horatmin": "00:15",
#         "tmax": "15,1",
#         "horatmax": "13:00",
#         "sol": "5,7",
#         "presMax": "949,5",
#         "horaPresMax": "10",
#         "presMin": "947,3",
#         "horaPresMin": "24"
#     },
#     {
#         "fecha": "1920-03-13",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,0",
#         "prec": "Ip",
#         "tmin": "7,2",
#         "horatmin": "08:00",
#         "tmax": "12,9",
#         "horatmax": "16:00",
#         "sol": "1,7",
#         "presMax": "947,3",
#         "horaPresMax": "00",
#         "presMin": "941,9",
#         "horaPresMin": "16",
#         "hrMedia": "80"
#     }
# ]

# %%
fecha_min = min([dato["fecha"] for dato in datos_historicos]) 
# A pesar de ser texto, es yyyy-mm-dd y se puede obtener el minimo directamente

print(f"La fecha más antigua descargada es: {fecha_min}")
# Out:
# La fecha más antigua descargada es: 1920-01-01

# %% [markdown]
# # 3. ¿Cuanto lloverá de media los próximos 30 días?
#
# [3. AEMET Preprocesamiento dataset y AutoARIMA.ipynb](3.%20AEMET%20Preprocesamiento%20dataset%20y%20AutoARIMA.ipynb)
