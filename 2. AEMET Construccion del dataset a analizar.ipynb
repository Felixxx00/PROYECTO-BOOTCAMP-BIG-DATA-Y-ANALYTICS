# %% [markdown]
# # 1. Se escribe el código necesario para descargar los datos de la AEMET disponibles en OpenData API de 6 en 6 meses sobre la estación meteorológica de Madrid - Retiro (id 3195).

# %% [markdown]
# ## 1.1 Primero se obtiene la fecha máxima de descarga, que se sabe que es de 4 días antes al día de hoy

# %%
import os
import requests
import json
from datetime import datetime, timedelta
import pandas as pd
import time
from urllib3.exceptions import ProtocolError
from requests.exceptions import ConnectionError
from http.client import RemoteDisconnected

# %%
with open('API_KEY_AEMET.txt') as f:
    API_KEY = f.readline().strip()

print(f"Mi API Key es: \n\n{API_KEY}")
# Out:
# Mi API Key es:
#
# eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJmZWxpeHRjbDk3QGdtYWlsLmNvbSIsImp0aSI6ImFmYTVjNjEwLTNmNmUtNDNhZS1iYTZiLWI0OTkyOTM2NTY2ZSIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNzQwOTM4NzY4LCJ1c2VySWQiOiJhZmE1YzYxMC0zZjZlLTQzYWUtYmE2Yi1iNDk5MjkzNjU2NmUiLCJyb2xlIjoiIn0.-D_-Zb0rh0kAgHJgGZOM_QCCKaNZhgDuP4wQPo2Bw7E

# %% [markdown]
# Se define la fecha actual en la variable 'ahora' y el día 1 del mes anterior para que haya suficientes días entre la fecha inicial y la fecha máxima del dato devuelto de la API

# %%
ahora = datetime.now()
if ahora.month == 1:
    dia_1_mes_anterior = datetime(ahora.year - 1, 12, 1)
else:
    dia_1_mes_anterior = datetime(ahora.year, ahora.month - 1, 1)

ahora = ahora.strftime("%Y-%m-%dT%H:%M:%SUTC")
dia_1_mes_anterior = dia_1_mes_anterior.strftime("%Y-%m-%dT%H:%M:%SUTC")

print(ahora)
print(dia_1_mes_anterior)
# Out:
# 2025-04-06T17:26:24UTC
# 2025-03-01T00:00:00UTC

# %% [markdown]
# Se descarga el json generado por las fechas definidas en el bloque anterior

# %%
fecha_ini = dia_1_mes_anterior
fecha_fin = ahora
estacion_id = "3195"  # Ejemplo de estación meteorológica de Madrid-Retiro

url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fecha_ini}/fechafin/{fecha_fin}/estacion/{estacion_id}?api_key={API_KEY}"

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=4, ensure_ascii=False))
    datos_url = data.get("datos")
    if datos_url:
        response_data = requests.get(datos_url)
        if response_data.status_code == 200:
            datos_historicos = response_data.json()
            print(json.dumps(datos_historicos, indent=4, ensure_ascii=False))
        else:
            print("Error al obtener los datos reales")
    else:
        print("No se encontró la URL de datos")
else:
    print("Error en la petición inicial, código de error:", response.status_code)
# Out:
# {
#     "descripcion": "exito",
#     "estado": 200,
#     "datos": "https://opendata.aemet.es/opendata/sh/9938bc8f",
#     "metadatos": "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# [
#     {
#         "fecha": "2025-03-01",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,4",
#         "prec": "12,0",
#         "tmin": "4,0",
#         "horatmin": "23:59",
#         "tmax": "10,8",
#         "horatmax": "00:10",
#         "dir": "99",
#         "velmedia": "3,3",
#         "racha": "9,2",
#         "horaracha": "Varias",
#         "presMax": "940,7",
#         "horaPresMax": "23",
#         "presMin": "936,0",
#         "horaPresMin": "04",
#         "hrMedia": "94",
#         "hrMax": "98",
#         "horaHrMax": "Varias",
#         "hrMin": "64",
#         "horaHrMin": "00:00"
#     },
#     {
#         "fecha": "2025-03-02",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "3,7",
#         "prec": "17,6",
#         "tmin": "2,5",
#         "horatmin": "08:00",
#         "tmax": "4,9",
#         "horatmax": "Varias",
#         "dir": "05",
#         "velmedia": "4,2",
#         "racha": "11,1",
#         "horaracha": "00:30",
#         "presMax": "941,5",
#         "horaPresMax": "09",
#         "presMin": "939,6",
#         "horaPresMin": "18",
#         "hrMedia": "96",
#         "hrMax": "99",
#         "horaHrMax": "Varias",
#         "hrMin": "89",
#         "horaHrMin": "03:20"
#     },
#     {
#         "fecha": "2025-03-03",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,6",
#         "prec": "14,3",
#         "tmin": "4,9",
#         "horatmin": "00:30",
#         "tmax": "10,4",
#         "horatmax": "13:50",
#         "dir": "05",
#         "velmedia": "3,3",
#         "racha": "7,8",
#         "horaracha": "07:50",
#         "presMax": "939,9",
#         "horaPresMax": "00",
#         "presMin": "936,3",
#         "horaPresMin": "17",
#         "hrMedia": "92",
#         "hrMax": "99",
#         "horaHrMax": "23:59",
#         "hrMin": "85",
#         "horaHrMin": "12:20"
#     },
#     {
#         "fecha": "2025-03-04",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,8",
#         "prec": "2,1",
#         "tmin": "7,5",
#         "horatmin": "06:30",
#         "tmax": "14,0",
#         "horatmax": "14:00",
#         "dir": "04",
#         "velmedia": "1,9",
#         "racha": "7,2",
#         "horaracha": "10:10",
#         "presMax": "939,6",
#         "horaPresMax": "22",
#         "presMin": "936,8",
#         "horaPresMin": "05",
#         "hrMedia": "84"
#     },
#     {
#         "fecha": "2025-03-05",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,8",
#         "prec": "4,4",
#         "tmin": "8,5",
#         "horatmin": "06:00",
#         "tmax": "13,0",
#         "horatmax": "13:50",
#         "dir": "06",
#         "velmedia": "2,8",
#         "racha": "8,1",
#         "horaracha": "08:20",
#         "presMax": "939,3",
#         "horaPresMax": "Varias",
#         "presMin": "936,7",
#         "horaPresMin": "Varias",
#         "hrMedia": "88",
#         "hrMax": "96",
#         "horaHrMax": "Varias",
#         "hrMin": "77",
#         "horaHrMin": "16:30"
#     },
#     {
#         "fecha": "2025-03-06",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,8",
#         "prec": "16,1",
#         "tmin": "8,5",
#         "horatmin": "04:00",
#         "tmax": "13,2",
#         "horatmax": "13:20",
#         "dir": "19",
#         "velmedia": "2,2",
#         "racha": "8,9",
#         "horaracha": "12:10",
#         "presMax": "937,2",
#         "horaPresMax": "23",
#         "presMin": "934,5",
#         "horaPresMin": "06",
#         "hrMedia": "92"
#     },
#     {
#         "fecha": "2025-03-07",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,4",
#         "prec": "21,9",
#         "tmin": "8,7",
#         "horatmin": "03:30",
#         "tmax": "12,0",
#         "horatmax": "14:20",
#         "dir": "99",
#         "velmedia": "2,5",
#         "racha": "9,2",
#         "horaracha": "Varias",
#         "presMax": "936,7",
#         "horaPresMax": "00",
#         "presMin": "928,8",
#         "horaPresMin": "19",
#         "hrMedia": "96"
#     },
#     {
#         "fecha": "2025-03-08",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,4",
#         "prec": "13,8",
#         "tmin": "5,7",
#         "horatmin": "23:59",
#         "tmax": "11,2",
#         "horatmax": "13:10",
#         "dir": "18",
#         "velmedia": "4,2",
#         "racha": "16,7",
#         "horaracha": "12:50",
#         "presMax": "929,3",
#         "horaPresMax": "00",
#         "presMin": "919,0",
#         "horaPresMin": "17",
#         "hrMedia": "92",
#         "hrMax": "99",
#         "horaHrMax": "01:00",
#         "hrMin": "88",
#         "horaHrMin": "14:00"
#     },
#     {
#         "fecha": "2025-03-09",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,2",
#         "prec": "3,6",
#         "tmin": "4,1",
#         "horatmin": "06:30",
#         "tmax": "10,3",
#         "horatmax": "14:00",
#         "dir": "25",
#         "velmedia": "2,2",
#         "racha": "11,1",
#         "horaracha": "11:20",
#         "presMax": "923,6",
#         "horaPresMax": "22",
#         "presMin": "921,1",
#         "horaPresMin": "16",
#         "hrMedia": "86",
#         "hrMax": "99",
#         "horaHrMax": "Varias",
#         "hrMin": "70",
#         "horaHrMin": "13:40"
#     },
#     {
#         "fecha": "2025-03-10",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,6",
#         "prec": "23,5",
#         "tmin": "5,8",
#         "horatmin": "Varias",
#         "tmax": "11,5",
#         "horatmax": "15:00"
#     },
#     {
#         "fecha": "2025-03-11",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,4",
#         "prec": "7,5",
#         "tmin": "6,2",
#         "horatmin": "23:59",
#         "tmax": "10,6",
#         "horatmax": "16:40",
#         "dir": "25",
#         "velmedia": "2,2",
#         "racha": "10,3",
#         "horaracha": "13:10",
#         "presMax": "925,8",
#         "horaPresMax": "24",
#         "presMin": "921,6",
#         "horaPresMin": "15"
#     },
#     {
#         "fecha": "2025-03-12",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,5",
#         "prec": "0,0",
#         "tmin": "4,2",
#         "horatmin": "07:00",
#         "tmax": "12,8",
#         "horatmax": "13:20",
#         "dir": "23",
#         "velmedia": "2,5",
#         "racha": "10,0",
#         "horaracha": "15:10",
#         "presMax": "928,1",
#         "horaPresMax": "09",
#         "presMin": "923,5",
#         "horaPresMin": "24"
#     },
#     {
#         "fecha": "2025-03-13",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,0",
#         "prec": "4,7",
#         "tmin": "4,3",
#         "horatmin": "23:50",
#         "tmax": "11,6",
#         "horatmax": "15:00",
#         "dir": "05",
#         "velmedia": "1,4",
#         "racha": "10,3",
#         "horaracha": "23:10",
#         "presMax": "923,5",
#         "horaPresMax": "00",
#         "presMin": "915,9",
#         "horaPresMin": "15",
#         "hrMedia": "89",
#         "hrMax": "98",
#         "horaHrMax": "18:40",
#         "hrMin": "63",
#         "horaHrMin": "14:30"
#     },
#     {
#         "fecha": "2025-03-14",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,2",
#         "prec": "0,0",
#         "tmin": "4,1",
#         "horatmin": "Varias",
#         "tmax": "10,4",
#         "horatmax": "14:00",
#         "dir": "05",
#         "velmedia": "3,6",
#         "racha": "12,2",
#         "horaracha": "09:10",
#         "presMax": "929,6",
#         "horaPresMax": "24",
#         "presMin": "919,3",
#         "horaPresMin": "04",
#         "hrMedia": "57",
#         "hrMax": "96",
#         "horaHrMax": "00:00",
#         "hrMin": "38",
#         "horaHrMin": "17:00"
#     },
#     {
#         "fecha": "2025-03-15",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,8",
#         "prec": "6,7",
#         "tmin": "1,1",
#         "horatmin": "06:00",
#         "tmax": "10,6",
#         "horatmax": "14:00",
#         "dir": "03",
#         "velmedia": "1,9",
#         "racha": "6,7",
#         "horaracha": "00:10",
#         "presMax": "936,1",
#         "horaPresMax": "Varias",
#         "presMin": "929,6",
#         "horaPresMin": "00",
#         "hrMedia": "60",
#         "hrMax": "88",
#         "horaHrMax": "05:20",
#         "hrMin": "40",
#         "horaHrMin": "13:50"
#     },
#     {
#         "fecha": "2025-03-16",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,8",
#         "prec": "0,4",
#         "tmin": "4,1",
#         "horatmin": "07:50",
#         "tmax": "11,6",
#         "horatmax": "15:30",
#         "dir": "27",
#         "velmedia": "2,2",
#         "racha": "7,2",
#         "horaracha": "09:50",
#         "presMax": "938,2",
#         "horaPresMax": "20",
#         "presMin": "934,3",
#         "horaPresMin": "Varias",
#         "hrMedia": "69",
#         "hrMax": "98",
#         "horaHrMax": "Varias",
#         "hrMin": "44",
#         "horaHrMin": "18:00"
#     },
#     {
#         "fecha": "2025-03-17",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,8",
#         "prec": "16,7",
#         "tmin": "4,2",
#         "horatmin": "09:00",
#         "tmax": "9,4",
#         "horatmax": "21:00",
#         "dir": "13",
#         "velmedia": "3,1",
#         "racha": "10,6",
#         "horaracha": "21:00",
#         "presMax": "937,8",
#         "horaPresMax": "00",
#         "presMin": "932,5",
#         "horaPresMin": "18",
#         "hrMedia": "88",
#         "hrMax": "99",
#         "horaHrMax": "23:59",
#         "hrMin": "58",
#         "horaHrMin": "00:00"
#     },
#     {
#         "fecha": "2025-03-18",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,8",
#         "prec": "20,9",
#         "tmin": "6,2",
#         "horatmin": "Varias",
#         "tmax": "11,4",
#         "horatmax": "16:00",
#         "dir": "12",
#         "velmedia": "2,8",
#         "racha": "10,8",
#         "horaracha": "10:00",
#         "presMax": "938,3",
#         "horaPresMax": "24",
#         "presMin": "931,8",
#         "horaPresMin": "Varias"
#     },
#     {
#         "fecha": "2025-03-19",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "12,4",
#         "prec": "0,0",
#         "tmin": "8,1",
#         "horatmin": "07:00",
#         "tmax": "16,6",
#         "horatmax": "16:00",
#         "dir": "12",
#         "velmedia": "3,3",
#         "racha": "13,1",
#         "horaracha": "21:10",
#         "presMax": "940,1",
#         "horaPresMax": "10",
#         "presMin": "935,9",
#         "horaPresMin": "18",
#         "hrMedia": "74",
#         "hrMax": "99",
#         "horaHrMax": "00:00",
#         "hrMin": "51",
#         "horaHrMin": "15:00"
#     },
#     {
#         "fecha": "2025-03-20",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "12,7",
#         "prec": "27,6",
#         "tmin": "9,3",
#         "horatmin": "22:30",
#         "tmax": "16,1",
#         "horatmax": "16:50",
#         "dir": "13",
#         "velmedia": "2,5",
#         "racha": "11,7",
#         "horaracha": "02:30",
#         "presMax": "937,8",
#         "horaPresMax": "Varias",
#         "presMin": "931,8",
#         "horaPresMin": "24",
#         "hrMedia": "79",
#         "hrMax": "99",
#         "horaHrMax": "Varias",
#         "hrMin": "65",
#         "horaHrMin": "16:10"
#     },
#     {
#         "fecha": "2025-03-21",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,0",
#         "prec": "14,5",
#         "tmin": "6,3",
#         "horatmin": "23:59",
#         "tmax": "11,8",
#         "horatmax": "14:10",
#         "dir": "24",
#         "velmedia": "3,6",
#         "racha": "16,9",
#         "horaracha": "22:10",
#         "presMax": "932,5",
#         "horaPresMax": "10",
#         "presMin": "928,5",
#         "horaPresMin": "21",
#         "hrMedia": "87"
#     },
#     {
#         "fecha": "2025-03-22",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,0",
#         "prec": "2,3",
#         "tmin": "5,0",
#         "horatmin": "23:00",
#         "tmax": "10,9",
#         "horatmax": "15:00",
#         "dir": "08",
#         "velmedia": "3,3",
#         "racha": "13,6",
#         "horaracha": "16:00",
#         "presMax": "930,2",
#         "horaPresMax": "01",
#         "presMin": "927,0",
#         "horaPresMin": "16",
#         "hrMedia": "92",
#         "hrMax": "99",
#         "horaHrMax": "09:50",
#         "hrMin": "78",
#         "horaHrMin": "21:10"
#     },
#     {
#         "fecha": "2025-03-23",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,0",
#         "prec": "0,0",
#         "tmin": "3,8",
#         "horatmin": "07:00",
#         "tmax": "12,3",
#         "horatmax": "15:30",
#         "dir": "11",
#         "velmedia": "1,7",
#         "racha": "9,7",
#         "horaracha": "01:10",
#         "presMax": "934,0",
#         "horaPresMax": "Varias",
#         "presMin": "928,7",
#         "horaPresMin": "04",
#         "hrMedia": "61",
#         "hrMax": "88",
#         "horaHrMax": "02:20",
#         "hrMin": "40",
#         "horaHrMin": "15:10"
#     },
#     {
#         "fecha": "2025-03-24",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,2",
#         "prec": "4,8",
#         "tmin": "4,3",
#         "horatmin": "07:00",
#         "tmax": "14,0",
#         "horatmax": "14:00",
#         "dir": "09",
#         "velmedia": "3,3",
#         "racha": "12,5",
#         "horaracha": "18:00",
#         "presMax": "941,4",
#         "horaPresMax": "Varias",
#         "presMin": "933,7",
#         "horaPresMin": "03",
#         "hrMedia": "70",
#         "hrMax": "96",
#         "horaHrMax": "23:50",
#         "hrMin": "45",
#         "horaHrMin": "14:20"
#     },
#     {
#         "fecha": "2025-03-25",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "11,0",
#         "prec": "0,0",
#         "tmin": "6,2",
#         "horatmin": "01:00",
#         "tmax": "15,9",
#         "horatmax": "15:20",
#         "dir": "03",
#         "velmedia": "2,2",
#         "racha": "9,4",
#         "horaracha": "11:00",
#         "presMax": "944,1",
#         "horaPresMax": "23",
#         "presMin": "941,0",
#         "horaPresMin": "02",
#         "hrMedia": "60",
#         "hrMax": "97",
#         "horaHrMax": "01:20",
#         "hrMin": "41",
#         "horaHrMin": "15:40"
#     },
#     {
#         "fecha": "2025-03-26",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,2",
#         "prec": "0,0",
#         "tmin": "5,2",
#         "horatmin": "06:40",
#         "tmax": "15,2",
#         "horatmax": "12:30",
#         "dir": "22",
#         "velmedia": "1,4",
#         "racha": "7,2",
#         "horaracha": "18:50",
#         "presMax": "944,0",
#         "horaPresMax": "00",
#         "presMin": "939,6",
#         "horaPresMin": "16",
#         "hrMedia": "60",
#         "hrMax": "93",
#         "horaHrMax": "Varias",
#         "hrMin": "41",
#         "horaHrMin": "14:20"
#     },
#     {
#         "fecha": "2025-03-27",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,2",
#         "prec": "0,0",
#         "tmin": "4,3",
#         "horatmin": "06:40",
#         "tmax": "16,1",
#         "horatmax": "16:20",
#         "dir": "23",
#         "velmedia": "1,9",
#         "racha": "6,1",
#         "horaracha": "21:50",
#         "presMax": "940,1",
#         "horaPresMax": "00",
#         "presMin": "936,4",
#         "horaPresMin": "16",
#         "hrMedia": "58",
#         "hrMax": "85",
#         "horaHrMax": "04:50",
#         "hrMin": "41",
#         "horaHrMin": "15:50"
#     },
#     {
#         "fecha": "2025-03-28",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "12,3",
#         "prec": "0,0",
#         "tmin": "6,2",
#         "horatmin": "Varias",
#         "tmax": "18,4",
#         "horatmax": "15:00",
#         "dir": "33",
#         "velmedia": "1,1",
#         "racha": "8,3",
#         "horaracha": "17:30",
#         "presMax": "941,8",
#         "horaPresMax": "23",
#         "presMin": "937,4",
#         "horaPresMin": "04",
#         "hrMedia": "49",
#         "hrMax": "84",
#         "horaHrMax": "06:40",
#         "hrMin": "26",
#         "horaHrMin": "14:30"
#     },
#     {
#         "fecha": "2025-03-29",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "12,8",
#         "prec": "0,0",
#         "tmin": "6,2",
#         "horatmin": "Varias",
#         "tmax": "19,3",
#         "horatmax": "14:30",
#         "dir": "02",
#         "velmedia": "1,7",
#         "racha": "10,8",
#         "horaracha": "16:30",
#         "presMax": "943,2",
#         "horaPresMax": "10",
#         "presMin": "940,4",
#         "horaPresMin": "17",
#         "hrMedia": "51",
#         "hrMax": "86",
#         "horaHrMax": "06:50",
#         "hrMin": "23",
#         "horaHrMin": "14:30"
#     },
#     {
#         "fecha": "2025-03-30",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "12,6",
#         "prec": "0,0",
#         "tmin": "4,2",
#         "horatmin": "06:50",
#         "tmax": "20,9",
#         "horatmax": "16:10",
#         "dir": "23",
#         "velmedia": "2,2",
#         "racha": "8,3",
#         "horaracha": "09:10",
#         "presMax": "943,6",
#         "horaPresMax": "10",
#         "presMin": "940,8",
#         "horaPresMin": "17",
#         "hrMedia": "33",
#         "hrMax": "69",
#         "horaHrMax": "06:40",
#         "hrMin": "16",
#         "horaHrMin": "15:10"
#     },
#     {
#         "fecha": "2025-03-31",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "16,9",
#         "prec": "0,0",
#         "tmin": "9,1",
#         "horatmin": "06:10",
#         "tmax": "24,7",
#         "horatmax": "14:00",
#         "dir": "26",
#         "velmedia": "1,4",
#         "racha": "6,7",
#         "horaracha": "04:40",
#         "presMax": "942,6",
#         "horaPresMax": "00",
#         "presMin": "935,4",
#         "horaPresMin": "Varias",
#         "hrMedia": "34",
#         "hrMax": "62",
#         "horaHrMax": "06:10",
#         "hrMin": "14",
#         "horaHrMin": "14:00"
#     },
#     {
#         "fecha": "2025-04-01",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "16,9",
#         "prec": "0,0",
#         "tmin": "10,1",
#         "horatmin": "05:20",
#         "tmax": "23,7",
#         "horatmax": "14:00",
#         "dir": "11",
#         "velmedia": "1,9",
#         "racha": "7,2",
#         "horaracha": "15:00",
#         "presMax": "935,4",
#         "horaPresMax": "00",
#         "presMin": "927,2",
#         "horaPresMin": "24",
#         "hrMedia": "42",
#         "hrMax": "71",
#         "horaHrMax": "23:59",
#         "hrMin": "26",
#         "horaHrMin": "14:00"
#     },
#     {
#         "fecha": "2025-04-02",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "14,6",
#         "prec": "21,9",
#         "tmin": "10,3",
#         "horatmin": "06:00",
#         "tmax": "18,8",
#         "horatmax": "15:10",
#         "dir": "14",
#         "velmedia": "2,2",
#         "racha": "8,3",
#         "horaracha": "23:50",
#         "presMax": "931,4",
#         "horaPresMax": "24",
#         "presMin": "925,5",
#         "horaPresMin": "06",
#         "hrMedia": "67",
#         "hrMax": "95",
#         "horaHrMax": "23:50",
#         "hrMin": "48",
#         "horaHrMin": "17:00"
#     },
#     {
#         "fecha": "2025-04-03",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,5",
#         "prec": "20,2",
#         "tmin": "8,3",
#         "horatmin": "07:00",
#         "tmax": "10,7",
#         "horatmax": "00:10",
#         "dir": "15",
#         "velmedia": "2,2",
#         "racha": "7,8",
#         "horaracha": "00:20",
#         "presMax": "935,2",
#         "horaPresMax": "11",
#         "presMin": "930,9",
#         "horaPresMin": "03",
#         "hrMedia": "98"
#     }
# ]

# %% [markdown]
# Se obtiene la fecha maxima descargada. A día 22/03/2025 es el 18/03/2025

# %%
fechas = [fecha['fecha'] for fecha in datos_historicos]
fecha_max_descargada = max(fechas)
print(fecha_max_descargada)
# Out:
# 2025-04-03

# %% [markdown]
# Se imprime la diferencia en días entre hoy y la fecha máxima descargada

# %%
# Convert fecha_max_descargada to datetime
fecha_max = datetime.strptime(fecha_max_descargada, '%Y-%m-%d')

# Convert ahora to datetime
ahora_dt = datetime.strptime(ahora, '%Y-%m-%dT%H:%M:%SUTC')

# Calculate difference in days
diferencia_dias = (ahora_dt - fecha_max).days

print(f"Diferencia en días: {diferencia_dias}")
# Out:
# Diferencia en días: 3

# %% [markdown]
# ## 1.2 Se descargan todos los datos de 6 en 6 meses, ya que esta API no permite un rango de fechas superior a 6 meses.

# %% [markdown]
# Se definen las fechas a descargar con la siguiente función

# %%
# Se formatea la fecha para que coincida con el formato de la API
fecha_max_descargada = fecha_max.strftime("%Y-%m-%dT%H:%M:%SUTC")

# Se convierte la fecha a datetime para poder restarle los dias que se quiera
fecha_max_dt = datetime.strptime(fecha_max_descargada, "%Y-%m-%dT%H:%M:%SUTC")

# %% [markdown]
# Se define la siguiente funcion que devuelve los intervalos de fechas a ejecutar en la API

# %%
def listar_fechas_descargas(fecha_max: datetime, dias: int, n_veces: int) -> {list, list}:
    """
    Función que devuelve 1 diccionario que contiene 2 listas de fechas empezando por 
    una fecha dada y retrocediendo un número de días dado n_veces.

    La primera lista almacena la fecha inicial de descarga y la segunda lista
    almacena la fecha final de descarga.

    Las fechas devueltas están en el formato correcto para la API de AEMET.
    """
    fechas_iniciales = []
    for i in range(n_veces):

        if i == 0 :
            fecha_inicial = fecha_max - timedelta(days=dias*(i+1))
        else:
            fecha_inicial = fecha_max - timedelta(days=dias*(i+1)+i) 
            # Se resta 1 días más para que la fecha inicial no coincida con la fecha final del siguiente periodo.

        fecha_inicial = fecha_inicial.strftime("%Y-%m-%dT%H:%M:%SUTC")
        fechas_iniciales.append(fecha_inicial)

    fechas_finales = []
    for i in range(n_veces):

        if i == 0:
            fecha_final = fecha_max - timedelta(days=dias*(i)) # En la primera iteración no resta nada porque interesa almacenar la fecha máxima.
        else:
            fecha_final = fecha_max - timedelta(days=dias*(i)+i)
            # Se resta i días más para que la fecha final no coincida con la fecha inicial del periodo anterior.

        fecha_final = fecha_final.strftime("%Y-%m-%dT%H:%M:%SUTC")
        fechas_finales.append(fecha_final)

    return {"fechas_iniciales" : fechas_iniciales, "fechas_finales" : fechas_finales}

# %% [markdown]
# Interesa que los intervalos sean de 6 en 6 meses, o lo que es lo mismo, de 180 en 180 días

# %%
diccionario_fechas = listar_fechas_descargas(fecha_max_dt, 180, 3)
diccionario_fechas
# Out:
# {'fechas_iniciales': ['2024-10-05T00:00:00UTC',
#   '2024-04-07T00:00:00UTC',
#   '2023-10-09T00:00:00UTC'],
#  'fechas_finales': ['2025-04-03T00:00:00UTC',
#   '2024-10-04T00:00:00UTC',
#   '2024-04-06T00:00:00UTC']}

# %% [markdown]
# Se comprueba en la siguiente tabla que efectivamente hay 180 días de diferencia entre las fechas iniciales y fechas finales por intervalo

# %%
df_lista_fechas = pd.DataFrame(diccionario_fechas)
df_lista_fechas["fechas_iniciales"] = pd.to_datetime(df_lista_fechas["fechas_iniciales"])
df_lista_fechas["fechas_finales"] = pd.to_datetime(df_lista_fechas["fechas_finales"])
df_lista_fechas["Diferencia en días"] = (df_lista_fechas["fechas_finales"] - df_lista_fechas["fechas_iniciales"]).dt.days
df_lista_fechas
# Out:
#            fechas_iniciales            fechas_finales  Diferencia en días
# 0 2024-10-05 00:00:00+00:00 2025-04-03 00:00:00+00:00                 180
# 1 2024-04-07 00:00:00+00:00 2024-10-04 00:00:00+00:00                 180
# 2 2023-10-09 00:00:00+00:00 2024-04-06 00:00:00+00:00                 180

# %% [markdown]
# Se descargan los datos recursivamente

# %% [markdown]
# 1. Controles de tiempo de descarga de datos

# %%
espera_error_429 = 20
espera_error_except = 30

# %% [markdown]
# 2. Bloque de código para descargar los datos

# %%
n_veces_inicial = 0
lista_datos_historicos = []
max_intentos = 0
max_intentors_error = 0

start_time = time.time()

while True :

    try :
        n_veces_inicial += 1
        fechas_descargas = listar_fechas_descargas(fecha_max_dt, 180, n_veces_inicial)

        # La variable n_veces_inicial se usa para obtener la última fecha de descarga recursivamente.

        fecha_ini = fechas_descargas["fechas_iniciales"][-1]
        fecha_fin = fechas_descargas["fechas_finales"][-1]

        estacion_id = "3195"  # Ejemplo de estación meteorológica de Madrid-Retiro

        url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fecha_ini}/fechafin/{fecha_fin}/estacion/{estacion_id}?api_key={API_KEY}"

        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            datos_url = data.get("datos")
            if datos_url:
                response_data = requests.get(datos_url)
                if response_data.status_code == 200:
                    datos_historicos = response_data.json()
                    lista_datos_historicos.append(datos_historicos)
                    print(f"Se ha descargado los datos de {fecha_ini} a {fecha_fin}")
                else:
                    print("Error al obtener los datos reales", response_data.status_code)
                    n_veces_inicial -= 1 # Se resta 1 para volver a la fecha anterior del ciclo.
            else:
                print("No se encontró la URL de datos")
                n_veces_inicial -= 1 # Se resta 1 para volver a la fecha anterior del ciclo.
                max_intentos += 1
        else:
            print("Error en la petición inicial, código de error:", response.status_code)

        if (response.status_code == 200) and datos_url :
            max_intentos = 0
            max_intentors_error = 0
            
        elif response.status_code == 429 :
            time.sleep(espera_error_429)
            n_veces_inicial -= 1 # Se resta 1 para volver a la fecha anterior del ciclo.
            max_intentos += 1

        elif max_intentos == 3:
            print("Número máximo de intentos alcanzado")
            break
                
        elif response.status_code != 200 :
            break
    
    except (ConnectionError, ProtocolError, RemoteDisconnected) as e:
        print(f"Error de conexión: {e}")
        time.sleep(espera_error_except)
        n_veces_inicial -= 1 # Se resta 1 para volver a la fecha anterior del ciclo.
        max_intentors_error += 1
        if max_intentors_error == 3:
            print("Número máximo de intentos alcanzado")
            break
        continue

end_time = time.time()
# Out:
# Se ha descargado los datos de 2024-10-05T00:00:00UTC a 2025-04-03T00:00:00UTC
# Se ha descargado los datos de 2024-04-07T00:00:00UTC a 2024-10-04T00:00:00UTC
# Se ha descargado los datos de 2023-10-09T00:00:00UTC a 2024-04-06T00:00:00UTC
# Se ha descargado los datos de 2023-04-11T00:00:00UTC a 2023-10-08T00:00:00UTC
# Se ha descargado los datos de 2022-10-12T00:00:00UTC a 2023-04-10T00:00:00UTC
# Se ha descargado los datos de 2022-04-14T00:00:00UTC a 2022-10-11T00:00:00UTC
# Se ha descargado los datos de 2021-10-15T00:00:00UTC a 2022-04-13T00:00:00UTC
# Se ha descargado los datos de 2021-04-17T00:00:00UTC a 2021-10-14T00:00:00UTC
# Se ha descargado los datos de 2020-10-18T00:00:00UTC a 2021-04-16T00:00:00UTC
# Se ha descargado los datos de 2020-04-20T00:00:00UTC a 2020-10-17T00:00:00UTC
# Se ha descargado los datos de 2019-10-22T00:00:00UTC a 2020-04-19T00:00:00UTC
# Se ha descargado los datos de 2019-04-24T00:00:00UTC a 2019-10-21T00:00:00UTC
# Se ha descargado los datos de 2018-10-25T00:00:00UTC a 2019-04-23T00:00:00UTC
# Se ha descargado los datos de 2018-04-27T00:00:00UTC a 2018-10-24T00:00:00UTC
# Se ha descargado los datos de 2017-10-28T00:00:00UTC a 2018-04-26T00:00:00UTC
# Se ha descargado los datos de 2017-04-30T00:00:00UTC a 2017-10-27T00:00:00UTC
# Se ha descargado los datos de 2016-10-31T00:00:00UTC a 2017-04-29T00:00:00UTC
# Se ha descargado los datos de 2016-05-03T00:00:00UTC a 2016-10-30T00:00:00UTC
# Se ha descargado los datos de 2015-11-04T00:00:00UTC a 2016-05-02T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 2015-05-07T00:00:00UTC a 2015-11-03T00:00:00UTC
# Se ha descargado los datos de 2014-11-07T00:00:00UTC a 2015-05-06T00:00:00UTC
# Se ha descargado los datos de 2014-05-10T00:00:00UTC a 2014-11-06T00:00:00UTC
# Se ha descargado los datos de 2013-11-10T00:00:00UTC a 2014-05-09T00:00:00UTC
# Se ha descargado los datos de 2013-05-13T00:00:00UTC a 2013-11-09T00:00:00UTC
# Se ha descargado los datos de 2012-11-13T00:00:00UTC a 2013-05-12T00:00:00UTC
# Se ha descargado los datos de 2012-05-16T00:00:00UTC a 2012-11-12T00:00:00UTC
# Se ha descargado los datos de 2011-11-17T00:00:00UTC a 2012-05-15T00:00:00UTC
# Se ha descargado los datos de 2011-05-20T00:00:00UTC a 2011-11-16T00:00:00UTC
# Se ha descargado los datos de 2010-11-20T00:00:00UTC a 2011-05-19T00:00:00UTC
# Se ha descargado los datos de 2010-05-23T00:00:00UTC a 2010-11-19T00:00:00UTC
# Se ha descargado los datos de 2009-11-23T00:00:00UTC a 2010-05-22T00:00:00UTC
# Se ha descargado los datos de 2009-05-26T00:00:00UTC a 2009-11-22T00:00:00UTC
# Se ha descargado los datos de 2008-11-26T00:00:00UTC a 2009-05-25T00:00:00UTC
# Se ha descargado los datos de 2008-05-29T00:00:00UTC a 2008-11-25T00:00:00UTC
# Se ha descargado los datos de 2007-11-30T00:00:00UTC a 2008-05-28T00:00:00UTC
# Se ha descargado los datos de 2007-06-02T00:00:00UTC a 2007-11-29T00:00:00UTC
# Se ha descargado los datos de 2006-12-03T00:00:00UTC a 2007-06-01T00:00:00UTC
# Se ha descargado los datos de 2006-06-05T00:00:00UTC a 2006-12-02T00:00:00UTC
# Se ha descargado los datos de 2005-12-06T00:00:00UTC a 2006-06-04T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 2005-06-08T00:00:00UTC a 2005-12-05T00:00:00UTC
# Se ha descargado los datos de 2004-12-09T00:00:00UTC a 2005-06-07T00:00:00UTC
# Se ha descargado los datos de 2004-06-11T00:00:00UTC a 2004-12-08T00:00:00UTC
# Se ha descargado los datos de 2003-12-13T00:00:00UTC a 2004-06-10T00:00:00UTC
# Se ha descargado los datos de 2003-06-15T00:00:00UTC a 2003-12-12T00:00:00UTC
# Se ha descargado los datos de 2002-12-16T00:00:00UTC a 2003-06-14T00:00:00UTC
# Se ha descargado los datos de 2002-06-18T00:00:00UTC a 2002-12-15T00:00:00UTC
# Se ha descargado los datos de 2001-12-19T00:00:00UTC a 2002-06-17T00:00:00UTC
# Se ha descargado los datos de 2001-06-21T00:00:00UTC a 2001-12-18T00:00:00UTC
# Se ha descargado los datos de 2000-12-22T00:00:00UTC a 2001-06-20T00:00:00UTC
# Se ha descargado los datos de 2000-06-24T00:00:00UTC a 2000-12-21T00:00:00UTC
# Se ha descargado los datos de 1999-12-26T00:00:00UTC a 2000-06-23T00:00:00UTC
# Se ha descargado los datos de 1999-06-28T00:00:00UTC a 1999-12-25T00:00:00UTC
# Se ha descargado los datos de 1998-12-29T00:00:00UTC a 1999-06-27T00:00:00UTC
# Se ha descargado los datos de 1998-07-01T00:00:00UTC a 1998-12-28T00:00:00UTC
# Se ha descargado los datos de 1998-01-01T00:00:00UTC a 1998-06-30T00:00:00UTC
# Se ha descargado los datos de 1997-07-04T00:00:00UTC a 1997-12-31T00:00:00UTC
# Se ha descargado los datos de 1997-01-04T00:00:00UTC a 1997-07-03T00:00:00UTC
# Se ha descargado los datos de 1996-07-07T00:00:00UTC a 1997-01-03T00:00:00UTC
# Se ha descargado los datos de 1996-01-08T00:00:00UTC a 1996-07-06T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 1995-07-11T00:00:00UTC a 1996-01-07T00:00:00UTC
# Se ha descargado los datos de 1995-01-11T00:00:00UTC a 1995-07-10T00:00:00UTC
# Se ha descargado los datos de 1994-07-14T00:00:00UTC a 1995-01-10T00:00:00UTC
# Se ha descargado los datos de 1994-01-14T00:00:00UTC a 1994-07-13T00:00:00UTC
# Se ha descargado los datos de 1993-07-17T00:00:00UTC a 1994-01-13T00:00:00UTC
# Se ha descargado los datos de 1993-01-17T00:00:00UTC a 1993-07-16T00:00:00UTC
# Se ha descargado los datos de 1992-07-20T00:00:00UTC a 1993-01-16T00:00:00UTC
# Se ha descargado los datos de 1992-01-21T00:00:00UTC a 1992-07-19T00:00:00UTC
# Se ha descargado los datos de 1991-07-24T00:00:00UTC a 1992-01-20T00:00:00UTC
# Se ha descargado los datos de 1991-01-24T00:00:00UTC a 1991-07-23T00:00:00UTC
# Se ha descargado los datos de 1990-07-27T00:00:00UTC a 1991-01-23T00:00:00UTC
# Se ha descargado los datos de 1990-01-27T00:00:00UTC a 1990-07-26T00:00:00UTC
# Se ha descargado los datos de 1989-07-30T00:00:00UTC a 1990-01-26T00:00:00UTC
# Se ha descargado los datos de 1989-01-30T00:00:00UTC a 1989-07-29T00:00:00UTC
# Se ha descargado los datos de 1988-08-02T00:00:00UTC a 1989-01-29T00:00:00UTC
# Se ha descargado los datos de 1988-02-03T00:00:00UTC a 1988-08-01T00:00:00UTC
# Se ha descargado los datos de 1987-08-06T00:00:00UTC a 1988-02-02T00:00:00UTC
# Se ha descargado los datos de 1987-02-06T00:00:00UTC a 1987-08-05T00:00:00UTC
# Se ha descargado los datos de 1986-08-09T00:00:00UTC a 1987-02-05T00:00:00UTC
# Se ha descargado los datos de 1986-02-09T00:00:00UTC a 1986-08-08T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 1985-08-12T00:00:00UTC a 1986-02-08T00:00:00UTC
# Se ha descargado los datos de 1985-02-12T00:00:00UTC a 1985-08-11T00:00:00UTC
# Se ha descargado los datos de 1984-08-15T00:00:00UTC a 1985-02-11T00:00:00UTC
# Se ha descargado los datos de 1984-02-16T00:00:00UTC a 1984-08-14T00:00:00UTC
# Se ha descargado los datos de 1983-08-19T00:00:00UTC a 1984-02-15T00:00:00UTC
# Se ha descargado los datos de 1983-02-19T00:00:00UTC a 1983-08-18T00:00:00UTC
# Se ha descargado los datos de 1982-08-22T00:00:00UTC a 1983-02-18T00:00:00UTC
# Se ha descargado los datos de 1982-02-22T00:00:00UTC a 1982-08-21T00:00:00UTC
# Se ha descargado los datos de 1981-08-25T00:00:00UTC a 1982-02-21T00:00:00UTC
# Se ha descargado los datos de 1981-02-25T00:00:00UTC a 1981-08-24T00:00:00UTC
# Se ha descargado los datos de 1980-08-28T00:00:00UTC a 1981-02-24T00:00:00UTC
# Se ha descargado los datos de 1980-02-29T00:00:00UTC a 1980-08-27T00:00:00UTC
# Se ha descargado los datos de 1979-09-01T00:00:00UTC a 1980-02-28T00:00:00UTC
# Se ha descargado los datos de 1979-03-04T00:00:00UTC a 1979-08-31T00:00:00UTC
# Se ha descargado los datos de 1978-09-04T00:00:00UTC a 1979-03-03T00:00:00UTC
# Se ha descargado los datos de 1978-03-07T00:00:00UTC a 1978-09-03T00:00:00UTC
# Se ha descargado los datos de 1977-09-07T00:00:00UTC a 1978-03-06T00:00:00UTC
# Se ha descargado los datos de 1977-03-10T00:00:00UTC a 1977-09-06T00:00:00UTC
# Se ha descargado los datos de 1976-09-10T00:00:00UTC a 1977-03-09T00:00:00UTC
# Se ha descargado los datos de 1976-03-13T00:00:00UTC a 1976-09-09T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 1975-09-14T00:00:00UTC a 1976-03-12T00:00:00UTC
# Se ha descargado los datos de 1975-03-17T00:00:00UTC a 1975-09-13T00:00:00UTC
# Se ha descargado los datos de 1974-09-17T00:00:00UTC a 1975-03-16T00:00:00UTC
# Se ha descargado los datos de 1974-03-20T00:00:00UTC a 1974-09-16T00:00:00UTC
# Se ha descargado los datos de 1973-09-20T00:00:00UTC a 1974-03-19T00:00:00UTC
# Se ha descargado los datos de 1973-03-23T00:00:00UTC a 1973-09-19T00:00:00UTC
# Se ha descargado los datos de 1972-09-23T00:00:00UTC a 1973-03-22T00:00:00UTC
# Se ha descargado los datos de 1972-03-26T00:00:00UTC a 1972-09-22T00:00:00UTC
# Se ha descargado los datos de 1971-09-27T00:00:00UTC a 1972-03-25T00:00:00UTC
# Se ha descargado los datos de 1971-03-30T00:00:00UTC a 1971-09-26T00:00:00UTC
# Se ha descargado los datos de 1970-09-30T00:00:00UTC a 1971-03-29T00:00:00UTC
# Se ha descargado los datos de 1970-04-02T00:00:00UTC a 1970-09-29T00:00:00UTC
# Se ha descargado los datos de 1969-10-03T00:00:00UTC a 1970-04-01T00:00:00UTC
# Se ha descargado los datos de 1969-04-05T00:00:00UTC a 1969-10-02T00:00:00UTC
# Se ha descargado los datos de 1968-10-06T00:00:00UTC a 1969-04-04T00:00:00UTC
# Se ha descargado los datos de 1968-04-08T00:00:00UTC a 1968-10-05T00:00:00UTC
# Se ha descargado los datos de 1967-10-10T00:00:00UTC a 1968-04-07T00:00:00UTC
# Se ha descargado los datos de 1967-04-12T00:00:00UTC a 1967-10-09T00:00:00UTC
# Se ha descargado los datos de 1966-10-13T00:00:00UTC a 1967-04-11T00:00:00UTC
# Se ha descargado los datos de 1966-04-15T00:00:00UTC a 1966-10-12T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Error de conexión: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Se ha descargado los datos de 1965-10-16T00:00:00UTC a 1966-04-14T00:00:00UTC
# Se ha descargado los datos de 1965-04-18T00:00:00UTC a 1965-10-15T00:00:00UTC
# Se ha descargado los datos de 1964-10-19T00:00:00UTC a 1965-04-17T00:00:00UTC
# Se ha descargado los datos de 1964-04-21T00:00:00UTC a 1964-10-18T00:00:00UTC
# Se ha descargado los datos de 1963-10-23T00:00:00UTC a 1964-04-20T00:00:00UTC
# Se ha descargado los datos de 1963-04-25T00:00:00UTC a 1963-10-22T00:00:00UTC
# Se ha descargado los datos de 1962-10-26T00:00:00UTC a 1963-04-24T00:00:00UTC
# Se ha descargado los datos de 1962-04-28T00:00:00UTC a 1962-10-25T00:00:00UTC
# Se ha descargado los datos de 1961-10-29T00:00:00UTC a 1962-04-27T00:00:00UTC
# Se ha descargado los datos de 1961-05-01T00:00:00UTC a 1961-10-28T00:00:00UTC
# Se ha descargado los datos de 1960-11-01T00:00:00UTC a 1961-04-30T00:00:00UTC
# Se ha descargado los datos de 1960-05-04T00:00:00UTC a 1960-10-31T00:00:00UTC
# Se ha descargado los datos de 1959-11-05T00:00:00UTC a 1960-05-03T00:00:00UTC
# Se ha descargado los datos de 1959-05-08T00:00:00UTC a 1959-11-04T00:00:00UTC
# Se ha descargado los datos de 1958-11-08T00:00:00UTC a 1959-05-07T00:00:00UTC
# Se ha descargado los datos de 1958-05-11T00:00:00UTC a 1958-11-07T00:00:00UTC
# Se ha descargado los datos de 1957-11-11T00:00:00UTC a 1958-05-10T00:00:00UTC
# Se ha descargado los datos de 1957-05-14T00:00:00UTC a 1957-11-10T00:00:00UTC
# Se ha descargado los datos de 1956-11-14T00:00:00UTC a 1957-05-13T00:00:00UTC
# Se ha descargado los datos de 1956-05-17T00:00:00UTC a 1956-11-13T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 1955-11-18T00:00:00UTC a 1956-05-16T00:00:00UTC
# Se ha descargado los datos de 1955-05-21T00:00:00UTC a 1955-11-17T00:00:00UTC
# Se ha descargado los datos de 1954-11-21T00:00:00UTC a 1955-05-20T00:00:00UTC
# Se ha descargado los datos de 1954-05-24T00:00:00UTC a 1954-11-20T00:00:00UTC
# Se ha descargado los datos de 1953-11-24T00:00:00UTC a 1954-05-23T00:00:00UTC
# Se ha descargado los datos de 1953-05-27T00:00:00UTC a 1953-11-23T00:00:00UTC
# Se ha descargado los datos de 1952-11-27T00:00:00UTC a 1953-05-26T00:00:00UTC
# Se ha descargado los datos de 1952-05-30T00:00:00UTC a 1952-11-26T00:00:00UTC
# Se ha descargado los datos de 1951-12-01T00:00:00UTC a 1952-05-29T00:00:00UTC
# Se ha descargado los datos de 1951-06-03T00:00:00UTC a 1951-11-30T00:00:00UTC
# Se ha descargado los datos de 1950-12-04T00:00:00UTC a 1951-06-02T00:00:00UTC
# Se ha descargado los datos de 1950-06-06T00:00:00UTC a 1950-12-03T00:00:00UTC
# Se ha descargado los datos de 1949-12-07T00:00:00UTC a 1950-06-05T00:00:00UTC
# Se ha descargado los datos de 1949-06-09T00:00:00UTC a 1949-12-06T00:00:00UTC
# Se ha descargado los datos de 1948-12-10T00:00:00UTC a 1949-06-08T00:00:00UTC
# Se ha descargado los datos de 1948-06-12T00:00:00UTC a 1948-12-09T00:00:00UTC
# Se ha descargado los datos de 1947-12-14T00:00:00UTC a 1948-06-11T00:00:00UTC
# Se ha descargado los datos de 1947-06-16T00:00:00UTC a 1947-12-13T00:00:00UTC
# Se ha descargado los datos de 1946-12-17T00:00:00UTC a 1947-06-15T00:00:00UTC
# Se ha descargado los datos de 1946-06-19T00:00:00UTC a 1946-12-16T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 1945-12-20T00:00:00UTC a 1946-06-18T00:00:00UTC
# Se ha descargado los datos de 1945-06-22T00:00:00UTC a 1945-12-19T00:00:00UTC
# Se ha descargado los datos de 1944-12-23T00:00:00UTC a 1945-06-21T00:00:00UTC
# Se ha descargado los datos de 1944-06-25T00:00:00UTC a 1944-12-22T00:00:00UTC
# Se ha descargado los datos de 1943-12-27T00:00:00UTC a 1944-06-24T00:00:00UTC
# Se ha descargado los datos de 1943-06-29T00:00:00UTC a 1943-12-26T00:00:00UTC
# Se ha descargado los datos de 1942-12-30T00:00:00UTC a 1943-06-28T00:00:00UTC
# Se ha descargado los datos de 1942-07-02T00:00:00UTC a 1942-12-29T00:00:00UTC
# Se ha descargado los datos de 1942-01-02T00:00:00UTC a 1942-07-01T00:00:00UTC
# Se ha descargado los datos de 1941-07-05T00:00:00UTC a 1942-01-01T00:00:00UTC
# Se ha descargado los datos de 1941-01-05T00:00:00UTC a 1941-07-04T00:00:00UTC
# Se ha descargado los datos de 1940-07-08T00:00:00UTC a 1941-01-04T00:00:00UTC
# Se ha descargado los datos de 1940-01-09T00:00:00UTC a 1940-07-07T00:00:00UTC
# Se ha descargado los datos de 1939-07-12T00:00:00UTC a 1940-01-08T00:00:00UTC
# Se ha descargado los datos de 1939-01-12T00:00:00UTC a 1939-07-11T00:00:00UTC
# Se ha descargado los datos de 1938-07-15T00:00:00UTC a 1939-01-11T00:00:00UTC
# Se ha descargado los datos de 1938-01-15T00:00:00UTC a 1938-07-14T00:00:00UTC
# Se ha descargado los datos de 1937-07-18T00:00:00UTC a 1938-01-14T00:00:00UTC
# Se ha descargado los datos de 1937-01-18T00:00:00UTC a 1937-07-17T00:00:00UTC
# Se ha descargado los datos de 1936-07-21T00:00:00UTC a 1937-01-17T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 1936-01-22T00:00:00UTC a 1936-07-20T00:00:00UTC
# Se ha descargado los datos de 1935-07-25T00:00:00UTC a 1936-01-21T00:00:00UTC
# Se ha descargado los datos de 1935-01-25T00:00:00UTC a 1935-07-24T00:00:00UTC
# Se ha descargado los datos de 1934-07-28T00:00:00UTC a 1935-01-24T00:00:00UTC
# Se ha descargado los datos de 1934-01-28T00:00:00UTC a 1934-07-27T00:00:00UTC
# Se ha descargado los datos de 1933-07-31T00:00:00UTC a 1934-01-27T00:00:00UTC
# Se ha descargado los datos de 1933-01-31T00:00:00UTC a 1933-07-30T00:00:00UTC
# Se ha descargado los datos de 1932-08-03T00:00:00UTC a 1933-01-30T00:00:00UTC
# Se ha descargado los datos de 1932-02-04T00:00:00UTC a 1932-08-02T00:00:00UTC
# Se ha descargado los datos de 1931-08-07T00:00:00UTC a 1932-02-03T00:00:00UTC
# Se ha descargado los datos de 1931-02-07T00:00:00UTC a 1931-08-06T00:00:00UTC
# Se ha descargado los datos de 1930-08-10T00:00:00UTC a 1931-02-06T00:00:00UTC
# Se ha descargado los datos de 1930-02-10T00:00:00UTC a 1930-08-09T00:00:00UTC
# Se ha descargado los datos de 1929-08-13T00:00:00UTC a 1930-02-09T00:00:00UTC
# Se ha descargado los datos de 1929-02-13T00:00:00UTC a 1929-08-12T00:00:00UTC
# Se ha descargado los datos de 1928-08-16T00:00:00UTC a 1929-02-12T00:00:00UTC
# Se ha descargado los datos de 1928-02-17T00:00:00UTC a 1928-08-15T00:00:00UTC
# Se ha descargado los datos de 1927-08-20T00:00:00UTC a 1928-02-16T00:00:00UTC
# Se ha descargado los datos de 1927-02-20T00:00:00UTC a 1927-08-19T00:00:00UTC
# Se ha descargado los datos de 1926-08-23T00:00:00UTC a 1927-02-19T00:00:00UTC
# Error en la petición inicial, código de error: 429
# Error en la petición inicial, código de error: 429
# Se ha descargado los datos de 1926-02-23T00:00:00UTC a 1926-08-22T00:00:00UTC
# Se ha descargado los datos de 1925-08-26T00:00:00UTC a 1926-02-22T00:00:00UTC
# Se ha descargado los datos de 1925-02-26T00:00:00UTC a 1925-08-25T00:00:00UTC
# Se ha descargado los datos de 1924-08-29T00:00:00UTC a 1925-02-25T00:00:00UTC
# Se ha descargado los datos de 1924-03-01T00:00:00UTC a 1924-08-28T00:00:00UTC
# Se ha descargado los datos de 1923-09-02T00:00:00UTC a 1924-02-29T00:00:00UTC
# Se ha descargado los datos de 1923-03-05T00:00:00UTC a 1923-09-01T00:00:00UTC
# Se ha descargado los datos de 1922-09-05T00:00:00UTC a 1923-03-04T00:00:00UTC
# Se ha descargado los datos de 1922-03-08T00:00:00UTC a 1922-09-04T00:00:00UTC
# Se ha descargado los datos de 1921-09-08T00:00:00UTC a 1922-03-07T00:00:00UTC
# Se ha descargado los datos de 1921-03-11T00:00:00UTC a 1921-09-07T00:00:00UTC
# Se ha descargado los datos de 1920-09-11T00:00:00UTC a 1921-03-10T00:00:00UTC
# Se ha descargado los datos de 1920-03-14T00:00:00UTC a 1920-09-10T00:00:00UTC
# Se ha descargado los datos de 1919-09-15T00:00:00UTC a 1920-03-13T00:00:00UTC
# No se encontró la URL de datos
# No se encontró la URL de datos
# No se encontró la URL de datos
# Número máximo de intentos alcanzado

# %%
execution_time = end_time - start_time
hours = int(execution_time // 3600)
minutes = int((execution_time % 3600) // 60)
seconds = execution_time % 60
print(f"Tiempo de ejecución: {hours}h {minutes}m {seconds:.0f}s")
# Out:
# Tiempo de ejecución: 0h 9m 37s

# %% [markdown]
# 3. Se guardan los datos descargados en un fichero .json

# %%
folder_name = "dataset_historico_id_3195"
os.makedirs(folder_name, exist_ok=True)

file_path = os.path.join(folder_name, f"datos_historicos_{fecha_max_descargada[:10]}.jsonl")

with open(file_path, "w", encoding="utf-8") as f:
    for sublista in lista_datos_historicos:  # Iterar sobre cada sublista
        for item in sublista:  # Iterar sobre cada diccionario en la sublista
            f.write(json.dumps(item, ensure_ascii=False) + "\n")  # 1 línea por JSON

# %% [markdown]
# 4. Se guarda el tiempo de ejecución de la descarga en un fichero .txt en modo "append"

# %%
file_path_time = os.path.join(folder_name, f"tiempo_ejecucion.txt")
with open(file_path_time, "a", encoding="utf-8") as f:
    f.write(f"Tiempo de ejecución: {hours}h {minutes}m {seconds:.0f}s a fecha de {ahora}\n")

# %% [markdown]
# # 2. Se investiga la fecha más antigua descargada

# %%
fecha_ini = "1919-09-15T00:00:00UTC"
fecha_fin = "1920-03-13T00:00:00UTC"
estacion_id = "3195"  # Ejemplo de estación meteorológica de Madrid-Retiro

url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fecha_ini}/fechafin/{fecha_fin}/estacion/{estacion_id}?api_key={API_KEY}"

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    print(json.dumps(data, indent=4, ensure_ascii=False))
    datos_url = data.get("datos")
    if datos_url:
        response_data = requests.get(datos_url)
        if response_data.status_code == 200:
            datos_historicos = response_data.json()
            print(json.dumps(datos_historicos, indent=4, ensure_ascii=False))
        else:
            print("Error al obtener los datos reales")
    else:
        print("No se encontró la URL de datos")
else:
    print("Error en la petición inicial, código de error:", response.status_code)
# Out:
# {
#     "descripcion": "exito",
#     "estado": 200,
#     "datos": "https://opendata.aemet.es/opendata/sh/48ac66f1",
#     "metadatos": "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }
# [
#     {
#         "fecha": "1920-01-01",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,4",
#         "prec": "0,0",
#         "tmin": "8,8",
#         "horatmin": "23:59",
#         "tmax": "11,9",
#         "horatmax": "10:30",
#         "sol": "3,5",
#         "presMax": "934,6",
#         "horaPresMax": "00",
#         "presMin": "925,3",
#         "horaPresMin": "15",
#         "hrMedia": "72"
#     },
#     {
#         "fecha": "1920-01-02",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,8",
#         "prec": "0,0",
#         "tmin": "2,6",
#         "horatmin": "06:30",
#         "tmax": "11,0",
#         "horatmax": "12:30",
#         "sol": "7,4",
#         "presMax": "940,3",
#         "horaPresMax": "11",
#         "presMin": "931,9",
#         "horaPresMin": "00",
#         "hrMedia": "63"
#     },
#     {
#         "fecha": "1920-01-03",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,5",
#         "prec": "1,4",
#         "tmin": "2,4",
#         "horatmin": "23:30",
#         "tmax": "8,6",
#         "horatmax": "09:30",
#         "sol": "3,3",
#         "presMax": "937,3",
#         "horaPresMax": "00",
#         "presMin": "923,7",
#         "horaPresMin": "24",
#         "hrMedia": "77"
#     },
#     {
#         "fecha": "1920-01-04",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,6",
#         "prec": "0,0",
#         "tmin": "2,5",
#         "horatmin": "22:00",
#         "tmax": "6,8",
#         "horatmax": "13:30",
#         "sol": "3,3",
#         "presMax": "929,0",
#         "horaPresMax": "24",
#         "presMin": "922,7",
#         "horaPresMin": "04",
#         "hrMedia": "72"
#     },
#     {
#         "fecha": "1920-01-05",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,1",
#         "prec": "0,0",
#         "tmin": "1,6",
#         "horatmin": "08:00",
#         "tmax": "6,6",
#         "horatmax": "00:00",
#         "sol": "5,3",
#         "presMax": "933,8",
#         "horaPresMax": "23",
#         "presMin": "928,7",
#         "horaPresMin": "00",
#         "hrMedia": "69"
#     },
#     {
#         "fecha": "1920-01-06",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "2,2",
#         "prec": "0,0",
#         "tmin": "-1,5",
#         "horatmin": "06:30",
#         "tmax": "5,8",
#         "horatmax": "16:00",
#         "sol": "7,2",
#         "presMax": "935,0",
#         "horaPresMax": "23",
#         "presMin": "929,8",
#         "horaPresMin": "14",
#         "hrMedia": "78"
#     },
#     {
#         "fecha": "1920-01-07",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "3,8",
#         "prec": "0,0",
#         "tmin": "0,8",
#         "horatmin": "08:00",
#         "tmax": "6,9",
#         "horatmax": "15:00",
#         "sol": "0,7",
#         "presMax": "943,3",
#         "horaPresMax": "24",
#         "presMin": "934,9",
#         "horaPresMin": "01",
#         "hrMedia": "72"
#     },
#     {
#         "fecha": "1920-01-08",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "2,3",
#         "prec": "0,0",
#         "tmin": "-1,6",
#         "horatmin": "08:00",
#         "tmax": "6,2",
#         "horatmax": "16:00",
#         "sol": "1,2",
#         "presMax": "948,6",
#         "horaPresMax": "23",
#         "presMin": "943,3",
#         "horaPresMin": "00",
#         "hrMedia": "81"
#     },
#     {
#         "fecha": "1920-01-09",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,5",
#         "prec": "0,0",
#         "tmin": "-1,2",
#         "horatmin": "04:15",
#         "tmax": "12,2",
#         "horatmax": "14:00",
#         "sol": "7,7",
#         "presMax": "950,3",
#         "horaPresMax": "24",
#         "presMin": "947,7",
#         "horaPresMin": "01",
#         "hrMedia": "77"
#     },
#     {
#         "fecha": "1920-01-10",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,3",
#         "prec": "0,0",
#         "tmin": "0,9",
#         "horatmin": "06:30",
#         "tmax": "9,7",
#         "horatmax": "00:00",
#         "sol": "0,0",
#         "presMax": "951,0",
#         "horaPresMax": "11",
#         "presMin": "948,2",
#         "horaPresMin": "01",
#         "hrMedia": "100"
#     },
#     {
#         "fecha": "1920-01-11",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,9",
#         "prec": "0,0",
#         "tmin": "4,2",
#         "horatmin": "07:00",
#         "tmax": "9,6",
#         "horatmax": "13:30",
#         "sol": "1,3",
#         "presMax": "953,8",
#         "horaPresMax": "24",
#         "presMin": "950,6",
#         "horaPresMin": "03"
#     },
#     {
#         "fecha": "1920-01-12",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,0",
#         "prec": "0,2",
#         "tmin": "3,6",
#         "horatmin": "08:00",
#         "tmax": "6,5",
#         "horatmax": "15:00",
#         "sol": "0,0",
#         "presMax": "957,2",
#         "horaPresMax": "21",
#         "presMin": "953,8",
#         "horaPresMin": "00",
#         "hrMedia": "99"
#     },
#     {
#         "fecha": "1920-01-13",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,5",
#         "prec": "0,0",
#         "tmin": "2,8",
#         "horatmin": "Varias",
#         "tmax": "10,2",
#         "horatmax": "14:00",
#         "sol": "5,0",
#         "presMax": "955,9",
#         "horaPresMax": "00",
#         "presMin": "951,9",
#         "horaPresMin": "16",
#         "hrMedia": "94"
#     },
#     {
#         "fecha": "1920-01-14",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,3",
#         "prec": "0,0",
#         "tmin": "0,1",
#         "horatmin": "08:00",
#         "tmax": "12,5",
#         "horatmax": "15:10",
#         "sol": "7,3",
#         "presMax": "953,3",
#         "horaPresMax": "10",
#         "presMin": "951,7",
#         "horaPresMin": "16",
#         "hrMedia": "86"
#     },
#     {
#         "fecha": "1920-01-15",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,2",
#         "prec": "0,0",
#         "tmin": "1,4",
#         "horatmin": "06:00",
#         "tmax": "12,9",
#         "horatmax": "15:00",
#         "sol": "8,4",
#         "presMax": "956,1",
#         "horaPresMax": "24",
#         "presMin": "952,9",
#         "horaPresMin": "01",
#         "hrMedia": "86"
#     },
#     {
#         "fecha": "1920-01-16",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,4",
#         "prec": "0,0",
#         "tmin": "3,4",
#         "horatmin": "08:00",
#         "tmax": "13,4",
#         "horatmax": "15:55",
#         "sol": "8,5",
#         "presMax": "959,7",
#         "horaPresMax": "24",
#         "presMin": "955,9",
#         "horaPresMin": "00",
#         "hrMedia": "81"
#     },
#     {
#         "fecha": "1920-01-17",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,6",
#         "prec": "0,0",
#         "tmin": "3,0",
#         "horatmin": "05:30",
#         "tmax": "14,3",
#         "horatmax": "15:00",
#         "sol": "8,4",
#         "presMax": "959,7",
#         "horaPresMax": "00",
#         "presMin": "955,9",
#         "horaPresMin": "24",
#         "hrMedia": "72"
#     },
#     {
#         "fecha": "1920-01-18",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,0",
#         "prec": "0,0",
#         "tmin": "0,3",
#         "horatmin": "07:45",
#         "tmax": "11,8",
#         "horatmax": "15:00",
#         "sol": "8,3",
#         "presMax": "955,9",
#         "horaPresMax": "00",
#         "presMin": "948,1",
#         "horaPresMin": "24",
#         "hrMedia": "80"
#     },
#     {
#         "fecha": "1920-01-19",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,7",
#         "prec": "0,0",
#         "tmin": "-0,1",
#         "horatmin": "07:00",
#         "tmax": "9,5",
#         "horatmax": "16:00",
#         "sol": "8,4",
#         "presMax": "951,9",
#         "horaPresMax": "24",
#         "presMin": "947,1",
#         "horaPresMin": "05"
#     },
#     {
#         "fecha": "1920-01-20",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,6",
#         "prec": "0,0",
#         "tmin": "-0,7",
#         "horatmin": "06:50",
#         "tmax": "9,8",
#         "horatmax": "16:00",
#         "sol": "8,3",
#         "presMax": "955,1",
#         "horaPresMax": "10",
#         "presMin": "952,1",
#         "horaPresMin": "00",
#         "hrMedia": "65"
#     },
#     {
#         "fecha": "1920-01-21",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,0",
#         "prec": "0,0",
#         "tmin": "1,7",
#         "horatmin": "08:00",
#         "tmax": "12,4",
#         "horatmax": "17:00",
#         "sol": "7,8",
#         "presMax": "953,5",
#         "horaPresMax": "00",
#         "presMin": "949,5",
#         "horaPresMin": "17",
#         "hrMedia": "76"
#     },
#     {
#         "fecha": "1920-01-22",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,9",
#         "prec": "0,0",
#         "tmin": "3,2",
#         "horatmin": "08:15",
#         "tmax": "14,6",
#         "horatmax": "16:30",
#         "sol": "8,4",
#         "presMax": "950,6",
#         "horaPresMax": "00",
#         "presMin": "947,4",
#         "horaPresMin": "24",
#         "hrMedia": "70"
#     },
#     {
#         "fecha": "1920-01-23",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,2",
#         "prec": "0,0",
#         "tmin": "2,1",
#         "horatmin": "08:00",
#         "tmax": "12,4",
#         "horatmax": "15:00",
#         "sol": "7,6",
#         "presMax": "947,9",
#         "horaPresMax": "11",
#         "presMin": "945,3",
#         "horaPresMin": "24",
#         "hrMedia": "62"
#     },
#     {
#         "fecha": "1920-01-24",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,6",
#         "prec": "0,0",
#         "tmin": "3,5",
#         "horatmin": "08:00",
#         "tmax": "11,6",
#         "horatmax": "15:00",
#         "sol": "4,4",
#         "presMax": "946,5",
#         "horaPresMax": "11",
#         "presMin": "944,2",
#         "horaPresMin": "15",
#         "hrMedia": "77"
#     },
#     {
#         "fecha": "1920-01-25",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,0",
#         "prec": "0,0",
#         "tmin": "3,7",
#         "horatmin": "06:30",
#         "tmax": "12,4",
#         "horatmax": "16:00",
#         "sol": "7,4",
#         "presMax": "946,6",
#         "horaPresMax": "11",
#         "presMin": "942,9",
#         "horaPresMin": "16",
#         "hrMedia": "75"
#     },
#     {
#         "fecha": "1920-01-26",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,8",
#         "prec": "0,8",
#         "tmin": "4,4",
#         "horatmin": "07:30",
#         "tmax": "9,3",
#         "horatmax": "14:45",
#         "sol": "0,0",
#         "presMax": "945,8",
#         "horaPresMax": "24",
#         "presMin": "944,5",
#         "horaPresMin": "00",
#         "hrMedia": "92"
#     },
#     {
#         "fecha": "1920-01-27",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,9",
#         "prec": "0,0",
#         "tmin": "6,0",
#         "horatmin": "Varias",
#         "tmax": "11,8",
#         "horatmax": "15:50",
#         "sol": "1,8",
#         "presMax": "946,6",
#         "horaPresMax": "11",
#         "presMin": "944,3",
#         "horaPresMin": "24",
#         "hrMedia": "95"
#     },
#     {
#         "fecha": "1920-01-28",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,8",
#         "prec": "0,4",
#         "tmin": "4,4",
#         "horatmin": "06:50",
#         "tmax": "11,2",
#         "horatmax": "15:30",
#         "sol": "1,0",
#         "presMax": "944,6",
#         "horaPresMax": "00",
#         "presMin": "940,1",
#         "horaPresMin": "14",
#         "hrMedia": "86"
#     },
#     {
#         "fecha": "1920-01-29",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,6",
#         "prec": "0,0",
#         "tmin": "3,5",
#         "horatmin": "23:59",
#         "tmax": "9,7",
#         "horatmax": "15:30",
#         "sol": "5,7",
#         "presMax": "952,5",
#         "horaPresMax": "24",
#         "presMin": "942,6",
#         "horaPresMin": "00",
#         "hrMedia": "69"
#     },
#     {
#         "fecha": "1920-01-30",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "3,6",
#         "prec": "0,0",
#         "tmin": "0,4",
#         "horatmin": "03:55",
#         "tmax": "6,8",
#         "horatmax": "17:00",
#         "sol": "0,0",
#         "presMax": "956,3",
#         "horaPresMax": "24",
#         "presMin": "952,2",
#         "horaPresMin": "02",
#         "hrMedia": "91"
#     },
#     {
#         "fecha": "1920-01-31",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,6",
#         "prec": "0,0",
#         "tmin": "0,5",
#         "horatmin": "05:00",
#         "tmax": "10,8",
#         "horatmax": "16:00",
#         "sol": "8,7",
#         "presMax": "957,0",
#         "horaPresMax": "24",
#         "presMin": "955,1",
#         "horaPresMin": "17",
#         "hrMedia": "86"
#     },
#     {
#         "fecha": "1920-02-01",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,6",
#         "prec": "0,0",
#         "tmin": "2,5",
#         "horatmin": "07:15",
#         "tmax": "14,8",
#         "horatmax": "15:30",
#         "sol": "9,0",
#         "presMax": "959,3",
#         "horaPresMax": "11",
#         "presMin": "956,9",
#         "horaPresMin": "00",
#         "hrMedia": "73"
#     },
#     {
#         "fecha": "1920-02-02",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,6",
#         "prec": "0,0",
#         "tmin": "4,6",
#         "horatmin": "08:00",
#         "tmax": "14,7",
#         "horatmax": "15:00",
#         "sol": "9,0",
#         "presMax": "960,6",
#         "horaPresMax": "10",
#         "presMin": "958,2",
#         "horaPresMin": "16",
#         "hrMedia": "76"
#     },
#     {
#         "fecha": "1920-02-03",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,4",
#         "prec": "0,0",
#         "tmin": "1,2",
#         "horatmin": "06:30",
#         "tmax": "13,7",
#         "horatmax": "16:00",
#         "sol": "9,1",
#         "presMax": "958,6",
#         "horaPresMax": "00",
#         "presMin": "954,2",
#         "horaPresMin": "24",
#         "hrMedia": "81"
#     },
#     {
#         "fecha": "1920-02-04",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,0",
#         "prec": "0,0",
#         "tmin": "1,0",
#         "horatmin": "07:15",
#         "tmax": "13,1",
#         "horatmax": "15:30",
#         "sol": "9,1",
#         "presMax": "954,6",
#         "horaPresMax": "24",
#         "presMin": "952,1",
#         "horaPresMin": "06",
#         "hrMedia": "59"
#     },
#     {
#         "fecha": "1920-02-05",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,1",
#         "prec": "0,0",
#         "tmin": "-0,6",
#         "horatmin": "07:30",
#         "tmax": "10,8",
#         "horatmax": "16:00",
#         "sol": "9,3",
#         "presMax": "954,6",
#         "horaPresMax": "00",
#         "presMin": "949,5",
#         "horaPresMin": "17",
#         "hrMedia": "74"
#     },
#     {
#         "fecha": "1920-02-06",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,9",
#         "prec": "0,0",
#         "tmin": "0,2",
#         "horatmin": "07:45",
#         "tmax": "9,6",
#         "horatmax": "16:00",
#         "sol": "9,2",
#         "presMax": "951,1",
#         "horaPresMax": "12",
#         "presMin": "948,6",
#         "horaPresMin": "16",
#         "hrMedia": "69"
#     },
#     {
#         "fecha": "1920-02-07",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,5",
#         "prec": "0,0",
#         "tmin": "-0,3",
#         "horatmin": "07:45",
#         "tmax": "9,3",
#         "horatmax": "15:00",
#         "sol": "8,1",
#         "presMax": "953,9",
#         "horaPresMax": "24",
#         "presMin": "949,7",
#         "horaPresMin": "15",
#         "hrMedia": "79"
#     },
#     {
#         "fecha": "1920-02-08",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "3,8",
#         "prec": "0,0",
#         "tmin": "-0,7",
#         "horatmin": "07:30",
#         "tmax": "8,2",
#         "horatmax": "15:30",
#         "sol": "9,3",
#         "presMax": "957,7",
#         "horaPresMax": "24",
#         "presMin": "953,9",
#         "horaPresMin": "00",
#         "hrMedia": "77"
#     },
#     {
#         "fecha": "1920-02-09",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,0",
#         "prec": "0,0",
#         "tmin": "-1,6",
#         "horatmin": "06:45",
#         "tmax": "9,7",
#         "horatmax": "15:00",
#         "sol": "9,3",
#         "presMax": "959,0",
#         "horaPresMax": "11",
#         "presMin": "956,1",
#         "horaPresMin": "18",
#         "hrMedia": "59"
#     },
#     {
#         "fecha": "1920-02-10",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,9",
#         "prec": "0,0",
#         "tmin": "-1,4",
#         "horatmin": "07:15",
#         "tmax": "11,2",
#         "horatmax": "16:00",
#         "sol": "9,5",
#         "presMax": "957,9",
#         "horaPresMax": "11",
#         "presMin": "954,3",
#         "horaPresMin": "18",
#         "hrMedia": "38"
#     },
#     {
#         "fecha": "1920-02-11",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "4,4",
#         "prec": "0,0",
#         "tmin": "-2,9",
#         "horatmin": "07:15",
#         "tmax": "11,6",
#         "horatmax": "16:00",
#         "sol": "9,6",
#         "presMax": "955,9",
#         "horaPresMax": "00",
#         "presMin": "951,8",
#         "horaPresMin": "17",
#         "hrMedia": "56"
#     },
#     {
#         "fecha": "1920-02-12",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,4",
#         "prec": "0,0",
#         "tmin": "-1,3",
#         "horatmin": "07:15",
#         "tmax": "14,2",
#         "horatmax": "15:00",
#         "sol": "9,6",
#         "presMax": "953,3",
#         "horaPresMax": "11",
#         "presMin": "947,8",
#         "horaPresMin": "24",
#         "hrMedia": "58"
#     },
#     {
#         "fecha": "1920-02-13",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,4",
#         "prec": "0,0",
#         "tmin": "2,1",
#         "horatmin": "07:15",
#         "tmax": "12,8",
#         "horatmax": "14:30",
#         "sol": "0,0",
#         "presMax": "947,8",
#         "horaPresMax": "00",
#         "presMin": "943,5",
#         "horaPresMin": "24",
#         "hrMedia": "69"
#     },
#     {
#         "fecha": "1920-02-14",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,2",
#         "prec": "0,0",
#         "tmin": "4,6",
#         "horatmin": "06:15",
#         "tmax": "13,8",
#         "horatmax": "14:00",
#         "sol": "7,5",
#         "presMax": "943,9",
#         "horaPresMax": "14",
#         "presMin": "939,5",
#         "horaPresMin": "17",
#         "hrMedia": "68"
#     },
#     {
#         "fecha": "1920-02-15",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,2",
#         "prec": "Ip",
#         "tmin": "4,6",
#         "horatmin": "07:15",
#         "tmax": "9,8",
#         "horatmax": "16:00",
#         "sol": "1,6",
#         "presMax": "940,7",
#         "horaPresMax": "00",
#         "presMin": "939,7",
#         "horaPresMin": "16",
#         "hrMedia": "80"
#     },
#     {
#         "fecha": "1920-02-16",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,8",
#         "prec": "1,5",
#         "tmin": "5,9",
#         "horatmin": "06:55",
#         "tmax": "11,8",
#         "horatmax": "15:00",
#         "sol": "0,0",
#         "presMax": "940,2",
#         "horaPresMax": "00",
#         "presMin": "934,3",
#         "horaPresMin": "24",
#         "hrMedia": "79"
#     },
#     {
#         "fecha": "1920-02-17",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,0",
#         "prec": "2,5",
#         "tmin": "6,4",
#         "horatmin": "06:00",
#         "tmax": "11,5",
#         "horatmax": "16:00",
#         "sol": "1,3",
#         "presMax": "935,3",
#         "horaPresMax": "00",
#         "presMin": "927,9",
#         "horaPresMin": "18",
#         "hrMedia": "74"
#     },
#     {
#         "fecha": "1920-02-18",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "11,4",
#         "prec": "24,5",
#         "tmin": "8,7",
#         "horatmin": "18:45",
#         "tmax": "14,0",
#         "horatmax": "12:00",
#         "sol": "0,5",
#         "presMax": "931,7",
#         "horaPresMax": "22",
#         "presMin": "927,3",
#         "horaPresMin": "15",
#         "hrMedia": "79"
#     },
#     {
#         "fecha": "1920-02-19",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "9,2",
#         "prec": "26,2",
#         "tmin": "7,2",
#         "horatmin": "23:00",
#         "tmax": "11,1",
#         "horatmax": "12:00",
#         "sol": "0,0",
#         "presMax": "931,1",
#         "horaPresMax": "00",
#         "presMin": "924,3",
#         "horaPresMin": "14"
#     },
#     {
#         "fecha": "1920-02-20",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "6,0",
#         "prec": "14,4",
#         "tmin": "4,8",
#         "horatmin": "06:45",
#         "tmax": "7,3",
#         "horatmax": "17:00",
#         "sol": "0,0",
#         "presMax": "928,7",
#         "horaPresMax": "24",
#         "presMin": "923,9",
#         "horaPresMin": "06",
#         "hrMedia": "100"
#     },
#     {
#         "fecha": "1920-02-21",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,2",
#         "prec": "0,1",
#         "tmin": "4,7",
#         "horatmin": "06:00",
#         "tmax": "11,7",
#         "horatmax": "14:30",
#         "sol": "1,9",
#         "presMax": "940,2",
#         "horaPresMax": "24",
#         "presMin": "928,7",
#         "horaPresMin": "00",
#         "hrMedia": "89"
#     },
#     {
#         "fecha": "1920-02-22",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,8",
#         "prec": "0,0",
#         "tmin": "5,4",
#         "horatmin": "07:00",
#         "tmax": "12,3",
#         "horatmax": "16:00",
#         "sol": "8,4",
#         "presMax": "943,8",
#         "horaPresMax": "24",
#         "presMin": "940,2",
#         "horaPresMin": "00",
#         "hrMedia": "77"
#     },
#     {
#         "fecha": "1920-02-23",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,2",
#         "prec": "0,0",
#         "tmin": "4,6",
#         "horatmin": "06:00",
#         "tmax": "11,7",
#         "horatmax": "16:00",
#         "sol": "2,0",
#         "presMax": "945,7",
#         "horaPresMax": "10",
#         "presMin": "942,7",
#         "horaPresMin": "18",
#         "hrMedia": "79"
#     },
#     {
#         "fecha": "1920-02-24",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,6",
#         "prec": "7,7",
#         "tmin": "5,6",
#         "horatmin": "02:30",
#         "tmax": "9,5",
#         "horatmax": "14:00",
#         "sol": "0,0",
#         "presMax": "943,5",
#         "horaPresMax": "00",
#         "presMin": "941,0",
#         "horaPresMin": "17",
#         "hrMedia": "81"
#     },
#     {
#         "fecha": "1920-02-25",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "8,4",
#         "prec": "1,9",
#         "tmin": "7,0",
#         "horatmin": "07:00",
#         "tmax": "9,7",
#         "horatmax": "16:00",
#         "sol": "0,0",
#         "presMax": "942,2",
#         "horaPresMax": "24",
#         "presMin": "941,3",
#         "horaPresMin": "16",
#         "hrMedia": "98"
#     },
#     {
#         "fecha": "1920-02-26",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,2",
#         "prec": "6,0",
#         "tmin": "7,9",
#         "horatmin": "07:15",
#         "tmax": "12,5",
#         "horatmax": "15:00",
#         "sol": "0,0",
#         "presMax": "944,3",
#         "horaPresMax": "24",
#         "presMin": "941,9",
#         "horaPresMin": "15",
#         "hrMedia": "91"
#     },
#     {
#         "fecha": "1920-02-27",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "11,3",
#         "prec": "1,8",
#         "tmin": "8,4",
#         "horatmin": "07:15",
#         "tmax": "14,2",
#         "horatmax": "15:00",
#         "sol": "1,3",
#         "presMax": "945,8",
#         "horaPresMax": "20",
#         "presMin": "942,7",
#         "horaPresMin": "15",
#         "hrMedia": "88"
#     },
#     {
#         "fecha": "1920-02-28",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "11,8",
#         "prec": "2,8",
#         "tmin": "9,7",
#         "horatmin": "03:00",
#         "tmax": "13,8",
#         "horatmax": "12:00",
#         "sol": "1,0",
#         "presMax": "945,8",
#         "horaPresMax": "10",
#         "presMin": "942,6",
#         "horaPresMin": "16",
#         "hrMedia": "80"
#     },
#     {
#         "fecha": "1920-02-29",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "12,3",
#         "prec": "0,0",
#         "tmin": "8,8",
#         "horatmin": "23:59",
#         "tmax": "15,8",
#         "horatmax": "15:00",
#         "sol": "6,3",
#         "presMax": "946,6",
#         "horaPresMax": "24",
#         "presMin": "943,7",
#         "horaPresMin": "16",
#         "hrMedia": "80"
#     },
#     {
#         "fecha": "1920-03-01",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "7,4",
#         "prec": "0,5",
#         "tmin": "4,2",
#         "horatmin": "06:00",
#         "tmax": "10,6",
#         "horatmax": "13:00",
#         "sol": "1,3",
#         "presMax": "947,3",
#         "horaPresMax": "10",
#         "presMin": "944,5",
#         "horaPresMin": "16"
#     },
#     {
#         "fecha": "1920-03-02",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,1",
#         "prec": "3,9",
#         "tmin": "7,8",
#         "horatmin": "05:00",
#         "tmax": "12,4",
#         "horatmax": "12:55",
#         "sol": "0,0",
#         "presMax": "947,9",
#         "horaPresMax": "00",
#         "presMin": "944,4",
#         "horaPresMin": "Varias",
#         "hrMedia": "88"
#     },
#     {
#         "fecha": "1920-03-03",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,6",
#         "prec": "3,1",
#         "tmin": "6,2",
#         "horatmin": "08:40",
#         "tmax": "14,9",
#         "horatmax": "15:00",
#         "sol": "5,4",
#         "presMax": "951,9",
#         "horaPresMax": "09",
#         "presMin": "947,4",
#         "horaPresMin": "00",
#         "hrMedia": "72"
#     },
#     {
#         "fecha": "1920-03-04",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "11,8",
#         "prec": "0,0",
#         "tmin": "6,4",
#         "horatmin": "06:30",
#         "tmax": "17,2",
#         "horatmax": "16:00",
#         "sol": "9,2",
#         "presMax": "951,7",
#         "horaPresMax": "10",
#         "presMin": "945,7",
#         "horaPresMin": "19",
#         "hrMedia": "67"
#     },
#     {
#         "fecha": "1920-03-05",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "11,3",
#         "prec": "0,0",
#         "tmin": "6,5",
#         "horatmin": "06:40",
#         "tmax": "16,1",
#         "horatmax": "12:00",
#         "sol": "4,7",
#         "presMax": "946,9",
#         "horaPresMax": "00",
#         "presMin": "943,3",
#         "horaPresMin": "24",
#         "hrMedia": "81"
#     },
#     {
#         "fecha": "1920-03-06",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "13,6",
#         "prec": "0,0",
#         "tmin": "9,8",
#         "horatmin": "23:59",
#         "tmax": "17,4",
#         "horatmax": "13:00",
#         "sol": "1,5",
#         "presMax": "943,3",
#         "horaPresMax": "00",
#         "presMin": "931,1",
#         "horaPresMin": "24"
#     },
#     {
#         "fecha": "1920-03-07",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,6",
#         "prec": "8,2",
#         "tmin": "3,8",
#         "horatmin": "23:59",
#         "tmax": "7,5",
#         "horatmax": "13:00",
#         "sol": "2,5",
#         "presMax": "934,3",
#         "horaPresMax": "19",
#         "presMin": "929,7",
#         "horaPresMin": "05"
#     },
#     {
#         "fecha": "1920-03-08",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "3,1",
#         "prec": "0,6",
#         "tmin": "-0,5",
#         "horatmin": "04:00",
#         "tmax": "6,7",
#         "horatmax": "14:00",
#         "sol": "4,9",
#         "presMax": "945,9",
#         "horaPresMax": "24",
#         "presMin": "933,7",
#         "horaPresMin": "00",
#         "hrMedia": "69"
#     },
#     {
#         "fecha": "1920-03-09",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "1,8",
#         "prec": "Ip",
#         "tmin": "-0,7",
#         "horatmin": "06:00",
#         "tmax": "4,4",
#         "horatmax": "12:00",
#         "sol": "8,2",
#         "presMax": "951,7",
#         "horaPresMax": "23",
#         "presMin": "945,7",
#         "horaPresMin": "03",
#         "hrMedia": "46"
#     },
#     {
#         "fecha": "1920-03-10",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "3,5",
#         "prec": "0,0",
#         "tmin": "-0,6",
#         "horatmin": "03:00",
#         "tmax": "7,6",
#         "horatmax": "16:00",
#         "sol": "6,7",
#         "presMax": "951,5",
#         "horaPresMax": "00",
#         "presMin": "949,1",
#         "horaPresMin": "14",
#         "hrMedia": "55"
#     },
#     {
#         "fecha": "1920-03-11",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "5,4",
#         "prec": "0,0",
#         "tmin": "-1,8",
#         "horatmin": "05:00",
#         "tmax": "12,7",
#         "horatmax": "16:30",
#         "sol": "10,0",
#         "presMax": "951,2",
#         "horaPresMax": "09",
#         "presMin": "948,6",
#         "horaPresMin": "16",
#         "hrMedia": "57"
#     },
#     {
#         "fecha": "1920-03-12",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,5",
#         "prec": "0,0",
#         "tmin": "5,9",
#         "horatmin": "00:15",
#         "tmax": "15,1",
#         "horatmax": "13:00",
#         "sol": "5,7",
#         "presMax": "949,5",
#         "horaPresMax": "10",
#         "presMin": "947,3",
#         "horaPresMin": "24"
#     },
#     {
#         "fecha": "1920-03-13",
#         "indicativo": "3195",
#         "nombre": "MADRID, RETIRO",
#         "provincia": "MADRID",
#         "altitud": "667",
#         "tmed": "10,0",
#         "prec": "Ip",
#         "tmin": "7,2",
#         "horatmin": "08:00",
#         "tmax": "12,9",
#         "horatmax": "16:00",
#         "sol": "1,7",
#         "presMax": "947,3",
#         "horaPresMax": "00",
#         "presMin": "941,9",
#         "horaPresMin": "16",
#         "hrMedia": "80"
#     }
# ]

# %%
fecha_min = min([dato["fecha"] for dato in datos_historicos]) 
# A pesar de ser texto, es yyyy-mm-dd y se puede obtener el minimo directamente

print(f"La fecha más antigua descargada es: {fecha_min}")
# Out:
# La fecha más antigua descargada es: 1920-01-01
